# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Conv1D, GlobalAveragePooling1D, Dropout, Dense, BatchNormalization, ReLU
from tensorflow.keras.models import Model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, auc, precision_recall_curve
from tensorflow.keras.layers import Input, Permute
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight
#from tensorflow.keras import backend as K

#####
from utils.data_extraction import download_zip, extract_zip
from utils.read_data import tsv_to_csv
from utils.train_model import train_lstm_fcn
from utils.save_best import save_best_result
from utils.finetune import fine_tune_model
from utils.move import move_files
#from load_data import load_ucr_dataset
#from build_model import build_lstm_fcn,build_alstm_fcn
#from ALSTM import AttentionLSTM, AttentionLSTMCell
#####

# %%
##########
# you can skip the FOLLOWING steps if you already have
### data folder containing csv ###
# and directly proceed to load dataset name and train data
#########

# %%
# as a substitute you can download the zip 
# from https://www.cs.ucr.edu/~eamonn/time_series_data_2018/UCRArchive_2018.zip
# and name it as UCRArchive_2018.zip to skip this step
download_zip(URL = "https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/UCRArchive_2018.zip")
# Out:
# File downloaded successfully as UCRArchive_2018.zip

# %%
# it may take 5-10 minutes to extract the data.
# as a substitute you can extract the zip into a folder named "UCRArchive_2018" 
# under the current location to skip this step.
# the password to the zip is "someone". Good luck!
extract_zip(zip_file_path = "UCRArchive_2018.zip", pwd = "someone")
# Out:
# Files extracted successfully!

# %%
# we convert all the tsv file into csv file and store them in a folder named "data"
tsv_to_csv(input_folder = "UCRArchive_2018", output_folder = "data")
# Out:
# Converted: UCRArchive_2018/ECG5000/ECG5000_TRAIN.tsv to data/ECG5000_TRAIN.csv
# Converted: UCRArchive_2018/ECG5000/ECG5000_TEST.tsv to data/ECG5000_TEST.csv
# Converted: UCRArchive_2018/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TEST.tsv to data/SonyAIBORobotSurface2_TEST.csv
# Converted: UCRArchive_2018/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TRAIN.tsv to data/SonyAIBORobotSurface2_TRAIN.csv
# Converted: UCRArchive_2018/InlineSkate/InlineSkate_TRAIN.tsv to data/InlineSkate_TRAIN.csv
# Converted: UCRArchive_2018/InlineSkate/InlineSkate_TEST.tsv to data/InlineSkate_TEST.csv
# Converted: UCRArchive_2018/OliveOil/OliveOil_TEST.tsv to data/OliveOil_TEST.csv
# Converted: UCRArchive_2018/OliveOil/OliveOil_TRAIN.tsv to data/OliveOil_TRAIN.csv
# Converted: UCRArchive_2018/Earthquakes/Earthquakes_TEST.tsv to data/Earthquakes_TEST.csv
# Converted: UCRArchive_2018/Earthquakes/Earthquakes_TRAIN.tsv to data/Earthquakes_TRAIN.csv
# Converted: UCRArchive_2018/ShapesAll/ShapesAll_TRAIN.tsv to data/ShapesAll_TRAIN.csv
# Converted: UCRArchive_2018/ShapesAll/ShapesAll_TEST.tsv to data/ShapesAll_TEST.csv
# Converted: UCRArchive_2018/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TEST.tsv to data/MiddlePhalanxOutlineAgeGroup_TEST.csv
# Converted: UCRArchive_2018/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TRAIN.tsv to data/MiddlePhalanxOutlineAgeGroup_TRAIN.csv
# Converted: UCRArchive_2018/TwoPatterns/TwoPatterns_TEST.tsv to data/TwoPatterns_TEST.csv
# Converted: UCRArchive_2018/TwoPatterns/TwoPatterns_TRAIN.tsv to data/TwoPatterns_TRAIN.csv
# Converted: UCRArchive_2018/RefrigerationDevices/RefrigerationDevices_TRAIN.tsv to data/RefrigerationDevices_TRAIN.csv
# Converted: UCRArchive_2018/RefrigerationDevices/RefrigerationDevices_TEST.tsv to data/RefrigerationDevices_TEST.csv
# Converted: UCRArchive_2018/AllGestureWiimoteX/AllGestureWiimoteX_TRAIN.tsv to data/AllGestureWiimoteX_TRAIN.csv
# Converted: UCRArchive_2018/AllGestureWiimoteX/AllGestureWiimoteX_TEST.tsv to data/AllGestureWiimoteX_TEST.csv
# Converted: UCRArchive_2018/UMD/UMD_TRAIN.tsv to data/UMD_TRAIN.csv
# Converted: UCRArchive_2018/UMD/UMD_TEST.tsv to data/UMD_TEST.csv
# Converted: UCRArchive_2018/InsectEPGSmallTrain/InsectEPGSmallTrain_TRAIN.tsv to data/InsectEPGSmallTrain_TRAIN.csv
# Converted: UCRArchive_2018/InsectEPGSmallTrain/InsectEPGSmallTrain_TEST.tsv to data/InsectEPGSmallTrain_TEST.csv
# Converted: UCRArchive_2018/Phoneme/Phoneme_TRAIN.tsv to data/Phoneme_TRAIN.csv
# Converted: UCRArchive_2018/Phoneme/Phoneme_TEST.tsv to data/Phoneme_TEST.csv
# Converted: UCRArchive_2018/FaceAll/FaceAll_TEST.tsv to data/FaceAll_TEST.csv
# Converted: UCRArchive_2018/FaceAll/FaceAll_TRAIN.tsv to data/FaceAll_TRAIN.csv
# Converted: UCRArchive_2018/Wine/Wine_TEST.tsv to data/Wine_TEST.csv
# Converted: UCRArchive_2018/Wine/Wine_TRAIN.tsv to data/Wine_TRAIN.csv
# Converted: UCRArchive_2018/ToeSegmentation1/ToeSegmentation1_TRAIN.tsv to data/ToeSegmentation1_TRAIN.csv
# Converted: UCRArchive_2018/ToeSegmentation1/ToeSegmentation1_TEST.tsv to data/ToeSegmentation1_TEST.csv
# Converted: UCRArchive_2018/SmallKitchenAppliances/SmallKitchenAppliances_TEST.tsv to data/SmallKitchenAppliances_TEST.csv
# Converted: UCRArchive_2018/SmallKitchenAppliances/SmallKitchenAppliances_TRAIN.tsv to data/SmallKitchenAppliances_TRAIN.csv
# Converted: UCRArchive_2018/Trace/Trace_TRAIN.tsv to data/Trace_TRAIN.csv
# Converted: UCRArchive_2018/Trace/Trace_TEST.tsv to data/Trace_TEST.csv
# Converted: UCRArchive_2018/ACSF1/ACSF1_TRAIN.tsv to data/ACSF1_TRAIN.csv
# Converted: UCRArchive_2018/ACSF1/ACSF1_TEST.tsv to data/ACSF1_TEST.csv
# Converted: UCRArchive_2018/Mallat/Mallat_TRAIN.tsv to data/Mallat_TRAIN.csv
# Converted: UCRArchive_2018/Mallat/Mallat_TEST.tsv to data/Mallat_TEST.csv
# Converted: UCRArchive_2018/Car/Car_TRAIN.tsv to data/Car_TRAIN.csv
# Converted: UCRArchive_2018/Car/Car_TEST.tsv to data/Car_TEST.csv
# Converted: UCRArchive_2018/DistalPhalanxTW/DistalPhalanxTW_TRAIN.tsv to data/DistalPhalanxTW_TRAIN.csv
# Converted: UCRArchive_2018/DistalPhalanxTW/DistalPhalanxTW_TEST.tsv to data/DistalPhalanxTW_TEST.csv
# Converted: UCRArchive_2018/Wafer/Wafer_TEST.tsv to data/Wafer_TEST.csv
# Converted: UCRArchive_2018/Wafer/Wafer_TRAIN.tsv to data/Wafer_TRAIN.csv
# Converted: UCRArchive_2018/CricketX/CricketX_TRAIN.tsv to data/CricketX_TRAIN.csv
# Converted: UCRArchive_2018/CricketX/CricketX_TEST.tsv to data/CricketX_TEST.csv
# Converted: UCRArchive_2018/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TRAIN.tsv to data/SonyAIBORobotSurface1_TRAIN.csv
# Converted: UCRArchive_2018/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TEST.tsv to data/SonyAIBORobotSurface1_TEST.csv
# Converted: UCRArchive_2018/BME/BME_TRAIN.tsv to data/BME_TRAIN.csv
# Converted: UCRArchive_2018/BME/BME_TEST.tsv to data/BME_TEST.csv
# Converted: UCRArchive_2018/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TEST.tsv to data/ProximalPhalanxOutlineAgeGroup_TEST.csv
# Converted: UCRArchive_2018/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TRAIN.tsv to data/ProximalPhalanxOutlineAgeGroup_TRAIN.csv
# Converted: UCRArchive_2018/SmoothSubspace/SmoothSubspace_TRAIN.tsv to data/SmoothSubspace_TRAIN.csv
# Converted: UCRArchive_2018/SmoothSubspace/SmoothSubspace_TEST.tsv to data/SmoothSubspace_TEST.csv
# Converted: UCRArchive_2018/FordB/FordB_TRAIN.tsv to data/FordB_TRAIN.csv
# Converted: UCRArchive_2018/FordB/FordB_TEST.tsv to data/FordB_TEST.csv
# Converted: UCRArchive_2018/Rock/Rock_TRAIN.tsv to data/Rock_TRAIN.csv
# Converted: UCRArchive_2018/Rock/Rock_TEST.tsv to data/Rock_TEST.csv
# Converted: UCRArchive_2018/SwedishLeaf/SwedishLeaf_TRAIN.tsv to data/SwedishLeaf_TRAIN.csv
# Converted: UCRArchive_2018/SwedishLeaf/SwedishLeaf_TEST.tsv to data/SwedishLeaf_TEST.csv
# Converted: UCRArchive_2018/Computers/Computers_TEST.tsv to data/Computers_TEST.csv
# Converted: UCRArchive_2018/Computers/Computers_TRAIN.tsv to data/Computers_TRAIN.csv
# Converted: UCRArchive_2018/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TEST.tsv to data/DistalPhalanxOutlineCorrect_TEST.csv
# Converted: UCRArchive_2018/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TRAIN.tsv to data/DistalPhalanxOutlineCorrect_TRAIN.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TEST.tsv to data/UWaveGestureLibraryZ_TEST.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TRAIN.tsv to data/UWaveGestureLibraryZ_TRAIN.csv
# Converted: UCRArchive_2018/Fungi/Fungi_TEST.tsv to data/Fungi_TEST.csv
# Converted: UCRArchive_2018/Fungi/Fungi_TRAIN.tsv to data/Fungi_TRAIN.csv
# Converted: UCRArchive_2018/FiftyWords/FiftyWords_TRAIN.tsv to data/FiftyWords_TRAIN.csv
# Converted: UCRArchive_2018/FiftyWords/FiftyWords_TEST.tsv to data/FiftyWords_TEST.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryY/UWaveGestureLibraryY_TRAIN.tsv to data/UWaveGestureLibraryY_TRAIN.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryY/UWaveGestureLibraryY_TEST.tsv to data/UWaveGestureLibraryY_TEST.csv
# Converted: UCRArchive_2018/MedicalImages/MedicalImages_TEST.tsv to data/MedicalImages_TEST.csv
# Converted: UCRArchive_2018/MedicalImages/MedicalImages_TRAIN.tsv to data/MedicalImages_TRAIN.csv
# Converted: UCRArchive_2018/Fish/Fish_TEST.tsv to data/Fish_TEST.csv
# Converted: UCRArchive_2018/Fish/Fish_TRAIN.tsv to data/Fish_TRAIN.csv
# Converted: UCRArchive_2018/GesturePebbleZ1/GesturePebbleZ1_TEST.tsv to data/GesturePebbleZ1_TEST.csv
# Converted: UCRArchive_2018/GesturePebbleZ1/GesturePebbleZ1_TRAIN.tsv to data/GesturePebbleZ1_TRAIN.csv
# Converted: UCRArchive_2018/Lightning7/Lightning7_TRAIN.tsv to data/Lightning7_TRAIN.csv
# Converted: UCRArchive_2018/Lightning7/Lightning7_TEST.tsv to data/Lightning7_TEST.csv
# Converted: UCRArchive_2018/MixedShapesRegularTrain/MixedShapesRegularTrain_TRAIN.tsv to data/MixedShapesRegularTrain_TRAIN.csv
# Converted: UCRArchive_2018/MixedShapesRegularTrain/MixedShapesRegularTrain_TEST.tsv to data/MixedShapesRegularTrain_TEST.csv
# Converted: UCRArchive_2018/InsectWingbeatSound/InsectWingbeatSound_TRAIN.tsv to data/InsectWingbeatSound_TRAIN.csv
# Converted: UCRArchive_2018/InsectWingbeatSound/InsectWingbeatSound_TEST.tsv to data/InsectWingbeatSound_TEST.csv
# Converted: UCRArchive_2018/CricketZ/CricketZ_TEST.tsv to data/CricketZ_TEST.csv
# Converted: UCRArchive_2018/CricketZ/CricketZ_TRAIN.tsv to data/CricketZ_TRAIN.csv
# Converted: UCRArchive_2018/DodgerLoopDay/DodgerLoopDay_TEST.tsv to data/DodgerLoopDay_TEST.csv
# Converted: UCRArchive_2018/DodgerLoopDay/DodgerLoopDay_TRAIN.tsv to data/DodgerLoopDay_TRAIN.csv
# Converted: UCRArchive_2018/ShapeletSim/ShapeletSim_TRAIN.tsv to data/ShapeletSim_TRAIN.csv
# Converted: UCRArchive_2018/ShapeletSim/ShapeletSim_TEST.tsv to data/ShapeletSim_TEST.csv
# Converted: UCRArchive_2018/DiatomSizeReduction/DiatomSizeReduction_TEST.tsv to data/DiatomSizeReduction_TEST.csv
# Converted: UCRArchive_2018/DiatomSizeReduction/DiatomSizeReduction_TRAIN.tsv to data/DiatomSizeReduction_TRAIN.csv
# Converted: UCRArchive_2018/InsectEPGRegularTrain/InsectEPGRegularTrain_TEST.tsv to data/InsectEPGRegularTrain_TEST.csv
# Converted: UCRArchive_2018/InsectEPGRegularTrain/InsectEPGRegularTrain_TRAIN.tsv to data/InsectEPGRegularTrain_TRAIN.csv
# Converted: UCRArchive_2018/Ham/Ham_TRAIN.tsv to data/Ham_TRAIN.csv
# Converted: UCRArchive_2018/Ham/Ham_TEST.tsv to data/Ham_TEST.csv
# Converted: UCRArchive_2018/DodgerLoopGame/DodgerLoopGame_TRAIN.tsv to data/DodgerLoopGame_TRAIN.csv
# Converted: UCRArchive_2018/DodgerLoopGame/DodgerLoopGame_TEST.tsv to data/DodgerLoopGame_TEST.csv
# Converted: UCRArchive_2018/GunPoint/GunPoint_TRAIN.tsv to data/GunPoint_TRAIN.csv
# Converted: UCRArchive_2018/GunPoint/GunPoint_TEST.tsv to data/GunPoint_TEST.csv
# Converted: UCRArchive_2018/ScreenType/ScreenType_TEST.tsv to data/ScreenType_TEST.csv
# Converted: UCRArchive_2018/ScreenType/ScreenType_TRAIN.tsv to data/ScreenType_TRAIN.csv
# Converted: UCRArchive_2018/HandOutlines/HandOutlines_TRAIN.tsv to data/HandOutlines_TRAIN.csv
# Converted: UCRArchive_2018/HandOutlines/HandOutlines_TEST.tsv to data/HandOutlines_TEST.csv
# Converted: UCRArchive_2018/Plane/Plane_TEST.tsv to data/Plane_TEST.csv
# Converted: UCRArchive_2018/Plane/Plane_TRAIN.tsv to data/Plane_TRAIN.csv
# Converted: UCRArchive_2018/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TEST.tsv to data/NonInvasiveFetalECGThorax2_TEST.csv
# Converted: UCRArchive_2018/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TRAIN.tsv to data/NonInvasiveFetalECGThorax2_TRAIN.csv
# Converted: UCRArchive_2018/SemgHandGenderCh2/SemgHandGenderCh2_TRAIN.tsv to data/SemgHandGenderCh2_TRAIN.csv
# Converted: UCRArchive_2018/SemgHandGenderCh2/SemgHandGenderCh2_TEST.tsv to data/SemgHandGenderCh2_TEST.csv
# Converted: UCRArchive_2018/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TRAIN.tsv to data/PhalangesOutlinesCorrect_TRAIN.csv
# Converted: UCRArchive_2018/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TEST.tsv to data/PhalangesOutlinesCorrect_TEST.csv
# Converted: UCRArchive_2018/PLAID/PLAID_TEST.tsv to data/PLAID_TEST.csv
# Converted: UCRArchive_2018/PLAID/PLAID_TRAIN.tsv to data/PLAID_TRAIN.csv
# Converted: UCRArchive_2018/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TEST.tsv to data/MiddlePhalanxOutlineCorrect_TEST.csv
# Converted: UCRArchive_2018/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TRAIN.tsv to data/MiddlePhalanxOutlineCorrect_TRAIN.csv
# Converted: UCRArchive_2018/ChlorineConcentration/ChlorineConcentration_TRAIN.tsv to data/ChlorineConcentration_TRAIN.csv
# Converted: UCRArchive_2018/ChlorineConcentration/ChlorineConcentration_TEST.tsv to data/ChlorineConcentration_TEST.csv
# Converted: UCRArchive_2018/WormsTwoClass/WormsTwoClass_TRAIN.tsv to data/WormsTwoClass_TRAIN.csv
# Converted: UCRArchive_2018/WormsTwoClass/WormsTwoClass_TEST.tsv to data/WormsTwoClass_TEST.csv
# Converted: UCRArchive_2018/MelbournePedestrian/MelbournePedestrian_TEST.tsv to data/MelbournePedestrian_TEST.csv
# Converted: UCRArchive_2018/MelbournePedestrian/MelbournePedestrian_TRAIN.tsv to data/MelbournePedestrian_TRAIN.csv
# Converted: UCRArchive_2018/ProximalPhalanxTW/ProximalPhalanxTW_TEST.tsv to data/ProximalPhalanxTW_TEST.csv
# Converted: UCRArchive_2018/ProximalPhalanxTW/ProximalPhalanxTW_TRAIN.tsv to data/ProximalPhalanxTW_TRAIN.csv
# Converted: UCRArchive_2018/CinCECGTorso/CinCECGTorso_TEST.tsv to data/CinCECGTorso_TEST.csv
# Converted: UCRArchive_2018/CinCECGTorso/CinCECGTorso_TRAIN.tsv to data/CinCECGTorso_TRAIN.csv
# Converted: UCRArchive_2018/PigAirwayPressure/PigAirwayPressure_TRAIN.tsv to data/PigAirwayPressure_TRAIN.csv
# Converted: UCRArchive_2018/PigAirwayPressure/PigAirwayPressure_TEST.tsv to data/PigAirwayPressure_TEST.csv
# Converted: UCRArchive_2018/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TRAIN.tsv to data/ShakeGestureWiimoteZ_TRAIN.csv
# Converted: UCRArchive_2018/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TEST.tsv to data/ShakeGestureWiimoteZ_TEST.csv
# Converted: UCRArchive_2018/FordA/FordA_TEST.tsv to data/FordA_TEST.csv
# Converted: UCRArchive_2018/FordA/FordA_TRAIN.tsv to data/FordA_TRAIN.csv
# Converted: UCRArchive_2018/CBF/CBF_TEST.tsv to data/CBF_TEST.csv
# Converted: UCRArchive_2018/CBF/CBF_TRAIN.tsv to data/CBF_TRAIN.csv
# Converted: UCRArchive_2018/GestureMidAirD2/GestureMidAirD2_TEST.tsv to data/GestureMidAirD2_TEST.csv
# Converted: UCRArchive_2018/GestureMidAirD2/GestureMidAirD2_TRAIN.tsv to data/GestureMidAirD2_TRAIN.csv
# Converted: UCRArchive_2018/Meat/Meat_TRAIN.tsv to data/Meat_TRAIN.csv
# Converted: UCRArchive_2018/Meat/Meat_TEST.tsv to data/Meat_TEST.csv
# Converted: UCRArchive_2018/GesturePebbleZ2/GesturePebbleZ2_TRAIN.tsv to data/GesturePebbleZ2_TRAIN.csv
# Converted: UCRArchive_2018/GesturePebbleZ2/GesturePebbleZ2_TEST.tsv to data/GesturePebbleZ2_TEST.csv
# Converted: UCRArchive_2018/FaceFour/FaceFour_TEST.tsv to data/FaceFour_TEST.csv
# Converted: UCRArchive_2018/FaceFour/FaceFour_TRAIN.tsv to data/FaceFour_TRAIN.csv
# Converted: UCRArchive_2018/StarLightCurves/StarLightCurves_TRAIN.tsv to data/StarLightCurves_TRAIN.csv
# Converted: UCRArchive_2018/StarLightCurves/StarLightCurves_TEST.tsv to data/StarLightCurves_TEST.csv
# Converted: UCRArchive_2018/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TEST.tsv to data/ProximalPhalanxOutlineCorrect_TEST.csv
# Converted: UCRArchive_2018/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TRAIN.tsv to data/ProximalPhalanxOutlineCorrect_TRAIN.csv
# Converted: UCRArchive_2018/BeetleFly/BeetleFly_TRAIN.tsv to data/BeetleFly_TRAIN.csv
# Converted: UCRArchive_2018/BeetleFly/BeetleFly_TEST.tsv to data/BeetleFly_TEST.csv
# Converted: UCRArchive_2018/FreezerRegularTrain/FreezerRegularTrain_TRAIN.tsv to data/FreezerRegularTrain_TRAIN.csv
# Converted: UCRArchive_2018/FreezerRegularTrain/FreezerRegularTrain_TEST.tsv to data/FreezerRegularTrain_TEST.csv
# Converted: UCRArchive_2018/Worms/Worms_TRAIN.tsv to data/Worms_TRAIN.csv
# Converted: UCRArchive_2018/Worms/Worms_TEST.tsv to data/Worms_TEST.csv
# Converted: UCRArchive_2018/Beef/Beef_TRAIN.tsv to data/Beef_TRAIN.csv
# Converted: UCRArchive_2018/Beef/Beef_TEST.tsv to data/Beef_TEST.csv
# Converted: UCRArchive_2018/SyntheticControl/SyntheticControl_TEST.tsv to data/SyntheticControl_TEST.csv
# Converted: UCRArchive_2018/SyntheticControl/SyntheticControl_TRAIN.tsv to data/SyntheticControl_TRAIN.csv
# Converted: UCRArchive_2018/Crop/Crop_TEST.tsv to data/Crop_TEST.csv
# Converted: UCRArchive_2018/Crop/Crop_TRAIN.tsv to data/Crop_TRAIN.csv
# Converted: UCRArchive_2018/PigArtPressure/PigArtPressure_TRAIN.tsv to data/PigArtPressure_TRAIN.csv
# Converted: UCRArchive_2018/PigArtPressure/PigArtPressure_TEST.tsv to data/PigArtPressure_TEST.csv
# Converted: UCRArchive_2018/GestureMidAirD1/GestureMidAirD1_TRAIN.tsv to data/GestureMidAirD1_TRAIN.csv
# Converted: UCRArchive_2018/GestureMidAirD1/GestureMidAirD1_TEST.tsv to data/GestureMidAirD1_TEST.csv
# Converted: UCRArchive_2018/DodgerLoopWeekend/DodgerLoopWeekend_TRAIN.tsv to data/DodgerLoopWeekend_TRAIN.csv
# Converted: UCRArchive_2018/DodgerLoopWeekend/DodgerLoopWeekend_TEST.tsv to data/DodgerLoopWeekend_TEST.csv
# Converted: UCRArchive_2018/ECG200/ECG200_TEST.tsv to data/ECG200_TEST.csv
# Converted: UCRArchive_2018/ECG200/ECG200_TRAIN.tsv to data/ECG200_TRAIN.csv
# Converted: UCRArchive_2018/PowerCons/PowerCons_TRAIN.tsv to data/PowerCons_TRAIN.csv
# Converted: UCRArchive_2018/PowerCons/PowerCons_TEST.tsv to data/PowerCons_TEST.csv
# Converted: UCRArchive_2018/CricketY/CricketY_TRAIN.tsv to data/CricketY_TRAIN.csv
# Converted: UCRArchive_2018/CricketY/CricketY_TEST.tsv to data/CricketY_TEST.csv
# Converted: UCRArchive_2018/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TRAIN.tsv to data/GunPointMaleVersusFemale_TRAIN.csv
# Converted: UCRArchive_2018/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TEST.tsv to data/GunPointMaleVersusFemale_TEST.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryX/UWaveGestureLibraryX_TEST.tsv to data/UWaveGestureLibraryX_TEST.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryX/UWaveGestureLibraryX_TRAIN.tsv to data/UWaveGestureLibraryX_TRAIN.csv
# Converted: UCRArchive_2018/MiddlePhalanxTW/MiddlePhalanxTW_TEST.tsv to data/MiddlePhalanxTW_TEST.csv
# Converted: UCRArchive_2018/MiddlePhalanxTW/MiddlePhalanxTW_TRAIN.tsv to data/MiddlePhalanxTW_TRAIN.csv
# Converted: UCRArchive_2018/Symbols/Symbols_TEST.tsv to data/Symbols_TEST.csv
# Converted: UCRArchive_2018/Symbols/Symbols_TRAIN.tsv to data/Symbols_TRAIN.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN.tsv to data/UWaveGestureLibraryAll_TRAIN.csv
# Converted: UCRArchive_2018/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TEST.tsv to data/UWaveGestureLibraryAll_TEST.csv
# Converted: UCRArchive_2018/ECGFiveDays/ECGFiveDays_TRAIN.tsv to data/ECGFiveDays_TRAIN.csv
# Converted: UCRArchive_2018/ECGFiveDays/ECGFiveDays_TEST.tsv to data/ECGFiveDays_TEST.csv
# Converted: UCRArchive_2018/OSULeaf/OSULeaf_TEST.tsv to data/OSULeaf_TEST.csv
# Converted: UCRArchive_2018/OSULeaf/OSULeaf_TRAIN.tsv to data/OSULeaf_TRAIN.csv
# Converted: UCRArchive_2018/SemgHandMovementCh2/SemgHandMovementCh2_TRAIN.tsv to data/SemgHandMovementCh2_TRAIN.csv
# Converted: UCRArchive_2018/SemgHandMovementCh2/SemgHandMovementCh2_TEST.tsv to data/SemgHandMovementCh2_TEST.csv
# Converted: UCRArchive_2018/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TEST.tsv to data/DistalPhalanxOutlineAgeGroup_TEST.csv
# Converted: UCRArchive_2018/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TRAIN.tsv to data/DistalPhalanxOutlineAgeGroup_TRAIN.csv
# Converted: UCRArchive_2018/PigCVP/PigCVP_TRAIN.tsv to data/PigCVP_TRAIN.csv
# Converted: UCRArchive_2018/PigCVP/PigCVP_TEST.tsv to data/PigCVP_TEST.csv
# Converted: UCRArchive_2018/AllGestureWiimoteY/AllGestureWiimoteY_TRAIN.tsv to data/AllGestureWiimoteY_TRAIN.csv
# Converted: UCRArchive_2018/AllGestureWiimoteY/AllGestureWiimoteY_TEST.tsv to data/AllGestureWiimoteY_TEST.csv
# Converted: UCRArchive_2018/SemgHandSubjectCh2/SemgHandSubjectCh2_TEST.tsv to data/SemgHandSubjectCh2_TEST.csv
# Converted: UCRArchive_2018/SemgHandSubjectCh2/SemgHandSubjectCh2_TRAIN.tsv to data/SemgHandSubjectCh2_TRAIN.csv
# Converted: UCRArchive_2018/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TEST.tsv to data/NonInvasiveFetalECGThorax1_TEST.csv
# Converted: UCRArchive_2018/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TRAIN.tsv to data/NonInvasiveFetalECGThorax1_TRAIN.csv
# Converted: UCRArchive_2018/Adiac/Adiac_TEST.tsv to data/Adiac_TEST.csv
# Converted: UCRArchive_2018/Adiac/Adiac_TRAIN.tsv to data/Adiac_TRAIN.csv
# Converted: UCRArchive_2018/FacesUCR/FacesUCR_TRAIN.tsv to data/FacesUCR_TRAIN.csv
# Converted: UCRArchive_2018/FacesUCR/FacesUCR_TEST.tsv to data/FacesUCR_TEST.csv
# Converted: UCRArchive_2018/EthanolLevel/EthanolLevel_TEST.tsv to data/EthanolLevel_TEST.csv
# Converted: UCRArchive_2018/EthanolLevel/EthanolLevel_TRAIN.tsv to data/EthanolLevel_TRAIN.csv
# Converted: UCRArchive_2018/Strawberry/Strawberry_TRAIN.tsv to data/Strawberry_TRAIN.csv
# Converted: UCRArchive_2018/Strawberry/Strawberry_TEST.tsv to data/Strawberry_TEST.csv
# Converted: UCRArchive_2018/ToeSegmentation2/ToeSegmentation2_TEST.tsv to data/ToeSegmentation2_TEST.csv
# Converted: UCRArchive_2018/ToeSegmentation2/ToeSegmentation2_TRAIN.tsv to data/ToeSegmentation2_TRAIN.csv
# Converted: UCRArchive_2018/FreezerSmallTrain/FreezerSmallTrain_TEST.tsv to data/FreezerSmallTrain_TEST.csv
# Converted: UCRArchive_2018/FreezerSmallTrain/FreezerSmallTrain_TRAIN.tsv to data/FreezerSmallTrain_TRAIN.csv
# Converted: UCRArchive_2018/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TRAIN.tsv to data/PickupGestureWiimoteZ_TRAIN.csv
# Converted: UCRArchive_2018/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TEST.tsv to data/PickupGestureWiimoteZ_TEST.csv
# Converted: UCRArchive_2018/Lightning2/Lightning2_TEST.tsv to data/Lightning2_TEST.csv
# Converted: UCRArchive_2018/Lightning2/Lightning2_TRAIN.tsv to data/Lightning2_TRAIN.csv
# Converted: UCRArchive_2018/GunPointAgeSpan/GunPointAgeSpan_TEST.tsv to data/GunPointAgeSpan_TEST.csv
# Converted: UCRArchive_2018/GunPointAgeSpan/GunPointAgeSpan_TRAIN.tsv to data/GunPointAgeSpan_TRAIN.csv
# Converted: UCRArchive_2018/ItalyPowerDemand/ItalyPowerDemand_TRAIN.tsv to data/ItalyPowerDemand_TRAIN.csv
# Converted: UCRArchive_2018/ItalyPowerDemand/ItalyPowerDemand_TEST.tsv to data/ItalyPowerDemand_TEST.csv
# Converted: UCRArchive_2018/Herring/Herring_TEST.tsv to data/Herring_TEST.csv
# Converted: UCRArchive_2018/Herring/Herring_TRAIN.tsv to data/Herring_TRAIN.csv
# Converted: UCRArchive_2018/AllGestureWiimoteZ/AllGestureWiimoteZ_TEST.tsv to data/AllGestureWiimoteZ_TEST.csv
# Converted: UCRArchive_2018/AllGestureWiimoteZ/AllGestureWiimoteZ_TRAIN.tsv to data/AllGestureWiimoteZ_TRAIN.csv
# Converted: UCRArchive_2018/Haptics/Haptics_TEST.tsv to data/Haptics_TEST.csv
# Converted: UCRArchive_2018/Haptics/Haptics_TRAIN.tsv to data/Haptics_TRAIN.csv
# Converted: UCRArchive_2018/TwoLeadECG/TwoLeadECG_TEST.tsv to data/TwoLeadECG_TEST.csv
# Converted: UCRArchive_2018/TwoLeadECG/TwoLeadECG_TRAIN.tsv to data/TwoLeadECG_TRAIN.csv
# Converted: UCRArchive_2018/ElectricDevices/ElectricDevices_TEST.tsv to data/ElectricDevices_TEST.csv
# Converted: UCRArchive_2018/ElectricDevices/ElectricDevices_TRAIN.tsv to data/ElectricDevices_TRAIN.csv
# Converted: UCRArchive_2018/BirdChicken/BirdChicken_TRAIN.tsv to data/BirdChicken_TRAIN.csv
# Converted: UCRArchive_2018/BirdChicken/BirdChicken_TEST.tsv to data/BirdChicken_TEST.csv
# Converted: UCRArchive_2018/EOGVerticalSignal/EOGVerticalSignal_TEST.tsv to data/EOGVerticalSignal_TEST.csv
# Converted: UCRArchive_2018/EOGVerticalSignal/EOGVerticalSignal_TRAIN.tsv to data/EOGVerticalSignal_TRAIN.csv
# Converted: UCRArchive_2018/GunPointOldVersusYoung/GunPointOldVersusYoung_TRAIN.tsv to data/GunPointOldVersusYoung_TRAIN.csv
# Converted: UCRArchive_2018/GunPointOldVersusYoung/GunPointOldVersusYoung_TEST.tsv to data/GunPointOldVersusYoung_TEST.csv
# Converted: UCRArchive_2018/ArrowHead/ArrowHead_TRAIN.tsv to data/ArrowHead_TRAIN.csv
# Converted: UCRArchive_2018/ArrowHead/ArrowHead_TEST.tsv to data/ArrowHead_TEST.csv
# Converted: UCRArchive_2018/MoteStrain/MoteStrain_TRAIN.tsv to data/MoteStrain_TRAIN.csv
# Converted: UCRArchive_2018/MoteStrain/MoteStrain_TEST.tsv to data/MoteStrain_TEST.csv
# Converted: UCRArchive_2018/WordSynonyms/WordSynonyms_TEST.tsv to data/WordSynonyms_TEST.csv
# Converted: UCRArchive_2018/WordSynonyms/WordSynonyms_TRAIN.tsv to data/WordSynonyms_TRAIN.csv
# Converted: UCRArchive_2018/Coffee/Coffee_TRAIN.tsv to data/Coffee_TRAIN.csv
# Converted: UCRArchive_2018/Coffee/Coffee_TEST.tsv to data/Coffee_TEST.csv
# Converted: UCRArchive_2018/LargeKitchenAppliances/LargeKitchenAppliances_TEST.tsv to data/LargeKitchenAppliances_TEST.csv
# Converted: UCRArchive_2018/LargeKitchenAppliances/LargeKitchenAppliances_TRAIN.tsv to data/LargeKitchenAppliances_TRAIN.csv
# Converted: UCRArchive_2018/HouseTwenty/HouseTwenty_TRAIN.tsv to data/HouseTwenty_TRAIN.csv
# Converted: UCRArchive_2018/HouseTwenty/HouseTwenty_TEST.tsv to data/HouseTwenty_TEST.csv
# Converted: UCRArchive_2018/GestureMidAirD3/GestureMidAirD3_TEST.tsv to data/GestureMidAirD3_TEST.csv
# Converted: UCRArchive_2018/GestureMidAirD3/GestureMidAirD3_TRAIN.tsv to data/GestureMidAirD3_TRAIN.csv
# Converted: UCRArchive_2018/Chinatown/Chinatown_TEST.tsv to data/Chinatown_TEST.csv
# Converted: UCRArchive_2018/Chinatown/Chinatown_TRAIN.tsv to data/Chinatown_TRAIN.csv
# Converted: UCRArchive_2018/MixedShapesSmallTrain/MixedShapesSmallTrain_TEST.tsv to data/MixedShapesSmallTrain_TEST.csv
# Converted: UCRArchive_2018/MixedShapesSmallTrain/MixedShapesSmallTrain_TRAIN.tsv to data/MixedShapesSmallTrain_TRAIN.csv
# Converted: UCRArchive_2018/EOGHorizontalSignal/EOGHorizontalSignal_TEST.tsv to data/EOGHorizontalSignal_TEST.csv
# Converted: UCRArchive_2018/EOGHorizontalSignal/EOGHorizontalSignal_TRAIN.tsv to data/EOGHorizontalSignal_TRAIN.csv
# Converted: UCRArchive_2018/Yoga/Yoga_TEST.tsv to data/Yoga_TEST.csv
# Converted: UCRArchive_2018/Yoga/Yoga_TRAIN.tsv to data/Yoga_TRAIN.csv
# All files have been converted and saved.

# %%
##########
# you can skip the ABOVE steps if you already have
# UCRArchive_2018.zip, UCRArchive_2018 folder, data folder containing csv 
# and directly proceed to load dataset name and train data
#########

# %%
# we store all the 128 datasets' name in a list in alphabetic order
ucr_dir = './data'  # Path to UCR dataset directory
dataset_names = [f.split('_')[0] for f in os.listdir(ucr_dir) if f.endswith('_TRAIN.csv')]
dataset_names = sorted(dataset_names, key=str.lower)
print(dataset_names)
# Out:
# ['ACSF1', 'Adiac', 'AllGestureWiimoteX', 'AllGestureWiimoteY', 'AllGestureWiimoteZ', 'ArrowHead', 'Beef', 'BeetleFly', 'BirdChicken', 'BME', 'Car', 'CBF', 'Chinatown', 'ChlorineConcentration', 'CinCECGTorso', 'Coffee', 'Computers', 'CricketX', 'CricketY', 'CricketZ', 'Crop', 'DiatomSizeReduction', 'DistalPhalanxOutlineAgeGroup', 'DistalPhalanxOutlineCorrect', 'DistalPhalanxTW', 'DodgerLoopDay', 'DodgerLoopGame', 'DodgerLoopWeekend', 'Earthquakes', 'ECG200', 'ECG5000', 'ECGFiveDays', 'ElectricDevices', 'EOGHorizontalSignal', 'EOGVerticalSignal', 'EthanolLevel', 'FaceAll', 'FaceFour', 'FacesUCR', 'FiftyWords', 'Fish', 'FordA', 'FordB', 'FreezerRegularTrain', 'FreezerSmallTrain', 'Fungi', 'GestureMidAirD1', 'GestureMidAirD2', 'GestureMidAirD3', 'GesturePebbleZ1', 'GesturePebbleZ2', 'GunPoint', 'GunPointAgeSpan', 'GunPointMaleVersusFemale', 'GunPointOldVersusYoung', 'Ham', 'HandOutlines', 'Haptics', 'Herring', 'HouseTwenty', 'InlineSkate', 'InsectEPGRegularTrain', 'InsectEPGSmallTrain', 'InsectWingbeatSound', 'ItalyPowerDemand', 'LargeKitchenAppliances', 'Lightning2', 'Lightning7', 'Mallat', 'Meat', 'MedicalImages', 'MelbournePedestrian', 'MiddlePhalanxOutlineAgeGroup', 'MiddlePhalanxOutlineCorrect', 'MiddlePhalanxTW', 'MixedShapesRegularTrain', 'MixedShapesSmallTrain', 'MoteStrain', 'NonInvasiveFetalECGThorax1', 'NonInvasiveFetalECGThorax2', 'OliveOil', 'OSULeaf', 'PhalangesOutlinesCorrect', 'Phoneme', 'PickupGestureWiimoteZ', 'PigAirwayPressure', 'PigArtPressure', 'PigCVP', 'PLAID', 'Plane', 'PowerCons', 'ProximalPhalanxOutlineAgeGroup', 'ProximalPhalanxOutlineCorrect', 'ProximalPhalanxTW', 'RefrigerationDevices', 'Rock', 'ScreenType', 'SemgHandGenderCh2', 'SemgHandMovementCh2', 'SemgHandSubjectCh2', 'ShakeGestureWiimoteZ', 'ShapeletSim', 'ShapesAll', 'SmallKitchenAppliances', 'SmoothSubspace', 'SonyAIBORobotSurface1', 'SonyAIBORobotSurface2', 'StarLightCurves', 'Strawberry', 'SwedishLeaf', 'Symbols', 'SyntheticControl', 'ToeSegmentation1', 'ToeSegmentation2', 'Trace', 'TwoLeadECG', 'TwoPatterns', 'UMD', 'UWaveGestureLibraryAll', 'UWaveGestureLibraryX', 'UWaveGestureLibraryY', 'UWaveGestureLibraryZ', 'Wafer', 'Wine', 'WordSynonyms', 'Worms', 'WormsTwoClass', 'Yoga']

# %%
# 1st train: SELECT number of cells for each model and train 2000 epochs
#train_lstm_fcn model uses load_ucr_dataset(), build_lstm_fcn() and build_alstm_fcn() in it

#parameters used for training
num_cells_range = [8, 64, 128]
model_name = 'LSTM' #LSTM or ALSTM
ucr_dir = "./data"  #data folder location
epochs = 200
batch_size = 128
file_path = f"{model_name}_train_best_cell.csv"

# %%
##### NOTE: for your convinience, our output csv is directly saved in a safe location.
##### the code also output .keras models but they are useless, 
##### since we are searching hyperparameters not really training
##### so we didn't upload models output of this code!
##### running the cell would create a csv and a models folder to save the output.
##### keras models is saved once 1 dataset is down training;
##### for csv, you will have to wait until all 128 datasets processed to see a complete one.
##### ↑you will have to wait super long for the csv, 90 mins for LSTM and 120 mins for ALSTM :<

all_results = {}
# iterate through 128 datasets and train
for dataset_name in dataset_names:
    print(f"Training on dataset: {dataset_name}")
    best_num_cells, best_accuracy, best_loss,results, best_model_paths=train_lstm_fcn(model_name,
                                                                                      dataset_name,
                                                                                      ucr_dir,
                                                                                      num_cells_range,
                                                                                      epochs=epochs,
                                                                                      batch_size = batch_size,
                                                                                     verbose = 0)
    all_results[dataset_name] = {
        "dataset_name" : dataset_name,
        "best_num_cells" : best_num_cells,
        "accuracy": best_accuracy,
        "loss": best_loss,
        "best_model_paths":best_model_paths
    }
    
    # append best result to a csv at the current location once the current dataset have done 
    save_best_result(file_path, all_results[dataset_name])
# Out:
# Training on dataset: ACSF1
# Training ACSF1 with num_cells = 8
# dname = ACSF1, num_cells = 8, Test Accuracy = 0.3300, Test Loss = 2.0267
# Training ACSF1 with num_cells = 64
# dname = ACSF1, num_cells = 64, Test Accuracy = 0.3500, Test Loss = 1.7491
# Training ACSF1 with num_cells = 128
# dname = ACSF1, num_cells = 128, Test Accuracy = 0.1700, Test Loss = 2.4931
# BEST: dname = ACSF1, Best num_cells: 64, Test Accuracy: 0.3500, Test Loss: 1.7491
# ACSF1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Adiac
# Training Adiac with num_cells = 8
# dname = Adiac, num_cells = 8, Test Accuracy = 0.2353, Test Loss = 4.5505
# Training Adiac with num_cells = 64
# dname = Adiac, num_cells = 64, Test Accuracy = 0.1688, Test Loss = 7.7038
# Training Adiac with num_cells = 128
# dname = Adiac, num_cells = 128, Test Accuracy = 0.2916, Test Loss = 3.8689
# BEST: dname = Adiac, Best num_cells: 128, Test Accuracy: 0.2916, Test Loss: 3.8689
# Adiac best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: AllGestureWiimoteX
# Training AllGestureWiimoteX with num_cells = 8
# dname = AllGestureWiimoteX, num_cells = 8, Test Accuracy = 0.1357, Test Loss = 10.0654
# Training AllGestureWiimoteX with num_cells = 64
# dname = AllGestureWiimoteX, num_cells = 64, Test Accuracy = 0.1157, Test Loss = 10.7746
# Training AllGestureWiimoteX with num_cells = 128
# dname = AllGestureWiimoteX, num_cells = 128, Test Accuracy = 0.1114, Test Loss = 7.9836
# BEST: dname = AllGestureWiimoteX, Best num_cells: 8, Test Accuracy: 0.1357, Test Loss: 10.0654
# AllGestureWiimoteX best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: AllGestureWiimoteY
# Training AllGestureWiimoteY with num_cells = 8
# dname = AllGestureWiimoteY, num_cells = 8, Test Accuracy = 0.1200, Test Loss = 8.4388
# Training AllGestureWiimoteY with num_cells = 64
# dname = AllGestureWiimoteY, num_cells = 64, Test Accuracy = 0.1129, Test Loss = 8.3081
# Training AllGestureWiimoteY with num_cells = 128
# dname = AllGestureWiimoteY, num_cells = 128, Test Accuracy = 0.1114, Test Loss = 7.6195
# BEST: dname = AllGestureWiimoteY, Best num_cells: 8, Test Accuracy: 0.1200, Test Loss: 8.4388
# AllGestureWiimoteY best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: AllGestureWiimoteZ
# Training AllGestureWiimoteZ with num_cells = 8
# dname = AllGestureWiimoteZ, num_cells = 8, Test Accuracy = 0.3571, Test Loss = 2.9666
# Training AllGestureWiimoteZ with num_cells = 64
# dname = AllGestureWiimoteZ, num_cells = 64, Test Accuracy = 0.2186, Test Loss = 3.5367
# Training AllGestureWiimoteZ with num_cells = 128
# dname = AllGestureWiimoteZ, num_cells = 128, Test Accuracy = 0.3257, Test Loss = 3.4845
# BEST: dname = AllGestureWiimoteZ, Best num_cells: 8, Test Accuracy: 0.3571, Test Loss: 2.9666
# AllGestureWiimoteZ best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ArrowHead
# Training ArrowHead with num_cells = 8
# dname = ArrowHead, num_cells = 8, Test Accuracy = 0.6514, Test Loss = 0.9427
# Training ArrowHead with num_cells = 64
# dname = ArrowHead, num_cells = 64, Test Accuracy = 0.6686, Test Loss = 1.0336
# Training ArrowHead with num_cells = 128
# dname = ArrowHead, num_cells = 128, Test Accuracy = 0.6800, Test Loss = 0.8034
# BEST: dname = ArrowHead, Best num_cells: 128, Test Accuracy: 0.6800, Test Loss: 0.8034
# ArrowHead best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Beef
# Training Beef with num_cells = 8
# dname = Beef, num_cells = 8, Test Accuracy = 0.5333, Test Loss = 0.9202
# Training Beef with num_cells = 64
# dname = Beef, num_cells = 64, Test Accuracy = 0.6000, Test Loss = 0.9241
# Training Beef with num_cells = 128
# dname = Beef, num_cells = 128, Test Accuracy = 0.6333, Test Loss = 0.9674
# BEST: dname = Beef, Best num_cells: 128, Test Accuracy: 0.6333, Test Loss: 0.9674
# Beef best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: BeetleFly
# Training BeetleFly with num_cells = 8
# dname = BeetleFly, num_cells = 8, Test Accuracy = 0.8000, Test Loss = 0.5127
# Training BeetleFly with num_cells = 64
# dname = BeetleFly, num_cells = 64, Test Accuracy = 0.8500, Test Loss = 0.3914
# Training BeetleFly with num_cells = 128
# dname = BeetleFly, num_cells = 128, Test Accuracy = 0.9000, Test Loss = 0.3728
# BEST: dname = BeetleFly, Best num_cells: 128, Test Accuracy: 0.9000, Test Loss: 0.3728
# BeetleFly best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: BirdChicken
# Training BirdChicken with num_cells = 8
# dname = BirdChicken, num_cells = 8, Test Accuracy = 0.7500, Test Loss = 0.6657
# Training BirdChicken with num_cells = 64
# dname = BirdChicken, num_cells = 64, Test Accuracy = 0.5500, Test Loss = 0.7975
# Training BirdChicken with num_cells = 128
# dname = BirdChicken, num_cells = 128, Test Accuracy = 0.6500, Test Loss = 0.8358
# BEST: dname = BirdChicken, Best num_cells: 8, Test Accuracy: 0.7500, Test Loss: 0.6657
# BirdChicken best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: BME
# Training BME with num_cells = 8
# dname = BME, num_cells = 8, Test Accuracy = 0.8133, Test Loss = 0.5873
# Training BME with num_cells = 64
# dname = BME, num_cells = 64, Test Accuracy = 0.8667, Test Loss = 0.3252
# Training BME with num_cells = 128
# dname = BME, num_cells = 128, Test Accuracy = 0.8067, Test Loss = 0.4899
# BEST: dname = BME, Best num_cells: 64, Test Accuracy: 0.8667, Test Loss: 0.3252
# BME best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Car
# Training Car with num_cells = 8
# dname = Car, num_cells = 8, Test Accuracy = 0.7000, Test Loss = 0.9994
# Training Car with num_cells = 64
# dname = Car, num_cells = 64, Test Accuracy = 0.6667, Test Loss = 1.0358
# Training Car with num_cells = 128
# dname = Car, num_cells = 128, Test Accuracy = 0.7667, Test Loss = 1.0094
# BEST: dname = Car, Best num_cells: 128, Test Accuracy: 0.7667, Test Loss: 1.0094
# Car best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: CBF
# Training CBF with num_cells = 8
# dname = CBF, num_cells = 8, Test Accuracy = 0.7400, Test Loss = 0.5695
# Training CBF with num_cells = 64
# dname = CBF, num_cells = 64, Test Accuracy = 0.7433, Test Loss = 0.5685
# Training CBF with num_cells = 128
# dname = CBF, num_cells = 128, Test Accuracy = 0.8500, Test Loss = 0.3407
# BEST: dname = CBF, Best num_cells: 128, Test Accuracy: 0.8500, Test Loss: 0.3407
# CBF best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Chinatown
# Training Chinatown with num_cells = 8
# dname = Chinatown, num_cells = 8, Test Accuracy = 0.8163, Test Loss = 0.3015
# Training Chinatown with num_cells = 64
# dname = Chinatown, num_cells = 64, Test Accuracy = 0.8805, Test Loss = 0.2381
# Training Chinatown with num_cells = 128
# dname = Chinatown, num_cells = 128, Test Accuracy = 0.8950, Test Loss = 0.2781
# BEST: dname = Chinatown, Best num_cells: 128, Test Accuracy: 0.8950, Test Loss: 0.2781
# Chinatown best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ChlorineConcentration
# Training ChlorineConcentration with num_cells = 8
# dname = ChlorineConcentration, num_cells = 8, Test Accuracy = 0.8911, Test Loss = 0.4234
# Training ChlorineConcentration with num_cells = 64
# dname = ChlorineConcentration, num_cells = 64, Test Accuracy = 0.8909, Test Loss = 0.4139
# Training ChlorineConcentration with num_cells = 128
# dname = ChlorineConcentration, num_cells = 128, Test Accuracy = 0.8896, Test Loss = 0.5497
# BEST: dname = ChlorineConcentration, Best num_cells: 8, Test Accuracy: 0.8911, Test Loss: 0.4234
# ChlorineConcentration best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: CinCECGTorso
# Training CinCECGTorso with num_cells = 8
# dname = CinCECGTorso, num_cells = 8, Test Accuracy = 0.7819, Test Loss = 0.6978
# Training CinCECGTorso with num_cells = 64
# dname = CinCECGTorso, num_cells = 64, Test Accuracy = 0.8471, Test Loss = 0.4548
# Training CinCECGTorso with num_cells = 128
# dname = CinCECGTorso, num_cells = 128, Test Accuracy = 0.8391, Test Loss = 0.5320
# BEST: dname = CinCECGTorso, Best num_cells: 64, Test Accuracy: 0.8471, Test Loss: 0.4548
# CinCECGTorso best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Coffee
# Training Coffee with num_cells = 8
# dname = Coffee, num_cells = 8, Test Accuracy = 0.9643, Test Loss = 0.1874
# Training Coffee with num_cells = 64
# dname = Coffee, num_cells = 64, Test Accuracy = 0.9643, Test Loss = 0.1544
# Training Coffee with num_cells = 128
# dname = Coffee, num_cells = 128, Test Accuracy = 1.0000, Test Loss = 0.1215
# BEST: dname = Coffee, Best num_cells: 128, Test Accuracy: 1.0000, Test Loss: 0.1215
# Coffee best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Computers
# Training Computers with num_cells = 8
# dname = Computers, num_cells = 8, Test Accuracy = 0.5440, Test Loss = 1.7890
# Training Computers with num_cells = 64
# dname = Computers, num_cells = 64, Test Accuracy = 0.5400, Test Loss = 1.8799
# Training Computers with num_cells = 128
# dname = Computers, num_cells = 128, Test Accuracy = 0.5400, Test Loss = 1.8735
# BEST: dname = Computers, Best num_cells: 8, Test Accuracy: 0.5440, Test Loss: 1.7890
# Computers best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: CricketX
# Training CricketX with num_cells = 8
# dname = CricketX, num_cells = 8, Test Accuracy = 0.5077, Test Loss = 2.1209
# Training CricketX with num_cells = 64
# dname = CricketX, num_cells = 64, Test Accuracy = 0.5051, Test Loss = 2.0964
# Training CricketX with num_cells = 128
# dname = CricketX, num_cells = 128, Test Accuracy = 0.5026, Test Loss = 2.1947
# BEST: dname = CricketX, Best num_cells: 8, Test Accuracy: 0.5077, Test Loss: 2.1209
# CricketX best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: CricketY
# Training CricketY with num_cells = 8
# dname = CricketY, num_cells = 8, Test Accuracy = 0.5487, Test Loss = 1.8002
# Training CricketY with num_cells = 64
# dname = CricketY, num_cells = 64, Test Accuracy = 0.5333, Test Loss = 1.7841
# Training CricketY with num_cells = 128
# dname = CricketY, num_cells = 128, Test Accuracy = 0.5282, Test Loss = 1.9504
# BEST: dname = CricketY, Best num_cells: 8, Test Accuracy: 0.5487, Test Loss: 1.8002
# CricketY best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: CricketZ
# Training CricketZ with num_cells = 8
# dname = CricketZ, num_cells = 8, Test Accuracy = 0.4897, Test Loss = 2.0050
# Training CricketZ with num_cells = 64
# dname = CricketZ, num_cells = 64, Test Accuracy = 0.5026, Test Loss = 2.1093
# Training CricketZ with num_cells = 128
# dname = CricketZ, num_cells = 128, Test Accuracy = 0.5282, Test Loss = 2.0964
# BEST: dname = CricketZ, Best num_cells: 128, Test Accuracy: 0.5282, Test Loss: 2.0964
# CricketZ best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Crop
# Training Crop with num_cells = 8
# dname = Crop, num_cells = 8, Test Accuracy = 0.7452, Test Loss = 1.8271
# Training Crop with num_cells = 64
# dname = Crop, num_cells = 64, Test Accuracy = 0.7374, Test Loss = 1.8827
# Training Crop with num_cells = 128
# dname = Crop, num_cells = 128, Test Accuracy = 0.7392, Test Loss = 1.9085
# BEST: dname = Crop, Best num_cells: 8, Test Accuracy: 0.7452, Test Loss: 1.8271
# Crop best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DiatomSizeReduction
# Training DiatomSizeReduction with num_cells = 8
# dname = DiatomSizeReduction, num_cells = 8, Test Accuracy = 0.8660, Test Loss = 0.5752
# Training DiatomSizeReduction with num_cells = 64
# dname = DiatomSizeReduction, num_cells = 64, Test Accuracy = 0.6275, Test Loss = 0.8731
# Training DiatomSizeReduction with num_cells = 128
# dname = DiatomSizeReduction, num_cells = 128, Test Accuracy = 0.7908, Test Loss = 0.7131
# BEST: dname = DiatomSizeReduction, Best num_cells: 8, Test Accuracy: 0.8660, Test Loss: 0.5752
# DiatomSizeReduction best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DistalPhalanxOutlineAgeGroup
# Training DistalPhalanxOutlineAgeGroup with num_cells = 8
# dname = DistalPhalanxOutlineAgeGroup, num_cells = 8, Test Accuracy = 0.5755, Test Loss = 2.2381
# Training DistalPhalanxOutlineAgeGroup with num_cells = 64
# dname = DistalPhalanxOutlineAgeGroup, num_cells = 64, Test Accuracy = 0.6259, Test Loss = 2.1391
# Training DistalPhalanxOutlineAgeGroup with num_cells = 128
# dname = DistalPhalanxOutlineAgeGroup, num_cells = 128, Test Accuracy = 0.6835, Test Loss = 1.5646
# BEST: dname = DistalPhalanxOutlineAgeGroup, Best num_cells: 128, Test Accuracy: 0.6835, Test Loss: 1.5646
# DistalPhalanxOutlineAgeGroup best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DistalPhalanxOutlineCorrect
# Training DistalPhalanxOutlineCorrect with num_cells = 8
# dname = DistalPhalanxOutlineCorrect, num_cells = 8, Test Accuracy = 0.7174, Test Loss = 1.5940
# Training DistalPhalanxOutlineCorrect with num_cells = 64
# dname = DistalPhalanxOutlineCorrect, num_cells = 64, Test Accuracy = 0.6703, Test Loss = 1.6019
# Training DistalPhalanxOutlineCorrect with num_cells = 128
# dname = DistalPhalanxOutlineCorrect, num_cells = 128, Test Accuracy = 0.7464, Test Loss = 1.5300
# BEST: dname = DistalPhalanxOutlineCorrect, Best num_cells: 128, Test Accuracy: 0.7464, Test Loss: 1.5300
# DistalPhalanxOutlineCorrect best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DistalPhalanxTW
# Training DistalPhalanxTW with num_cells = 8
# dname = DistalPhalanxTW, num_cells = 8, Test Accuracy = 0.5396, Test Loss = 3.0748
# Training DistalPhalanxTW with num_cells = 64
# dname = DistalPhalanxTW, num_cells = 64, Test Accuracy = 0.5252, Test Loss = 3.2205
# Training DistalPhalanxTW with num_cells = 128
# dname = DistalPhalanxTW, num_cells = 128, Test Accuracy = 0.4317, Test Loss = 2.4819
# BEST: dname = DistalPhalanxTW, Best num_cells: 8, Test Accuracy: 0.5396, Test Loss: 3.0748
# DistalPhalanxTW best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DodgerLoopDay
# Training DodgerLoopDay with num_cells = 8
# dname = DodgerLoopDay, num_cells = 8, Test Accuracy = 0.5250, Test Loss = 1.3339
# Training DodgerLoopDay with num_cells = 64
# dname = DodgerLoopDay, num_cells = 64, Test Accuracy = 0.4750, Test Loss = 1.3085
# Training DodgerLoopDay with num_cells = 128
# dname = DodgerLoopDay, num_cells = 128, Test Accuracy = 0.6250, Test Loss = 1.1033
# BEST: dname = DodgerLoopDay, Best num_cells: 128, Test Accuracy: 0.6250, Test Loss: 1.1033
# DodgerLoopDay best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DodgerLoopGame
# Training DodgerLoopGame with num_cells = 8
# dname = DodgerLoopGame, num_cells = 8, Test Accuracy = 0.8913, Test Loss = 0.3133
# Training DodgerLoopGame with num_cells = 64
# dname = DodgerLoopGame, num_cells = 64, Test Accuracy = 0.8551, Test Loss = 0.3911
# Training DodgerLoopGame with num_cells = 128
# dname = DodgerLoopGame, num_cells = 128, Test Accuracy = 0.8768, Test Loss = 0.3487
# BEST: dname = DodgerLoopGame, Best num_cells: 8, Test Accuracy: 0.8913, Test Loss: 0.3133
# DodgerLoopGame best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: DodgerLoopWeekend
# Training DodgerLoopWeekend with num_cells = 8
# dname = DodgerLoopWeekend, num_cells = 8, Test Accuracy = 0.9855, Test Loss = 0.0861
# Training DodgerLoopWeekend with num_cells = 64
# dname = DodgerLoopWeekend, num_cells = 64, Test Accuracy = 0.9855, Test Loss = 0.0776
# Training DodgerLoopWeekend with num_cells = 128
# dname = DodgerLoopWeekend, num_cells = 128, Test Accuracy = 0.9783, Test Loss = 0.0867
# BEST: dname = DodgerLoopWeekend, Best num_cells: 8, Test Accuracy: 0.9855, Test Loss: 0.0861
# DodgerLoopWeekend best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Earthquakes
# Training Earthquakes with num_cells = 8
# dname = Earthquakes, num_cells = 8, Test Accuracy = 0.7266, Test Loss = 1.1181
# Training Earthquakes with num_cells = 64
# dname = Earthquakes, num_cells = 64, Test Accuracy = 0.6691, Test Loss = 1.2922
# Training Earthquakes with num_cells = 128
# dname = Earthquakes, num_cells = 128, Test Accuracy = 0.7050, Test Loss = 1.0589
# BEST: dname = Earthquakes, Best num_cells: 8, Test Accuracy: 0.7266, Test Loss: 1.1181
# Earthquakes best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ECG200
# Training ECG200 with num_cells = 8
# dname = ECG200, num_cells = 8, Test Accuracy = 0.9000, Test Loss = 0.2558
# Training ECG200 with num_cells = 64
# dname = ECG200, num_cells = 64, Test Accuracy = 0.8800, Test Loss = 0.2960
# Training ECG200 with num_cells = 128
# dname = ECG200, num_cells = 128, Test Accuracy = 0.8400, Test Loss = 0.3859
# BEST: dname = ECG200, Best num_cells: 8, Test Accuracy: 0.9000, Test Loss: 0.2558
# ECG200 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ECG5000
# Training ECG5000 with num_cells = 8
# dname = ECG5000, num_cells = 8, Test Accuracy = 0.9336, Test Loss = 0.4012
# Training ECG5000 with num_cells = 64
# dname = ECG5000, num_cells = 64, Test Accuracy = 0.9302, Test Loss = 0.3859
# Training ECG5000 with num_cells = 128
# dname = ECG5000, num_cells = 128, Test Accuracy = 0.9300, Test Loss = 0.4539
# BEST: dname = ECG5000, Best num_cells: 8, Test Accuracy: 0.9336, Test Loss: 0.4012
# ECG5000 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ECGFiveDays
# Training ECGFiveDays with num_cells = 8
# dname = ECGFiveDays, num_cells = 8, Test Accuracy = 0.8804, Test Loss = 0.2292
# Training ECGFiveDays with num_cells = 64
# dname = ECGFiveDays, num_cells = 64, Test Accuracy = 0.8792, Test Loss = 0.2634
# Training ECGFiveDays with num_cells = 128
# dname = ECGFiveDays, num_cells = 128, Test Accuracy = 0.8885, Test Loss = 0.2417
# BEST: dname = ECGFiveDays, Best num_cells: 128, Test Accuracy: 0.8885, Test Loss: 0.2417
# ECGFiveDays best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ElectricDevices
# Training ElectricDevices with num_cells = 8
# dname = ElectricDevices, num_cells = 8, Test Accuracy = 0.5361, Test Loss = 5.1244
# Training ElectricDevices with num_cells = 64
# dname = ElectricDevices, num_cells = 64, Test Accuracy = 0.5395, Test Loss = 5.0897
# Training ElectricDevices with num_cells = 128
# dname = ElectricDevices, num_cells = 128, Test Accuracy = 0.5247, Test Loss = 5.5814
# BEST: dname = ElectricDevices, Best num_cells: 64, Test Accuracy: 0.5395, Test Loss: 5.0897
# ElectricDevices best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: EOGHorizontalSignal
# Training EOGHorizontalSignal with num_cells = 8
# dname = EOGHorizontalSignal, num_cells = 8, Test Accuracy = 0.4530, Test Loss = 3.1023
# Training EOGHorizontalSignal with num_cells = 64
# dname = EOGHorizontalSignal, num_cells = 64, Test Accuracy = 0.4392, Test Loss = 2.9652
# Training EOGHorizontalSignal with num_cells = 128
# dname = EOGHorizontalSignal, num_cells = 128, Test Accuracy = 0.4033, Test Loss = 3.1823
# BEST: dname = EOGHorizontalSignal, Best num_cells: 8, Test Accuracy: 0.4530, Test Loss: 3.1023
# EOGHorizontalSignal best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: EOGVerticalSignal
# Training EOGVerticalSignal with num_cells = 8
# dname = EOGVerticalSignal, num_cells = 8, Test Accuracy = 0.4392, Test Loss = 3.5753
# Training EOGVerticalSignal with num_cells = 64
# dname = EOGVerticalSignal, num_cells = 64, Test Accuracy = 0.3757, Test Loss = 4.0595
# Training EOGVerticalSignal with num_cells = 128
# dname = EOGVerticalSignal, num_cells = 128, Test Accuracy = 0.3729, Test Loss = 4.5341
# BEST: dname = EOGVerticalSignal, Best num_cells: 8, Test Accuracy: 0.4392, Test Loss: 3.5753
# EOGVerticalSignal best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: EthanolLevel
# Training EthanolLevel with num_cells = 8
# dname = EthanolLevel, num_cells = 8, Test Accuracy = 0.3220, Test Loss = 12.1082
# Training EthanolLevel with num_cells = 64
# dname = EthanolLevel, num_cells = 64, Test Accuracy = 0.4200, Test Loss = 5.7644
# Training EthanolLevel with num_cells = 128
# dname = EthanolLevel, num_cells = 128, Test Accuracy = 0.2500, Test Loss = 14.2730
# BEST: dname = EthanolLevel, Best num_cells: 64, Test Accuracy: 0.4200, Test Loss: 5.7644
# EthanolLevel best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FaceAll
# Training FaceAll with num_cells = 8
# dname = FaceAll, num_cells = 8, Test Accuracy = 0.8657, Test Loss = 0.5391
# Training FaceAll with num_cells = 64
# dname = FaceAll, num_cells = 64, Test Accuracy = 0.8331, Test Loss = 0.6114
# Training FaceAll with num_cells = 128
# dname = FaceAll, num_cells = 128, Test Accuracy = 0.8467, Test Loss = 0.5776
# BEST: dname = FaceAll, Best num_cells: 8, Test Accuracy: 0.8657, Test Loss: 0.5391
# FaceAll best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FaceFour
# Training FaceFour with num_cells = 8
# dname = FaceFour, num_cells = 8, Test Accuracy = 0.8295, Test Loss = 0.4474
# Training FaceFour with num_cells = 64
# dname = FaceFour, num_cells = 64, Test Accuracy = 0.8295, Test Loss = 0.5056
# Training FaceFour with num_cells = 128
# dname = FaceFour, num_cells = 128, Test Accuracy = 0.8295, Test Loss = 0.5883
# BEST: dname = FaceFour, Best num_cells: 8, Test Accuracy: 0.8295, Test Loss: 0.4474
# FaceFour best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FacesUCR
# Training FacesUCR with num_cells = 8
# dname = FacesUCR, num_cells = 8, Test Accuracy = 0.7941, Test Loss = 0.7965
# Training FacesUCR with num_cells = 64
# dname = FacesUCR, num_cells = 64, Test Accuracy = 0.7980, Test Loss = 0.7277
# Training FacesUCR with num_cells = 128
# dname = FacesUCR, num_cells = 128, Test Accuracy = 0.7927, Test Loss = 0.7907
# BEST: dname = FacesUCR, Best num_cells: 64, Test Accuracy: 0.7980, Test Loss: 0.7277
# FacesUCR best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FiftyWords
# Training FiftyWords with num_cells = 8
# dname = FiftyWords, num_cells = 8, Test Accuracy = 0.6637, Test Loss = 1.6005
# Training FiftyWords with num_cells = 64
# dname = FiftyWords, num_cells = 64, Test Accuracy = 0.6659, Test Loss = 1.7003
# Training FiftyWords with num_cells = 128
# dname = FiftyWords, num_cells = 128, Test Accuracy = 0.6725, Test Loss = 1.5962
# BEST: dname = FiftyWords, Best num_cells: 128, Test Accuracy: 0.6725, Test Loss: 1.5962
# FiftyWords best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Fish
# Training Fish with num_cells = 8
# dname = Fish, num_cells = 8, Test Accuracy = 0.8571, Test Loss = 0.4045
# Training Fish with num_cells = 64
# dname = Fish, num_cells = 64, Test Accuracy = 0.8857, Test Loss = 0.3738
# Training Fish with num_cells = 128
# dname = Fish, num_cells = 128, Test Accuracy = 0.8286, Test Loss = 0.6308
# BEST: dname = Fish, Best num_cells: 64, Test Accuracy: 0.8857, Test Loss: 0.3738
# Fish best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FordA
# Training FordA with num_cells = 8
# dname = FordA, num_cells = 8, Test Accuracy = 0.7856, Test Loss = 1.0234
# Training FordA with num_cells = 64
# dname = FordA, num_cells = 64, Test Accuracy = 0.7765, Test Loss = 1.1660
# Training FordA with num_cells = 128
# dname = FordA, num_cells = 128, Test Accuracy = 0.7871, Test Loss = 1.1862
# BEST: dname = FordA, Best num_cells: 128, Test Accuracy: 0.7871, Test Loss: 1.1862
# FordA best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FordB
# Training FordB with num_cells = 8
# dname = FordB, num_cells = 8, Test Accuracy = 0.7012, Test Loss = 1.7312
# Training FordB with num_cells = 64
# dname = FordB, num_cells = 64, Test Accuracy = 0.7049, Test Loss = 2.0047
# Training FordB with num_cells = 128
# dname = FordB, num_cells = 128, Test Accuracy = 0.7062, Test Loss = 1.4581
# BEST: dname = FordB, Best num_cells: 128, Test Accuracy: 0.7062, Test Loss: 1.4581
# FordB best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FreezerRegularTrain
# Training FreezerRegularTrain with num_cells = 8
# dname = FreezerRegularTrain, num_cells = 8, Test Accuracy = 0.6253, Test Loss = 1.0414
# Training FreezerRegularTrain with num_cells = 64
# dname = FreezerRegularTrain, num_cells = 64, Test Accuracy = 0.7737, Test Loss = 1.2763
# Training FreezerRegularTrain with num_cells = 128
# dname = FreezerRegularTrain, num_cells = 128, Test Accuracy = 0.9312, Test Loss = 0.3067
# BEST: dname = FreezerRegularTrain, Best num_cells: 128, Test Accuracy: 0.9312, Test Loss: 0.3067
# FreezerRegularTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: FreezerSmallTrain
# Training FreezerSmallTrain with num_cells = 8
# dname = FreezerSmallTrain, num_cells = 8, Test Accuracy = 0.7246, Test Loss = 0.7719
# Training FreezerSmallTrain with num_cells = 64
# dname = FreezerSmallTrain, num_cells = 64, Test Accuracy = 0.7354, Test Loss = 0.8048
# Training FreezerSmallTrain with num_cells = 128
# dname = FreezerSmallTrain, num_cells = 128, Test Accuracy = 0.7393, Test Loss = 0.9438
# BEST: dname = FreezerSmallTrain, Best num_cells: 128, Test Accuracy: 0.7393, Test Loss: 0.9438
# FreezerSmallTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Fungi
# Training Fungi with num_cells = 8
# dname = Fungi, num_cells = 8, Test Accuracy = 0.8495, Test Loss = 0.6723
# Training Fungi with num_cells = 64
# dname = Fungi, num_cells = 64, Test Accuracy = 0.8333, Test Loss = 0.5698
# Training Fungi with num_cells = 128
# dname = Fungi, num_cells = 128, Test Accuracy = 0.8387, Test Loss = 0.5736
# BEST: dname = Fungi, Best num_cells: 8, Test Accuracy: 0.8495, Test Loss: 0.6723
# Fungi best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GestureMidAirD1
# Training GestureMidAirD1 with num_cells = 8
# dname = GestureMidAirD1, num_cells = 8, Test Accuracy = 0.3077, Test Loss = 3.0145
# Training GestureMidAirD1 with num_cells = 64
# dname = GestureMidAirD1, num_cells = 64, Test Accuracy = 0.3000, Test Loss = 3.3001
# Training GestureMidAirD1 with num_cells = 128
# dname = GestureMidAirD1, num_cells = 128, Test Accuracy = 0.2846, Test Loss = 3.0051
# BEST: dname = GestureMidAirD1, Best num_cells: 8, Test Accuracy: 0.3077, Test Loss: 3.0145
# GestureMidAirD1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GestureMidAirD2
# Training GestureMidAirD2 with num_cells = 8
# dname = GestureMidAirD2, num_cells = 8, Test Accuracy = 0.2308, Test Loss = 3.2464
# Training GestureMidAirD2 with num_cells = 64
# dname = GestureMidAirD2, num_cells = 64, Test Accuracy = 0.2462, Test Loss = 3.0599
# Training GestureMidAirD2 with num_cells = 128
# dname = GestureMidAirD2, num_cells = 128, Test Accuracy = 0.2615, Test Loss = 3.2072
# BEST: dname = GestureMidAirD2, Best num_cells: 128, Test Accuracy: 0.2615, Test Loss: 3.2072
# GestureMidAirD2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GestureMidAirD3
# Training GestureMidAirD3 with num_cells = 8
# dname = GestureMidAirD3, num_cells = 8, Test Accuracy = 0.2308, Test Loss = 3.5676
# Training GestureMidAirD3 with num_cells = 64
# dname = GestureMidAirD3, num_cells = 64, Test Accuracy = 0.2462, Test Loss = 3.6547
# Training GestureMidAirD3 with num_cells = 128
# dname = GestureMidAirD3, num_cells = 128, Test Accuracy = 0.2231, Test Loss = 3.4669
# BEST: dname = GestureMidAirD3, Best num_cells: 64, Test Accuracy: 0.2462, Test Loss: 3.6547
# GestureMidAirD3 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GesturePebbleZ1
# Training GesturePebbleZ1 with num_cells = 8
# dname = GesturePebbleZ1, num_cells = 8, Test Accuracy = 0.4128, Test Loss = 1.7606
# Training GesturePebbleZ1 with num_cells = 64
# dname = GesturePebbleZ1, num_cells = 64, Test Accuracy = 0.4186, Test Loss = 2.4413
# Training GesturePebbleZ1 with num_cells = 128
# dname = GesturePebbleZ1, num_cells = 128, Test Accuracy = 0.5465, Test Loss = 1.5414
# BEST: dname = GesturePebbleZ1, Best num_cells: 128, Test Accuracy: 0.5465, Test Loss: 1.5414
# GesturePebbleZ1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GesturePebbleZ2
# Training GesturePebbleZ2 with num_cells = 8
# dname = GesturePebbleZ2, num_cells = 8, Test Accuracy = 0.4873, Test Loss = 1.8859
# Training GesturePebbleZ2 with num_cells = 64
# dname = GesturePebbleZ2, num_cells = 64, Test Accuracy = 0.4304, Test Loss = 1.9188
# Training GesturePebbleZ2 with num_cells = 128
# dname = GesturePebbleZ2, num_cells = 128, Test Accuracy = 0.5127, Test Loss = 1.9949
# BEST: dname = GesturePebbleZ2, Best num_cells: 128, Test Accuracy: 0.5127, Test Loss: 1.9949
# GesturePebbleZ2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GunPoint
# Training GunPoint with num_cells = 8
# dname = GunPoint, num_cells = 8, Test Accuracy = 0.7333, Test Loss = 0.8377
# Training GunPoint with num_cells = 64
# dname = GunPoint, num_cells = 64, Test Accuracy = 0.7533, Test Loss = 0.4816
# Training GunPoint with num_cells = 128
# dname = GunPoint, num_cells = 128, Test Accuracy = 0.8533, Test Loss = 0.2834
# BEST: dname = GunPoint, Best num_cells: 128, Test Accuracy: 0.8533, Test Loss: 0.2834
# GunPoint best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GunPointAgeSpan
# Training GunPointAgeSpan with num_cells = 8
# dname = GunPointAgeSpan, num_cells = 8, Test Accuracy = 0.8228, Test Loss = 0.8968
# Training GunPointAgeSpan with num_cells = 64
# dname = GunPointAgeSpan, num_cells = 64, Test Accuracy = 0.9114, Test Loss = 0.2448
# Training GunPointAgeSpan with num_cells = 128
# dname = GunPointAgeSpan, num_cells = 128, Test Accuracy = 0.9051, Test Loss = 0.3547
# BEST: dname = GunPointAgeSpan, Best num_cells: 64, Test Accuracy: 0.9114, Test Loss: 0.2448
# GunPointAgeSpan best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GunPointMaleVersusFemale
# Training GunPointMaleVersusFemale with num_cells = 8
# dname = GunPointMaleVersusFemale, num_cells = 8, Test Accuracy = 0.9905, Test Loss = 0.0443
# Training GunPointMaleVersusFemale with num_cells = 64
# dname = GunPointMaleVersusFemale, num_cells = 64, Test Accuracy = 0.9082, Test Loss = 0.2189
# Training GunPointMaleVersusFemale with num_cells = 128
# dname = GunPointMaleVersusFemale, num_cells = 128, Test Accuracy = 0.9810, Test Loss = 0.0712
# BEST: dname = GunPointMaleVersusFemale, Best num_cells: 8, Test Accuracy: 0.9905, Test Loss: 0.0443
# GunPointMaleVersusFemale best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: GunPointOldVersusYoung
# Training GunPointOldVersusYoung with num_cells = 8
# dname = GunPointOldVersusYoung, num_cells = 8, Test Accuracy = 0.9175, Test Loss = 0.3247
# Training GunPointOldVersusYoung with num_cells = 64
# dname = GunPointOldVersusYoung, num_cells = 64, Test Accuracy = 0.9333, Test Loss = 0.2334
# Training GunPointOldVersusYoung with num_cells = 128
# dname = GunPointOldVersusYoung, num_cells = 128, Test Accuracy = 0.8921, Test Loss = 0.4899
# BEST: dname = GunPointOldVersusYoung, Best num_cells: 64, Test Accuracy: 0.9333, Test Loss: 0.2334
# GunPointOldVersusYoung best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Ham
# Training Ham with num_cells = 8
# dname = Ham, num_cells = 8, Test Accuracy = 0.6952, Test Loss = 0.7150
# Training Ham with num_cells = 64
# dname = Ham, num_cells = 64, Test Accuracy = 0.6476, Test Loss = 0.7747
# Training Ham with num_cells = 128
# dname = Ham, num_cells = 128, Test Accuracy = 0.6667, Test Loss = 0.8190
# BEST: dname = Ham, Best num_cells: 8, Test Accuracy: 0.6952, Test Loss: 0.7150
# Ham best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: HandOutlines
# Training HandOutlines with num_cells = 8
# dname = HandOutlines, num_cells = 8, Test Accuracy = 0.8811, Test Loss = 0.7582
# Training HandOutlines with num_cells = 64
# dname = HandOutlines, num_cells = 64, Test Accuracy = 0.8757, Test Loss = 0.6533
# Training HandOutlines with num_cells = 128
# dname = HandOutlines, num_cells = 128, Test Accuracy = 0.8919, Test Loss = 0.6656
# BEST: dname = HandOutlines, Best num_cells: 128, Test Accuracy: 0.8919, Test Loss: 0.6656
# HandOutlines best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Haptics
# Training Haptics with num_cells = 8
# dname = Haptics, num_cells = 8, Test Accuracy = 0.3896, Test Loss = 3.1536
# Training Haptics with num_cells = 64
# dname = Haptics, num_cells = 64, Test Accuracy = 0.4513, Test Loss = 3.3001
# Training Haptics with num_cells = 128
# dname = Haptics, num_cells = 128, Test Accuracy = 0.3734, Test Loss = 3.6281
# BEST: dname = Haptics, Best num_cells: 64, Test Accuracy: 0.4513, Test Loss: 3.3001
# Haptics best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Herring
# Training Herring with num_cells = 8
# dname = Herring, num_cells = 8, Test Accuracy = 0.5625, Test Loss = 0.8397
# Training Herring with num_cells = 64
# dname = Herring, num_cells = 64, Test Accuracy = 0.6562, Test Loss = 0.7240
# Training Herring with num_cells = 128
# dname = Herring, num_cells = 128, Test Accuracy = 0.6562, Test Loss = 0.7745
# BEST: dname = Herring, Best num_cells: 64, Test Accuracy: 0.6562, Test Loss: 0.7240
# Herring best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: HouseTwenty
# Training HouseTwenty with num_cells = 8
# dname = HouseTwenty, num_cells = 8, Test Accuracy = 0.7479, Test Loss = 0.9578
# Training HouseTwenty with num_cells = 64
# dname = HouseTwenty, num_cells = 64, Test Accuracy = 0.7815, Test Loss = 0.9888
# Training HouseTwenty with num_cells = 128
# dname = HouseTwenty, num_cells = 128, Test Accuracy = 0.7059, Test Loss = 1.1885
# BEST: dname = HouseTwenty, Best num_cells: 64, Test Accuracy: 0.7815, Test Loss: 0.9888
# HouseTwenty best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: InlineSkate
# Training InlineSkate with num_cells = 8
# dname = InlineSkate, num_cells = 8, Test Accuracy = 0.2891, Test Loss = 2.2272
# Training InlineSkate with num_cells = 64
# dname = InlineSkate, num_cells = 64, Test Accuracy = 0.3309, Test Loss = 2.2299
# Training InlineSkate with num_cells = 128
# dname = InlineSkate, num_cells = 128, Test Accuracy = 0.3218, Test Loss = 2.2853
# BEST: dname = InlineSkate, Best num_cells: 64, Test Accuracy: 0.3309, Test Loss: 2.2299
# InlineSkate best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: InsectEPGRegularTrain
# Training InsectEPGRegularTrain with num_cells = 8
# dname = InsectEPGRegularTrain, num_cells = 8, Test Accuracy = 0.6386, Test Loss = 1.2481
# Training InsectEPGRegularTrain with num_cells = 64
# dname = InsectEPGRegularTrain, num_cells = 64, Test Accuracy = 0.6586, Test Loss = 1.2504
# Training InsectEPGRegularTrain with num_cells = 128
# dname = InsectEPGRegularTrain, num_cells = 128, Test Accuracy = 0.6627, Test Loss = 1.2660
# BEST: dname = InsectEPGRegularTrain, Best num_cells: 128, Test Accuracy: 0.6627, Test Loss: 1.2660
# InsectEPGRegularTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: InsectEPGSmallTrain
# Training InsectEPGSmallTrain with num_cells = 8
# dname = InsectEPGSmallTrain, num_cells = 8, Test Accuracy = 0.6305, Test Loss = 1.3562
# Training InsectEPGSmallTrain with num_cells = 64
# dname = InsectEPGSmallTrain, num_cells = 64, Test Accuracy = 0.6305, Test Loss = 1.3211
# Training InsectEPGSmallTrain with num_cells = 128
# dname = InsectEPGSmallTrain, num_cells = 128, Test Accuracy = 0.6466, Test Loss = 1.3381
# BEST: dname = InsectEPGSmallTrain, Best num_cells: 128, Test Accuracy: 0.6466, Test Loss: 1.3381
# InsectEPGSmallTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: InsectWingbeatSound
# Training InsectWingbeatSound with num_cells = 8
# dname = InsectWingbeatSound, num_cells = 8, Test Accuracy = 0.6172, Test Loss = 1.6183
# Training InsectWingbeatSound with num_cells = 64
# dname = InsectWingbeatSound, num_cells = 64, Test Accuracy = 0.5894, Test Loss = 1.9149
# Training InsectWingbeatSound with num_cells = 128
# dname = InsectWingbeatSound, num_cells = 128, Test Accuracy = 0.6136, Test Loss = 1.6690
# BEST: dname = InsectWingbeatSound, Best num_cells: 8, Test Accuracy: 0.6172, Test Loss: 1.6183
# InsectWingbeatSound best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ItalyPowerDemand
# Training ItalyPowerDemand with num_cells = 8
# dname = ItalyPowerDemand, num_cells = 8, Test Accuracy = 0.9553, Test Loss = 0.1336
# Training ItalyPowerDemand with num_cells = 64
# dname = ItalyPowerDemand, num_cells = 64, Test Accuracy = 0.9563, Test Loss = 0.1290
# Training ItalyPowerDemand with num_cells = 128
# dname = ItalyPowerDemand, num_cells = 128, Test Accuracy = 0.9670, Test Loss = 0.1141
# BEST: dname = ItalyPowerDemand, Best num_cells: 128, Test Accuracy: 0.9670, Test Loss: 0.1141
# ItalyPowerDemand best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: LargeKitchenAppliances
# Training LargeKitchenAppliances with num_cells = 8
# dname = LargeKitchenAppliances, num_cells = 8, Test Accuracy = 0.4640, Test Loss = 2.4572
# Training LargeKitchenAppliances with num_cells = 64
# dname = LargeKitchenAppliances, num_cells = 64, Test Accuracy = 0.4693, Test Loss = 2.4632
# Training LargeKitchenAppliances with num_cells = 128
# dname = LargeKitchenAppliances, num_cells = 128, Test Accuracy = 0.4880, Test Loss = 2.4142
# BEST: dname = LargeKitchenAppliances, Best num_cells: 128, Test Accuracy: 0.4880, Test Loss: 2.4142
# LargeKitchenAppliances best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Lightning2
# Training Lightning2 with num_cells = 8
# dname = Lightning2, num_cells = 8, Test Accuracy = 0.6557, Test Loss = 0.8917
# Training Lightning2 with num_cells = 64
# dname = Lightning2, num_cells = 64, Test Accuracy = 0.7213, Test Loss = 1.0001
# Training Lightning2 with num_cells = 128
# dname = Lightning2, num_cells = 128, Test Accuracy = 0.7049, Test Loss = 1.1016
# BEST: dname = Lightning2, Best num_cells: 64, Test Accuracy: 0.7213, Test Loss: 1.0001
# Lightning2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Lightning7
# Training Lightning7 with num_cells = 8
# dname = Lightning7, num_cells = 8, Test Accuracy = 0.6164, Test Loss = 1.2417
# Training Lightning7 with num_cells = 64
# dname = Lightning7, num_cells = 64, Test Accuracy = 0.6027, Test Loss = 1.2548
# Training Lightning7 with num_cells = 128
# dname = Lightning7, num_cells = 128, Test Accuracy = 0.5616, Test Loss = 1.4036
# BEST: dname = Lightning7, Best num_cells: 8, Test Accuracy: 0.6164, Test Loss: 1.2417
# Lightning7 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Mallat
# Training Mallat with num_cells = 8
# dname = Mallat, num_cells = 8, Test Accuracy = 0.8708, Test Loss = 0.5602
# Training Mallat with num_cells = 64
# dname = Mallat, num_cells = 64, Test Accuracy = 0.8303, Test Loss = 0.7731
# Training Mallat with num_cells = 128
# dname = Mallat, num_cells = 128, Test Accuracy = 0.8375, Test Loss = 0.6732
# BEST: dname = Mallat, Best num_cells: 8, Test Accuracy: 0.8708, Test Loss: 0.5602
# Mallat best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Meat
# Training Meat with num_cells = 8
# dname = Meat, num_cells = 8, Test Accuracy = 0.4500, Test Loss = 0.9043
# Training Meat with num_cells = 64
# dname = Meat, num_cells = 64, Test Accuracy = 0.8333, Test Loss = 0.6764
# Training Meat with num_cells = 128
# dname = Meat, num_cells = 128, Test Accuracy = 0.6333, Test Loss = 0.7469
# BEST: dname = Meat, Best num_cells: 64, Test Accuracy: 0.8333, Test Loss: 0.6764
# Meat best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MedicalImages
# Training MedicalImages with num_cells = 8
# dname = MedicalImages, num_cells = 8, Test Accuracy = 0.6961, Test Loss = 1.4513
# Training MedicalImages with num_cells = 64
# dname = MedicalImages, num_cells = 64, Test Accuracy = 0.6908, Test Loss = 1.3038
# Training MedicalImages with num_cells = 128
# dname = MedicalImages, num_cells = 128, Test Accuracy = 0.7132, Test Loss = 1.3373
# BEST: dname = MedicalImages, Best num_cells: 128, Test Accuracy: 0.7132, Test Loss: 1.3373
# MedicalImages best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MelbournePedestrian
# Training MelbournePedestrian with num_cells = 8
# dname = MelbournePedestrian, num_cells = 8, Test Accuracy = 0.8934, Test Loss = 0.5346
# Training MelbournePedestrian with num_cells = 64
# dname = MelbournePedestrian, num_cells = 64, Test Accuracy = 0.8831, Test Loss = 0.6107
# Training MelbournePedestrian with num_cells = 128
# dname = MelbournePedestrian, num_cells = 128, Test Accuracy = 0.8856, Test Loss = 0.5712
# BEST: dname = MelbournePedestrian, Best num_cells: 8, Test Accuracy: 0.8934, Test Loss: 0.5346
# MelbournePedestrian best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MiddlePhalanxOutlineAgeGroup
# Training MiddlePhalanxOutlineAgeGroup with num_cells = 8
# dname = MiddlePhalanxOutlineAgeGroup, num_cells = 8, Test Accuracy = 0.4740, Test Loss = 2.4851
# Training MiddlePhalanxOutlineAgeGroup with num_cells = 64
# dname = MiddlePhalanxOutlineAgeGroup, num_cells = 64, Test Accuracy = 0.6169, Test Loss = 3.3521
# Training MiddlePhalanxOutlineAgeGroup with num_cells = 128
# dname = MiddlePhalanxOutlineAgeGroup, num_cells = 128, Test Accuracy = 0.5909, Test Loss = 3.1915
# BEST: dname = MiddlePhalanxOutlineAgeGroup, Best num_cells: 64, Test Accuracy: 0.6169, Test Loss: 3.3521
# MiddlePhalanxOutlineAgeGroup best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MiddlePhalanxOutlineCorrect
# Training MiddlePhalanxOutlineCorrect with num_cells = 8
# dname = MiddlePhalanxOutlineCorrect, num_cells = 8, Test Accuracy = 0.7973, Test Loss = 0.7941
# Training MiddlePhalanxOutlineCorrect with num_cells = 64
# dname = MiddlePhalanxOutlineCorrect, num_cells = 64, Test Accuracy = 0.7113, Test Loss = 1.5535
# Training MiddlePhalanxOutlineCorrect with num_cells = 128
# dname = MiddlePhalanxOutlineCorrect, num_cells = 128, Test Accuracy = 0.7973, Test Loss = 1.0150
# BEST: dname = MiddlePhalanxOutlineCorrect, Best num_cells: 8, Test Accuracy: 0.7973, Test Loss: 0.7941
# MiddlePhalanxOutlineCorrect best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MiddlePhalanxTW
# Training MiddlePhalanxTW with num_cells = 8
# dname = MiddlePhalanxTW, num_cells = 8, Test Accuracy = 0.5000, Test Loss = 2.7342
# Training MiddlePhalanxTW with num_cells = 64
# dname = MiddlePhalanxTW, num_cells = 64, Test Accuracy = 0.4091, Test Loss = 3.4561
# Training MiddlePhalanxTW with num_cells = 128
# dname = MiddlePhalanxTW, num_cells = 128, Test Accuracy = 0.5844, Test Loss = 2.5994
# BEST: dname = MiddlePhalanxTW, Best num_cells: 128, Test Accuracy: 0.5844, Test Loss: 2.5994
# MiddlePhalanxTW best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MixedShapesRegularTrain
# Training MixedShapesRegularTrain with num_cells = 8
# dname = MixedShapesRegularTrain, num_cells = 8, Test Accuracy = 0.9163, Test Loss = 0.3978
# Training MixedShapesRegularTrain with num_cells = 64
# dname = MixedShapesRegularTrain, num_cells = 64, Test Accuracy = 0.9060, Test Loss = 0.4326
# Training MixedShapesRegularTrain with num_cells = 128
# dname = MixedShapesRegularTrain, num_cells = 128, Test Accuracy = 0.9097, Test Loss = 0.4433
# BEST: dname = MixedShapesRegularTrain, Best num_cells: 8, Test Accuracy: 0.9163, Test Loss: 0.3978
# MixedShapesRegularTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MixedShapesSmallTrain
# Training MixedShapesSmallTrain with num_cells = 8
# dname = MixedShapesSmallTrain, num_cells = 8, Test Accuracy = 0.8433, Test Loss = 0.5264
# Training MixedShapesSmallTrain with num_cells = 64
# dname = MixedShapesSmallTrain, num_cells = 64, Test Accuracy = 0.8441, Test Loss = 0.5389
# Training MixedShapesSmallTrain with num_cells = 128
# dname = MixedShapesSmallTrain, num_cells = 128, Test Accuracy = 0.8301, Test Loss = 0.6185
# BEST: dname = MixedShapesSmallTrain, Best num_cells: 64, Test Accuracy: 0.8441, Test Loss: 0.5389
# MixedShapesSmallTrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: MoteStrain
# Training MoteStrain with num_cells = 8
# dname = MoteStrain, num_cells = 8, Test Accuracy = 0.8562, Test Loss = 0.3372
# Training MoteStrain with num_cells = 64
# dname = MoteStrain, num_cells = 64, Test Accuracy = 0.8650, Test Loss = 0.3014
# Training MoteStrain with num_cells = 128
# dname = MoteStrain, num_cells = 128, Test Accuracy = 0.8642, Test Loss = 0.3185
# BEST: dname = MoteStrain, Best num_cells: 64, Test Accuracy: 0.8650, Test Loss: 0.3014
# MoteStrain best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: NonInvasiveFetalECGThorax1
# Training NonInvasiveFetalECGThorax1 with num_cells = 8
# dname = NonInvasiveFetalECGThorax1, num_cells = 8, Test Accuracy = 0.3847, Test Loss = 5.6124
# Training NonInvasiveFetalECGThorax1 with num_cells = 64
# dname = NonInvasiveFetalECGThorax1, num_cells = 64, Test Accuracy = 0.5735, Test Loss = 2.4229
# Training NonInvasiveFetalECGThorax1 with num_cells = 128
# dname = NonInvasiveFetalECGThorax1, num_cells = 128, Test Accuracy = 0.8346, Test Loss = 0.6364
# BEST: dname = NonInvasiveFetalECGThorax1, Best num_cells: 128, Test Accuracy: 0.8346, Test Loss: 0.6364
# NonInvasiveFetalECGThorax1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: NonInvasiveFetalECGThorax2
# Training NonInvasiveFetalECGThorax2 with num_cells = 8
# dname = NonInvasiveFetalECGThorax2, num_cells = 8, Test Accuracy = 0.8835, Test Loss = 0.4408
# Training NonInvasiveFetalECGThorax2 with num_cells = 64
# dname = NonInvasiveFetalECGThorax2, num_cells = 64, Test Accuracy = 0.7517, Test Loss = 1.0293
# Training NonInvasiveFetalECGThorax2 with num_cells = 128
# dname = NonInvasiveFetalECGThorax2, num_cells = 128, Test Accuracy = 0.8412, Test Loss = 0.7392
# BEST: dname = NonInvasiveFetalECGThorax2, Best num_cells: 8, Test Accuracy: 0.8835, Test Loss: 0.4408
# NonInvasiveFetalECGThorax2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: OliveOil
# Training OliveOil with num_cells = 8
# dname = OliveOil, num_cells = 8, Test Accuracy = 0.3333, Test Loss = 1.3125
# Training OliveOil with num_cells = 64
# dname = OliveOil, num_cells = 64, Test Accuracy = 0.4000, Test Loss = 1.3233
# Training OliveOil with num_cells = 128
# dname = OliveOil, num_cells = 128, Test Accuracy = 0.4000, Test Loss = 1.3090
# BEST: dname = OliveOil, Best num_cells: 64, Test Accuracy: 0.4000, Test Loss: 1.3233
# OliveOil best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: OSULeaf
# Training OSULeaf with num_cells = 8
# dname = OSULeaf, num_cells = 8, Test Accuracy = 0.5455, Test Loss = 1.8765
# Training OSULeaf with num_cells = 64
# dname = OSULeaf, num_cells = 64, Test Accuracy = 0.5537, Test Loss = 1.8009
# Training OSULeaf with num_cells = 128
# dname = OSULeaf, num_cells = 128, Test Accuracy = 0.5744, Test Loss = 1.9453
# BEST: dname = OSULeaf, Best num_cells: 128, Test Accuracy: 0.5744, Test Loss: 1.9453
# OSULeaf best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: PhalangesOutlinesCorrect
# Training PhalangesOutlinesCorrect with num_cells = 8
# dname = PhalangesOutlinesCorrect, num_cells = 8, Test Accuracy = 0.6375, Test Loss = 1.4396
# Training PhalangesOutlinesCorrect with num_cells = 64
# dname = PhalangesOutlinesCorrect, num_cells = 64, Test Accuracy = 0.6212, Test Loss = 1.7796
# Training PhalangesOutlinesCorrect with num_cells = 128
# dname = PhalangesOutlinesCorrect, num_cells = 128, Test Accuracy = 0.7890, Test Loss = 0.7154
# BEST: dname = PhalangesOutlinesCorrect, Best num_cells: 128, Test Accuracy: 0.7890, Test Loss: 0.7154
# PhalangesOutlinesCorrect best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Phoneme
# Training Phoneme with num_cells = 8
# dname = Phoneme, num_cells = 8, Test Accuracy = 0.0828, Test Loss = 3.9573
# Training Phoneme with num_cells = 64
# ...
# Training ShakeGestureWiimoteZ with num_cells = 64
# dname = ShakeGestureWiimoteZ, num_cells = 64, Test Accuracy = 0.4800, Test Loss = 2.1893
# Training ShakeGestureWiimoteZ with num_cells = 128
# dname = ShakeGestureWiimoteZ, num_cells = 128, Test Accuracy = 0.5200, Test Loss = 2.0508
# BEST: dname = ShakeGestureWiimoteZ, Best num_cells: 128, Test Accuracy: 0.5200, Test Loss: 2.0508
# ShakeGestureWiimoteZ best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ShapeletSim
# Training ShapeletSim with num_cells = 8
# dname = ShapeletSim, num_cells = 8, Test Accuracy = 0.4944, Test Loss = 0.8139
# Training ShapeletSim with num_cells = 64
# dname = ShapeletSim, num_cells = 64, Test Accuracy = 0.5167, Test Loss = 0.8025
# Training ShapeletSim with num_cells = 128
# dname = ShapeletSim, num_cells = 128, Test Accuracy = 0.4889, Test Loss = 0.8655
# BEST: dname = ShapeletSim, Best num_cells: 64, Test Accuracy: 0.5167, Test Loss: 0.8025
# ShapeletSim best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ShapesAll
# Training ShapesAll with num_cells = 8
# dname = ShapesAll, num_cells = 8, Test Accuracy = 0.7550, Test Loss = 1.2233
# Training ShapesAll with num_cells = 64
# dname = ShapesAll, num_cells = 64, Test Accuracy = 0.7400, Test Loss = 1.3532
# Training ShapesAll with num_cells = 128
# dname = ShapesAll, num_cells = 128, Test Accuracy = 0.7600, Test Loss = 1.3642
# BEST: dname = ShapesAll, Best num_cells: 128, Test Accuracy: 0.7600, Test Loss: 1.3642
# ShapesAll best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SmallKitchenAppliances
# Training SmallKitchenAppliances with num_cells = 8
# dname = SmallKitchenAppliances, num_cells = 8, Test Accuracy = 0.4027, Test Loss = 2.5892
# Training SmallKitchenAppliances with num_cells = 64
# dname = SmallKitchenAppliances, num_cells = 64, Test Accuracy = 0.3547, Test Loss = 2.7763
# Training SmallKitchenAppliances with num_cells = 128
# dname = SmallKitchenAppliances, num_cells = 128, Test Accuracy = 0.3733, Test Loss = 2.6379
# BEST: dname = SmallKitchenAppliances, Best num_cells: 8, Test Accuracy: 0.4027, Test Loss: 2.5892
# SmallKitchenAppliances best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SmoothSubspace
# Training SmoothSubspace with num_cells = 8
# dname = SmoothSubspace, num_cells = 8, Test Accuracy = 0.9000, Test Loss = 0.2532
# Training SmoothSubspace with num_cells = 64
# dname = SmoothSubspace, num_cells = 64, Test Accuracy = 0.8867, Test Loss = 0.3276
# Training SmoothSubspace with num_cells = 128
# dname = SmoothSubspace, num_cells = 128, Test Accuracy = 0.8733, Test Loss = 0.3771
# BEST: dname = SmoothSubspace, Best num_cells: 8, Test Accuracy: 0.9000, Test Loss: 0.2532
# SmoothSubspace best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SonyAIBORobotSurface1
# Training SonyAIBORobotSurface1 with num_cells = 8
# dname = SonyAIBORobotSurface1, num_cells = 8, Test Accuracy = 0.7005, Test Loss = 0.6015
# Training SonyAIBORobotSurface1 with num_cells = 64
# dname = SonyAIBORobotSurface1, num_cells = 64, Test Accuracy = 0.5824, Test Loss = 1.0292
# Training SonyAIBORobotSurface1 with num_cells = 128
# dname = SonyAIBORobotSurface1, num_cells = 128, Test Accuracy = 0.5408, Test Loss = 1.0512
# BEST: dname = SonyAIBORobotSurface1, Best num_cells: 8, Test Accuracy: 0.7005, Test Loss: 0.6015
# SonyAIBORobotSurface1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SonyAIBORobotSurface2
# Training SonyAIBORobotSurface2 with num_cells = 8
# dname = SonyAIBORobotSurface2, num_cells = 8, Test Accuracy = 0.8332, Test Loss = 0.3989
# Training SonyAIBORobotSurface2 with num_cells = 64
# dname = SonyAIBORobotSurface2, num_cells = 64, Test Accuracy = 0.8269, Test Loss = 0.3793
# Training SonyAIBORobotSurface2 with num_cells = 128
# dname = SonyAIBORobotSurface2, num_cells = 128, Test Accuracy = 0.8164, Test Loss = 0.3800
# BEST: dname = SonyAIBORobotSurface2, Best num_cells: 8, Test Accuracy: 0.8332, Test Loss: 0.3989
# SonyAIBORobotSurface2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: StarLightCurves
# Training StarLightCurves with num_cells = 8
# dname = StarLightCurves, num_cells = 8, Test Accuracy = 0.9015, Test Loss = 0.5535
# Training StarLightCurves with num_cells = 64
# dname = StarLightCurves, num_cells = 64, Test Accuracy = 0.9411, Test Loss = 0.3136
# Training StarLightCurves with num_cells = 128
# dname = StarLightCurves, num_cells = 128, Test Accuracy = 0.9273, Test Loss = 0.3812
# BEST: dname = StarLightCurves, Best num_cells: 64, Test Accuracy: 0.9411, Test Loss: 0.3136
# StarLightCurves best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Strawberry
# Training Strawberry with num_cells = 8
# dname = Strawberry, num_cells = 8, Test Accuracy = 0.6838, Test Loss = 1.9154
# Training Strawberry with num_cells = 64
# dname = Strawberry, num_cells = 64, Test Accuracy = 0.9703, Test Loss = 0.1161
# Training Strawberry with num_cells = 128
# dname = Strawberry, num_cells = 128, Test Accuracy = 0.9784, Test Loss = 0.1479
# BEST: dname = Strawberry, Best num_cells: 128, Test Accuracy: 0.9784, Test Loss: 0.1479
# Strawberry best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SwedishLeaf
# Training SwedishLeaf with num_cells = 8
# dname = SwedishLeaf, num_cells = 8, Test Accuracy = 0.8816, Test Loss = 0.4147
# Training SwedishLeaf with num_cells = 64
# dname = SwedishLeaf, num_cells = 64, Test Accuracy = 0.8944, Test Loss = 0.3899
# Training SwedishLeaf with num_cells = 128
# dname = SwedishLeaf, num_cells = 128, Test Accuracy = 0.8832, Test Loss = 0.4383
# BEST: dname = SwedishLeaf, Best num_cells: 64, Test Accuracy: 0.8944, Test Loss: 0.3899
# SwedishLeaf best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Symbols
# Training Symbols with num_cells = 8
# dname = Symbols, num_cells = 8, Test Accuracy = 0.8271, Test Loss = 0.5745
# Training Symbols with num_cells = 64
# dname = Symbols, num_cells = 64, Test Accuracy = 0.8372, Test Loss = 0.5799
# Training Symbols with num_cells = 128
# dname = Symbols, num_cells = 128, Test Accuracy = 0.8553, Test Loss = 0.5244
# BEST: dname = Symbols, Best num_cells: 128, Test Accuracy: 0.8553, Test Loss: 0.5244
# Symbols best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: SyntheticControl
# Training SyntheticControl with num_cells = 8
# dname = SyntheticControl, num_cells = 8, Test Accuracy = 0.9167, Test Loss = 0.2827
# Training SyntheticControl with num_cells = 64
# dname = SyntheticControl, num_cells = 64, Test Accuracy = 0.9433, Test Loss = 0.1372
# Training SyntheticControl with num_cells = 128
# dname = SyntheticControl, num_cells = 128, Test Accuracy = 0.9100, Test Loss = 0.3282
# BEST: dname = SyntheticControl, Best num_cells: 64, Test Accuracy: 0.9433, Test Loss: 0.1372
# SyntheticControl best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ToeSegmentation1
# Training ToeSegmentation1 with num_cells = 8
# dname = ToeSegmentation1, num_cells = 8, Test Accuracy = 0.6140, Test Loss = 1.0364
# Training ToeSegmentation1 with num_cells = 64
# dname = ToeSegmentation1, num_cells = 64, Test Accuracy = 0.5921, Test Loss = 1.0523
# Training ToeSegmentation1 with num_cells = 128
# dname = ToeSegmentation1, num_cells = 128, Test Accuracy = 0.6579, Test Loss = 0.9615
# BEST: dname = ToeSegmentation1, Best num_cells: 128, Test Accuracy: 0.6579, Test Loss: 0.9615
# ToeSegmentation1 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: ToeSegmentation2
# Training ToeSegmentation2 with num_cells = 8
# dname = ToeSegmentation2, num_cells = 8, Test Accuracy = 0.7000, Test Loss = 0.7395
# Training ToeSegmentation2 with num_cells = 64
# dname = ToeSegmentation2, num_cells = 64, Test Accuracy = 0.7154, Test Loss = 0.6251
# Training ToeSegmentation2 with num_cells = 128
# dname = ToeSegmentation2, num_cells = 128, Test Accuracy = 0.7615, Test Loss = 0.5603
# BEST: dname = ToeSegmentation2, Best num_cells: 128, Test Accuracy: 0.7615, Test Loss: 0.5603
# ToeSegmentation2 best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Trace
# Training Trace with num_cells = 8
# dname = Trace, num_cells = 8, Test Accuracy = 0.5500, Test Loss = 1.2865
# Training Trace with num_cells = 64
# dname = Trace, num_cells = 64, Test Accuracy = 0.4900, Test Loss = 1.5816
# Training Trace with num_cells = 128
# dname = Trace, num_cells = 128, Test Accuracy = 0.4900, Test Loss = 1.6926
# BEST: dname = Trace, Best num_cells: 8, Test Accuracy: 0.5500, Test Loss: 1.2865
# Trace best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: TwoLeadECG
# Training TwoLeadECG with num_cells = 8
# dname = TwoLeadECG, num_cells = 8, Test Accuracy = 0.5426, Test Loss = 1.3437
# Training TwoLeadECG with num_cells = 64
# dname = TwoLeadECG, num_cells = 64, Test Accuracy = 0.5189, Test Loss = 1.5672
# Training TwoLeadECG with num_cells = 128
# dname = TwoLeadECG, num_cells = 128, Test Accuracy = 0.5329, Test Loss = 1.6543
# BEST: dname = TwoLeadECG, Best num_cells: 8, Test Accuracy: 0.5426, Test Loss: 1.3437
# TwoLeadECG best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: TwoPatterns
# Training TwoPatterns with num_cells = 8
# dname = TwoPatterns, num_cells = 8, Test Accuracy = 0.8535, Test Loss = 0.5220
# Training TwoPatterns with num_cells = 64
# dname = TwoPatterns, num_cells = 64, Test Accuracy = 0.8662, Test Loss = 0.4762
# Training TwoPatterns with num_cells = 128
# dname = TwoPatterns, num_cells = 128, Test Accuracy = 0.8650, Test Loss = 0.4684
# BEST: dname = TwoPatterns, Best num_cells: 64, Test Accuracy: 0.8662, Test Loss: 0.4762
# TwoPatterns best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: UMD
# Training UMD with num_cells = 8
# dname = UMD, num_cells = 8, Test Accuracy = 0.8264, Test Loss = 0.4481
# Training UMD with num_cells = 64
# dname = UMD, num_cells = 64, Test Accuracy = 0.7500, Test Loss = 0.6719
# Training UMD with num_cells = 128
# dname = UMD, num_cells = 128, Test Accuracy = 0.7778, Test Loss = 0.5347
# BEST: dname = UMD, Best num_cells: 8, Test Accuracy: 0.8264, Test Loss: 0.4481
# UMD best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: UWaveGestureLibraryAll
# Training UWaveGestureLibraryAll with num_cells = 8
# dname = UWaveGestureLibraryAll, num_cells = 8, Test Accuracy = 0.9562, Test Loss = 0.2341
# Training UWaveGestureLibraryAll with num_cells = 64
# dname = UWaveGestureLibraryAll, num_cells = 64, Test Accuracy = 0.9551, Test Loss = 0.2213
# Training UWaveGestureLibraryAll with num_cells = 128
# dname = UWaveGestureLibraryAll, num_cells = 128, Test Accuracy = 0.9548, Test Loss = 0.2244
# BEST: dname = UWaveGestureLibraryAll, Best num_cells: 8, Test Accuracy: 0.9562, Test Loss: 0.2341
# UWaveGestureLibraryAll best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: UWaveGestureLibraryX
# Training UWaveGestureLibraryX with num_cells = 8
# dname = UWaveGestureLibraryX, num_cells = 8, Test Accuracy = 0.7594, Test Loss = 1.3377
# Training UWaveGestureLibraryX with num_cells = 64
# dname = UWaveGestureLibraryX, num_cells = 64, Test Accuracy = 0.7655, Test Loss = 1.4266
# Training UWaveGestureLibraryX with num_cells = 128
# dname = UWaveGestureLibraryX, num_cells = 128, Test Accuracy = 0.7655, Test Loss = 1.2485
# BEST: dname = UWaveGestureLibraryX, Best num_cells: 64, Test Accuracy: 0.7655, Test Loss: 1.4266
# UWaveGestureLibraryX best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: UWaveGestureLibraryY
# Training UWaveGestureLibraryY with num_cells = 8
# dname = UWaveGestureLibraryY, num_cells = 8, Test Accuracy = 0.6873, Test Loss = 1.7084
# Training UWaveGestureLibraryY with num_cells = 64
# dname = UWaveGestureLibraryY, num_cells = 64, Test Accuracy = 0.6937, Test Loss = 1.7345
# Training UWaveGestureLibraryY with num_cells = 128
# dname = UWaveGestureLibraryY, num_cells = 128, Test Accuracy = 0.6826, Test Loss = 1.7305
# BEST: dname = UWaveGestureLibraryY, Best num_cells: 64, Test Accuracy: 0.6937, Test Loss: 1.7345
# UWaveGestureLibraryY best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: UWaveGestureLibraryZ
# Training UWaveGestureLibraryZ with num_cells = 8
# dname = UWaveGestureLibraryZ, num_cells = 8, Test Accuracy = 0.6840, Test Loss = 1.6383
# Training UWaveGestureLibraryZ with num_cells = 64
# dname = UWaveGestureLibraryZ, num_cells = 64, Test Accuracy = 0.6639, Test Loss = 1.9693
# Training UWaveGestureLibraryZ with num_cells = 128
# dname = UWaveGestureLibraryZ, num_cells = 128, Test Accuracy = 0.6798, Test Loss = 1.7801
# BEST: dname = UWaveGestureLibraryZ, Best num_cells: 8, Test Accuracy: 0.6840, Test Loss: 1.6383
# UWaveGestureLibraryZ best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Wafer
# Training Wafer with num_cells = 8
# dname = Wafer, num_cells = 8, Test Accuracy = 0.9959, Test Loss = 0.0242
# Training Wafer with num_cells = 64
# dname = Wafer, num_cells = 64, Test Accuracy = 0.9942, Test Loss = 0.0308
# Training Wafer with num_cells = 128
# dname = Wafer, num_cells = 128, Test Accuracy = 0.9950, Test Loss = 0.0277
# BEST: dname = Wafer, Best num_cells: 8, Test Accuracy: 0.9959, Test Loss: 0.0242
# Wafer best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Wine
# Training Wine with num_cells = 8
# dname = Wine, num_cells = 8, Test Accuracy = 0.5556, Test Loss = 0.7437
# Training Wine with num_cells = 64
# dname = Wine, num_cells = 64, Test Accuracy = 0.5000, Test Loss = 1.6263
# Training Wine with num_cells = 128
# dname = Wine, num_cells = 128, Test Accuracy = 0.5000, Test Loss = 0.8066
# BEST: dname = Wine, Best num_cells: 8, Test Accuracy: 0.5556, Test Loss: 0.7437
# Wine best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: WordSynonyms
# Training WordSynonyms with num_cells = 8
# dname = WordSynonyms, num_cells = 8, Test Accuracy = 0.5455, Test Loss = 2.3158
# Training WordSynonyms with num_cells = 64
# dname = WordSynonyms, num_cells = 64, Test Accuracy = 0.5486, Test Loss = 2.3682
# Training WordSynonyms with num_cells = 128
# dname = WordSynonyms, num_cells = 128, Test Accuracy = 0.5705, Test Loss = 2.1684
# BEST: dname = WordSynonyms, Best num_cells: 128, Test Accuracy: 0.5705, Test Loss: 2.1684
# WordSynonyms best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Worms
# Training Worms with num_cells = 8
# dname = Worms, num_cells = 8, Test Accuracy = 0.4805, Test Loss = 2.7226
# Training Worms with num_cells = 64
# dname = Worms, num_cells = 64, Test Accuracy = 0.4935, Test Loss = 2.8499
# Training Worms with num_cells = 128
# dname = Worms, num_cells = 128, Test Accuracy = 0.4935, Test Loss = 2.8502
# BEST: dname = Worms, Best num_cells: 64, Test Accuracy: 0.4935, Test Loss: 2.8499
# Worms best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: WormsTwoClass
# Training WormsTwoClass with num_cells = 8
# dname = WormsTwoClass, num_cells = 8, Test Accuracy = 0.6104, Test Loss = 1.9818
# Training WormsTwoClass with num_cells = 64
# dname = WormsTwoClass, num_cells = 64, Test Accuracy = 0.6364, Test Loss = 1.8488
# Training WormsTwoClass with num_cells = 128
# dname = WormsTwoClass, num_cells = 128, Test Accuracy = 0.5974, Test Loss = 2.2612
# BEST: dname = WormsTwoClass, Best num_cells: 64, Test Accuracy: 0.6364, Test Loss: 1.8488
# WormsTwoClass best result appended successfully to LSTM_train_best_cell.csv
# Training on dataset: Yoga
# Training Yoga with num_cells = 8
# dname = Yoga, num_cells = 8, Test Accuracy = 0.8523, Test Loss = 0.6560
# Training Yoga with num_cells = 64
# dname = Yoga, num_cells = 64, Test Accuracy = 0.8507, Test Loss = 0.7067
# Training Yoga with num_cells = 128
# dname = Yoga, num_cells = 128, Test Accuracy = 0.8237, Test Loss = 0.7700
# BEST: dname = Yoga, Best num_cells: 8, Test Accuracy: 0.8523, Test Loss: 0.6560
# Yoga best result appended successfully to LSTM_train_best_cell.csv

# %%
# move the models in this round of training to another folder
# to make space for next round of training.
current_path = "./models"
to_path = "./models/hyper_search"

move_files(current_path,to_path)
# Out:
# Moved: LSTM__TwoLeadECG__8.keras
# Moved: LSTM__FiftyWords__8.keras
# Moved: LSTM__Haptics__64.keras
# Moved: LSTM__DiatomSizeReduction__128.keras
# Moved: LSTM__PLAID__128.keras
# Moved: LSTM__MixedShapesRegularTrain__128.keras
# Moved: LSTM__Worms__64.keras
# Moved: LSTM__EOGVerticalSignal__128.keras
# Moved: LSTM__GunPoint__64.keras
# Moved: LSTM__ShapesAll__8.keras
# Moved: LSTM__InlineSkate__8.keras
# Moved: LSTM__CinCECGTorso__128.keras
# Moved: LSTM__EOGHorizontalSignal__8.keras
# Moved: LSTM__SonyAIBORobotSurface2__64.keras
# Moved: LSTM__UMD__8.keras
# Moved: LSTM__GestureMidAirD3__64.keras
# Moved: LSTM__Yoga__8.keras
# Moved: LSTM__ToeSegmentation2__128.keras
# Moved: LSTM__Fungi__8.keras
# Moved: LSTM__BirdChicken__64.keras
# Moved: LSTM__Adiac__8.keras
# Moved: LSTM__Mallat__64.keras
# Moved: LSTM__Symbols__8.keras
# Moved: LSTM__PigAirwayPressure__8.keras
# Moved: LSTM__MixedShapesSmallTrain__128.keras
# Moved: LSTM__Plane__8.keras
# Moved: LSTM__InsectEPGSmallTrain__8.keras
# Moved: LSTM__ProximalPhalanxOutlineCorrect__8.keras
# Moved: LSTM__Car__8.keras
# Moved: LSTM__OSULeaf__8.keras
# Moved: LSTM__ShakeGestureWiimoteZ__8.keras
# Moved: LSTM__Coffee__128.keras
# Moved: LSTM__ShapesAll__128.keras
# Moved: LSTM__GunPointAgeSpan__8.keras
# Moved: LSTM__DistalPhalanxOutlineAgeGroup__128.keras
# Moved: LSTM__PhalangesOutlinesCorrect__8.keras
# Moved: LSTM__BirdChicken__8.keras
# Moved: LSTM__Phoneme__8.keras
# Moved: LSTM__MiddlePhalanxOutlineAgeGroup__8.keras
# Moved: LSTM__CricketZ__64.keras
# Moved: LSTM__BeetleFly__64.keras
# Moved: LSTM__MedicalImages__64.keras
# Moved: LSTM__Wine__128.keras
# Moved: LSTM__PigCVP__64.keras
# Moved: LSTM__CinCECGTorso__8.keras
# Moved: LSTM__AllGestureWiimoteY__128.keras
# Moved: LSTM__Computers__64.keras
# Moved: LSTM__SemgHandMovementCh2__8.keras
# Moved: LSTM__FreezerRegularTrain__128.keras
# Moved: LSTM__DistalPhalanxOutlineCorrect__128.keras
# Moved: LSTM__ShapesAll__64.keras
# Moved: LSTM__FreezerSmallTrain__128.keras
# Moved: LSTM__DistalPhalanxTW__64.keras
# Moved: LSTM__TwoLeadECG__128.keras
# Moved: LSTM__AllGestureWiimoteX__64.keras
# Moved: LSTM__Worms__128.keras
# Moved: LSTM__MixedShapesSmallTrain__64.keras
# Moved: LSTM__Rock__8.keras
# Moved: LSTM__EOGHorizontalSignal__64.keras
# Moved: LSTM__MixedShapesRegularTrain__8.keras
# Moved: LSTM__Phoneme__64.keras
# Moved: LSTM__ECG5000__64.keras
# Moved: LSTM__Herring__128.keras
# Moved: LSTM__DistalPhalanxTW__128.keras
# Moved: LSTM__FaceFour__8.keras
# Moved: LSTM__GunPointOldVersusYoung__64.keras
# Moved: LSTM__ECG200__8.keras
# Moved: LSTM__ElectricDevices__64.keras
# Moved: LSTM__AllGestureWiimoteZ__8.keras
# Moved: LSTM__PigAirwayPressure__128.keras
# Moved: LSTM__Lightning7__8.keras
# Moved: LSTM__InlineSkate__64.keras
# Moved: LSTM__UWaveGestureLibraryX__64.keras
# Moved: LSTM__InlineSkate__128.keras
# Moved: LSTM__Lightning7__64.keras
# Moved: LSTM__Ham__128.keras
# Moved: LSTM__NonInvasiveFetalECGThorax2__8.keras
# Moved: LSTM__ScreenType__128.keras
# Moved: LSTM__Computers__128.keras
# Moved: LSTM__PowerCons__8.keras
# Moved: LSTM__InsectEPGRegularTrain__8.keras
# Moved: LSTM__GunPoint__8.keras
# Moved: LSTM__BME__8.keras
# Moved: LSTM__EOGVerticalSignal__8.keras
# Moved: LSTM__DodgerLoopGame__64.keras
# Moved: LSTM__Plane__64.keras
# Moved: LSTM__HandOutlines__64.keras
# Moved: LSTM__PhalangesOutlinesCorrect__128.keras
# Moved: LSTM__GunPointAgeSpan__64.keras
# Moved: LSTM__ItalyPowerDemand__8.keras
# Moved: LSTM__FaceAll__8.keras
# Moved: LSTM__UWaveGestureLibraryZ__64.keras
# Moved: LSTM__CricketZ__128.keras
# Moved: LSTM__BirdChicken__128.keras
# Moved: LSTM__SemgHandGenderCh2__128.keras
# Moved: LSTM__SmallKitchenAppliances__8.keras
# Moved: LSTM__GunPoint__128.keras
# Moved: LSTM__GestureMidAirD2__8.keras
# Moved: LSTM__WordSynonyms__128.keras
# Moved: LSTM__LargeKitchenAppliances__8.keras
# Moved: LSTM__Beef__8.keras
# Moved: LSTM__SwedishLeaf__128.keras
# Moved: LSTM__Meat__64.keras
# Moved: LSTM__Yoga__128.keras
# Moved: LSTM__Haptics__128.keras
# Moved: LSTM__SwedishLeaf__8.keras
# Moved: LSTM__Ham__64.keras
# Moved: LSTM__ProximalPhalanxTW__128.keras
# Moved: LSTM__ShapeletSim__8.keras
# Moved: LSTM__Crop__64.keras
# Moved: LSTM__DodgerLoopGame__8.keras
# Moved: LSTM__AllGestureWiimoteY__8.keras
# Moved: LSTM__Car__64.keras
# Moved: LSTM__MelbournePedestrian__128.keras
# Moved: LSTM__ScreenType__64.keras
# Moved: LSTM__GunPointOldVersusYoung__128.keras
# Moved: LSTM__ProximalPhalanxOutlineAgeGroup__128.keras
# Moved: LSTM__SemgHandGenderCh2__64.keras
# Moved: LSTM__GunPointOldVersusYoung__8.keras
# Moved: LSTM__GunPointMaleVersusFemale__128.keras
# Moved: LSTM__DiatomSizeReduction__8.keras
# Moved: LSTM__CricketX__128.keras
# Moved: LSTM__NonInvasiveFetalECGThorax2__64.keras
# Moved: LSTM__InsectEPGRegularTrain__128.keras
# Moved: LSTM__Trace__128.keras
# Moved: LSTM__UWaveGestureLibraryAll__8.keras
# Moved: LSTM__ShakeGestureWiimoteZ__128.keras
# Moved: LSTM__CinCECGTorso__64.keras
# Moved: LSTM__Plane__128.keras
# Moved: LSTM__SonyAIBORobotSurface1__64.keras
# Moved: LSTM__Earthquakes__64.keras
# Moved: LSTM__Adiac__64.keras
# Moved: LSTM__OliveOil__64.keras
# Moved: LSTM__Beef__64.keras
# Moved: LSTM__Strawberry__8.keras
# Moved: LSTM__Rock__128.keras
# Moved: LSTM__MelbournePedestrian__8.keras
# Moved: LSTM__DodgerLoopWeekend__128.keras
# Moved: LSTM__ProximalPhalanxOutlineCorrect__128.keras
# Moved: LSTM__LargeKitchenAppliances__128.keras
# Moved: LSTM__Fungi__128.keras
# Moved: LSTM__DodgerLoopGame__128.keras
# Moved: LSTM__WormsTwoClass__8.keras
# Moved: LSTM__DistalPhalanxOutlineAgeGroup__64.keras
# Moved: LSTM__WormsTwoClass__128.keras
# Moved: LSTM__EthanolLevel__128.keras
# Moved: LSTM__MiddlePhalanxTW__8.keras
# Moved: LSTM__Haptics__8.keras
# Moved: LSTM__FordB__64.keras
# Moved: LSTM__CricketY__128.keras
# Moved: LSTM__MixedShapesSmallTrain__8.keras
# Moved: LSTM__PLAID__64.keras
# Moved: LSTM__TwoPatterns__128.keras
# Moved: LSTM__BeetleFly__128.keras
# Moved: LSTM__FreezerSmallTrain__8.keras
# Moved: LSTM__Lightning2__8.keras
# Moved: LSTM__DodgerLoopWeekend__64.keras
# Moved: LSTM__SemgHandMovementCh2__128.keras
# Moved: LSTM__DiatomSizeReduction__64.keras
# Moved: LSTM__RefrigerationDevices__8.keras
# Moved: LSTM__SyntheticControl__64.keras
# Moved: LSTM__PowerCons__64.keras
# Moved: LSTM__Beef__128.keras
# Moved: LSTM__DistalPhalanxOutlineCorrect__64.keras
# Moved: LSTM__ECGFiveDays__8.keras
# Moved: LSTM__ArrowHead__128.keras
# Moved: LSTM__DodgerLoopWeekend__8.keras
# Moved: LSTM__FacesUCR__128.keras
# Moved: LSTM__DodgerLoopDay__128.keras
# Moved: LSTM__CricketY__8.keras
# Moved: LSTM__Wafer__8.keras
# Moved: LSTM__GesturePebbleZ1__64.keras
# Moved: LSTM__NonInvasiveFetalECGThorax1__128.keras
# Moved: LSTM__CBF__8.keras
# Moved: LSTM__HandOutlines__8.keras
# Moved: LSTM__ProximalPhalanxOutlineCorrect__64.keras
# Moved: LSTM__ChlorineConcentration__8.keras
# Moved: LSTM__ProximalPhalanxOutlineAgeGroup__8.keras
# Moved: LSTM__Earthquakes__128.keras
# Moved: LSTM__UMD__128.keras
# Moved: LSTM__BeetleFly__8.keras
# Moved: LSTM__GesturePebbleZ1__128.keras
# Moved: LSTM__MiddlePhalanxOutlineAgeGroup__128.keras
# Moved: LSTM__Meat__128.keras
# Moved: LSTM__EthanolLevel__8.keras
# Moved: LSTM__InsectWingbeatSound__64.keras
# Moved: LSTM__Crop__8.keras
# Moved: LSTM__SmoothSubspace__128.keras
# Moved: LSTM__HouseTwenty__128.keras
# Moved: LSTM__ToeSegmentation2__8.keras
# Moved: LSTM__NonInvasiveFetalECGThorax2__128.keras
# Moved: LSTM__SemgHandSubjectCh2__128.keras
# Moved: LSTM__FordA__128.keras
# Moved: LSTM__FaceAll__64.keras
# Moved: LSTM__MiddlePhalanxTW__128.keras
# Moved: LSTM__FiftyWords__64.keras
# Moved: LSTM__ArrowHead__64.keras
# Moved: LSTM__UWaveGestureLibraryY__128.keras
# Moved: LSTM__FacesUCR__8.keras
# Moved: LSTM__Crop__128.keras
# Moved: LSTM__Lightning2__64.keras
# Moved: LSTM__SmallKitchenAppliances__64.keras
# Moved: LSTM__Adiac__128.keras
# Moved: LSTM__HouseTwenty__8.keras
# Moved: LSTM__Lightning2__128.keras
# Moved: LSTM__Earthquakes__8.keras
# Moved: LSTM__SemgHandSubjectCh2__64.keras
# Moved: LSTM__GunPointMaleVersusFemale__64.keras
# Moved: LSTM__DistalPhalanxOutlineAgeGroup__8.keras
# Moved: LSTM__InsectWingbeatSound__8.keras
# Moved: LSTM__LargeKitchenAppliances__64.keras
# Moved: LSTM__Trace__8.keras
# Moved: LSTM__ProximalPhalanxTW__64.keras
# Moved: LSTM__OliveOil__8.keras
# Moved: LSTM__CBF__128.keras
# Moved: LSTM__CricketY__64.keras
# Moved: LSTM__Yoga__64.keras
# Moved: LSTM__SemgHandGenderCh2__8.keras
# Moved: LSTM__InsectEPGSmallTrain__64.keras
# Moved: LSTM__ToeSegmentation1__128.keras
# Moved: LSTM__BME__64.keras
# Moved: LSTM__ACSF1__128.keras
# Moved: LSTM__Wine__8.keras
# Moved: LSTM__FreezerSmallTrain__64.keras
# Moved: LSTM__UWaveGestureLibraryX__8.keras
# Moved: LSTM__GestureMidAirD1__8.keras
# Moved: LSTM__GesturePebbleZ2__128.keras
# Moved: LSTM__UWaveGestureLibraryY__8.keras
# Moved: LSTM__InsectEPGRegularTrain__64.keras
# Moved: LSTM__PowerCons__128.keras
# Moved: LSTM__UWaveGestureLibraryAll__64.keras
# Moved: LSTM__SemgHandSubjectCh2__8.keras
# Moved: LSTM__ItalyPowerDemand__128.keras
# Moved: LSTM__SonyAIBORobotSurface2__8.keras
# Moved: LSTM__TwoPatterns__8.keras
# Moved: LSTM__FaceAll__128.keras
# Moved: LSTM__Coffee__8.keras
# Moved: LSTM__Car__128.keras
# Moved: LSTM__FordA__64.keras
# Moved: LSTM__StarLightCurves__128.keras
# Moved: LSTM__ECGFiveDays__64.keras
# Moved: LSTM__FaceFour__128.keras
# Moved: LSTM__DodgerLoopDay__64.keras
# Moved: LSTM__Chinatown__8.keras
# Moved: LSTM__GestureMidAirD3__8.keras
# Moved: LSTM__PLAID__8.keras
# Moved: LSTM__InsectEPGSmallTrain__128.keras
# Moved: LSTM__SmallKitchenAppliances__128.keras
# Moved: LSTM__FordA__8.keras
# Moved: LSTM__UWaveGestureLibraryY__64.keras
# Moved: LSTM__Wine__64.keras
# Moved: LSTM__ArrowHead__8.keras
# Moved: LSTM__RefrigerationDevices__128.keras
# Moved: LSTM__FordB__128.keras
# Moved: LSTM__DodgerLoopDay__8.keras
# Moved: LSTM__MiddlePhalanxOutlineCorrect__8.keras
# Moved: LSTM__PhalangesOutlinesCorrect__64.keras
# Moved: LSTM__Chinatown__64.keras
# Moved: LSTM__Fish__64.keras
# Moved: LSTM__ShapeletSim__64.keras
# Moved: LSTM__Wafer__64.keras
# Moved: LSTM__PickupGestureWiimoteZ__64.keras
# Moved: LSTM__TwoPatterns__64.keras
# Moved: LSTM__NonInvasiveFetalECGThorax1__8.keras
# Moved: LSTM__ProximalPhalanxTW__8.keras
# Moved: LSTM__ItalyPowerDemand__64.keras
# Moved: LSTM__GestureMidAirD2__128.keras
# Moved: LSTM__MiddlePhalanxTW__64.keras
# Moved: LSTM__ProximalPhalanxOutlineAgeGroup__64.keras
# Moved: LSTM__UWaveGestureLibraryZ__8.keras
# Moved: LSTM__Mallat__8.keras
# Moved: LSTM__UWaveGestureLibraryX__128.keras
# Moved: LSTM__RefrigerationDevices__64.keras
# Moved: LSTM__SmoothSubspace__64.keras
# Moved: LSTM__SemgHandMovementCh2__64.keras
# Moved: LSTM__WormsTwoClass__64.keras
# Moved: LSTM__Worms__8.keras
# Moved: LSTM__ECG5000__8.keras
# Moved: LSTM__Trace__64.keras
# Moved: LSTM__Coffee__64.keras
# Moved: LSTM__ShakeGestureWiimoteZ__64.keras
# Moved: LSTM__Rock__64.keras
# Moved: LSTM__CricketX__64.keras
# Moved: LSTM__FaceFour__64.keras
# Moved: LSTM__OliveOil__128.keras
# Moved: LSTM__Herring__64.keras
# Moved: LSTM__GesturePebbleZ2__64.keras
# Moved: LSTM__AllGestureWiimoteX__128.keras
# Moved: LSTM__MixedShapesRegularTrain__64.keras
# Moved: LSTM__SonyAIBORobotSurface1__8.keras
# Moved: LSTM__GestureMidAirD1__64.keras
# Moved: LSTM__FreezerRegularTrain__64.keras
# Moved: LSTM__SmoothSubspace__8.keras
# Moved: LSTM__SonyAIBORobotSurface2__128.keras
# Moved: LSTM__EthanolLevel__64.keras
# Moved: LSTM__SwedishLeaf__64.keras
# Moved: LSTM__GestureMidAirD1__128.keras
# Moved: LSTM__PigCVP__8.keras
# Moved: LSTM__AllGestureWiimoteY__64.keras
# Moved: LSTM__Computers__8.keras
# Moved: LSTM__ToeSegmentation2__64.keras
# Moved: LSTM__TwoLeadECG__64.keras
# Moved: LSTM__PigArtPressure__128.keras
# Moved: LSTM__HouseTwenty__64.keras
# Moved: LSTM__Chinatown__128.keras
# Moved: LSTM__FordB__8.keras
# Moved: LSTM__Strawberry__128.keras
# Moved: LSTM__EOGHorizontalSignal__128.keras
# Moved: LSTM__Fungi__64.keras
# Moved: LSTM__MoteStrain__64.keras
# Moved: LSTM__ShapeletSim__128.keras
# Moved: LSTM__GunPointAgeSpan__128.keras
# Moved: LSTM__SonyAIBORobotSurface1__128.keras
# Moved: LSTM__CricketX__8.keras
# Moved: LSTM__ACSF1__64.keras
# Moved: LSTM__WordSynonyms__64.keras
# Moved: LSTM__PickupGestureWiimoteZ__128.keras
# Moved: LSTM__SyntheticControl__128.keras
# Moved: LSTM__EOGVerticalSignal__64.keras
# Moved: LSTM__ElectricDevices__128.keras
# Moved: LSTM__SyntheticControl__8.keras
# Moved: LSTM__ECG200__64.keras
# Moved: LSTM__InsectWingbeatSound__128.keras
# Moved: LSTM__MedicalImages__128.keras
# Moved: LSTM__MiddlePhalanxOutlineCorrect__64.keras
# Moved: LSTM__ChlorineConcentration__64.keras
# Moved: LSTM__MiddlePhalanxOutlineAgeGroup__64.keras
# Moved: LSTM__ElectricDevices__8.keras
# Moved: LSTM__UMD__64.keras
# Moved: LSTM__GestureMidAirD2__64.keras
# Moved: LSTM__ToeSegmentation1__64.keras
# Moved: LSTM__PigArtPressure__64.keras
# Moved: LSTM__FreezerRegularTrain__8.keras
# Moved: LSTM__HandOutlines__128.keras
# Moved: LSTM__Symbols__64.keras
# Moved: LSTM__MoteStrain__128.keras
# Moved: LSTM__CBF__64.keras
# Moved: LSTM__AllGestureWiimoteZ__128.keras
# Moved: LSTM__Ham__8.keras
# Moved: LSTM__Fish__8.keras
# Moved: LSTM__Strawberry__64.keras
# Moved: LSTM__ECG5000__128.keras
# Moved: LSTM__StarLightCurves__8.keras
# Moved: LSTM__Herring__8.keras
# Moved: LSTM__ToeSegmentation1__8.keras
# Moved: LSTM__MiddlePhalanxOutlineCorrect__128.keras
# Moved: LSTM__GestureMidAirD3__128.keras
# Moved: LSTM__MedicalImages__8.keras
# Moved: LSTM__NonInvasiveFetalECGThorax1__64.keras
# Moved: LSTM__AllGestureWiimoteX__8.keras
# Moved: LSTM__Fish__128.keras
# Moved: LSTM__MoteStrain__8.keras
# Moved: LSTM__AllGestureWiimoteZ__64.keras
# Moved: LSTM__PickupGestureWiimoteZ__8.keras
# Moved: LSTM__Symbols__128.keras
# Moved: LSTM__ECG200__128.keras
# Moved: LSTM__Phoneme__128.keras
# Moved: LSTM__Wafer__128.keras
# Moved: LSTM__Mallat__128.keras
# Moved: LSTM__ChlorineConcentration__128.keras
# Moved: LSTM__Lightning7__128.keras
# Moved: LSTM__MelbournePedestrian__64.keras
# Moved: LSTM__UWaveGestureLibraryZ__128.keras
# Moved: LSTM__GesturePebbleZ2__8.keras
# Moved: LSTM__GunPointMaleVersusFemale__8.keras
# Moved: LSTM__CricketZ__8.keras
# Moved: LSTM__DistalPhalanxOutlineCorrect__8.keras
# Moved: LSTM__ECGFiveDays__128.keras
# Moved: LSTM__FacesUCR__64.keras
# Moved: LSTM__OSULeaf__128.keras
# Moved: LSTM__ScreenType__8.keras
# Moved: LSTM__ACSF1__8.keras
# Moved: LSTM__DistalPhalanxTW__8.keras
# Moved: LSTM__PigCVP__128.keras
# Moved: LSTM__OSULeaf__64.keras
# Moved: LSTM__GesturePebbleZ1__8.keras
# Moved: LSTM__PigAirwayPressure__64.keras
# Moved: LSTM__BME__128.keras
# Moved: LSTM__WordSynonyms__8.keras
# Moved: LSTM__PigArtPressure__8.keras
# Moved: LSTM__UWaveGestureLibraryAll__128.keras
# Moved: LSTM__StarLightCurves__64.keras
# Moved: LSTM__Meat__8.keras
# Moved: LSTM__FiftyWords__128.keras
# All files have been moved.

# %%
#2nd train: for each dataset, train model with best cell number for 2000 epoches

#training parameter
model_name = 'LSTM' #LSTM or ALSTM
epochs = 2000
batch_size = 128
ucr_dir = "./data" #data folder location
file_path = f"{model_name}_train_2000_epoches.csv" # csv to save accuracy after this round of training

# %%
##### ATTENTION!!! 128 trained model of this step ↓, too large to upload to github
##### ATTENTION!!! so we only provide the model for Beef dataset for your reference
##### ATTENTION!!! you can try train any datasets in the 128 datasets
##### ATTENTION!!! we believe you will get similar result shown in our report!

# %%
##### NOTE: for your convinience, our output csv and model is directly saved in a safe location.
##### running the cell would create a csv and a models folder to save the output.(diffenrent models and csv!)
##### keras models is saved once 1 dataset is down training;
##### for csv, you will have to wait until all 128 datasets processed to see a complete one.
##### ↑you will have to wait super long for the csv, 180 mins for LSTM and 300 mins for ALSTM :<

# load record of best number of cells for each dataset of 200 epochs
# you need to finish the above 1st train to get the csv
# or you can change the directory to our saved csv for 1st train. No thanks!  
cell_record = pd.read_csv(f"{model_name}_train_best_cell.csv",encoding="UTF-8")
# iterate through 128 datasets and train
all_results_2000 = {}
for i in range(cell_record.shape[0]):
    dataset_name,num_cell,accuracy,loss,model_path = cell_record.iloc[i,:].values
    print(dataset_name, num_cell)
    num_cells_range = [num_cell]
    print(f"Training on dataset: {dataset_name}")
    best_num_cells, best_accuracy, best_loss,results,best_model_paths=train_lstm_fcn(model_name,
                                                                            dataset_name,
                                                                            ucr_dir,
                                                                            num_cells_range,
                                                                            epochs=epochs,
                                                                            batch_size = batch_size,
                                                                            verbose = 0)
    
    all_results_2000[dataset_name] = {
        "dataset_name" : dataset_name,
        "best_num_cells" : best_num_cells,
        "accuracy": best_accuracy,
        "loss": best_loss,
        "best_model_paths":best_model_paths
    }
    
    # append best result to a csv once the current dataset have done 
    save_best_result(file_path, all_results_2000[dataset_name])
# Out:
# ShapesAll 128
# Training on dataset: ShapesAll
# Training ShapesAll with num_cells = 128
# dname = ShapesAll, num_cells = 128, Test Accuracy = 0.7683, Test Loss = 1.0846
# BEST: dname = ShapesAll, Best num_cells: 128, Test Accuracy: 0.7683, Test Loss: 1.0846
# ShapesAll best result appended successfully to LSTM_train_2000_epoches.csv
# SmallKitchenAppliances 8
# Training on dataset: SmallKitchenAppliances
# Training SmallKitchenAppliances with num_cells = 8
# dname = SmallKitchenAppliances, num_cells = 8, Test Accuracy = 0.3520, Test Loss = 1.0929
# BEST: dname = SmallKitchenAppliances, Best num_cells: 8, Test Accuracy: 0.3520, Test Loss: 1.0929
# SmallKitchenAppliances best result appended successfully to LSTM_train_2000_epoches.csv
# SmoothSubspace 8
# Training on dataset: SmoothSubspace
# Training SmoothSubspace with num_cells = 8
# dname = SmoothSubspace, num_cells = 8, Test Accuracy = 0.9000, Test Loss = 0.2320
# BEST: dname = SmoothSubspace, Best num_cells: 8, Test Accuracy: 0.9000, Test Loss: 0.2320
# SmoothSubspace best result appended successfully to LSTM_train_2000_epoches.csv
# SonyAIBORobotSurface1 8
# Training on dataset: SonyAIBORobotSurface1
# Training SonyAIBORobotSurface1 with num_cells = 8
# dname = SonyAIBORobotSurface1, num_cells = 8, Test Accuracy = 0.5907, Test Loss = 0.6564
# BEST: dname = SonyAIBORobotSurface1, Best num_cells: 8, Test Accuracy: 0.5907, Test Loss: 0.6564
# SonyAIBORobotSurface1 best result appended successfully to LSTM_train_2000_epoches.csv
# SonyAIBORobotSurface2 8
# Training on dataset: SonyAIBORobotSurface2
# Training SonyAIBORobotSurface2 with num_cells = 8
# dname = SonyAIBORobotSurface2, num_cells = 8, Test Accuracy = 0.8164, Test Loss = 0.3712
# BEST: dname = SonyAIBORobotSurface2, Best num_cells: 8, Test Accuracy: 0.8164, Test Loss: 0.3712
# SonyAIBORobotSurface2 best result appended successfully to LSTM_train_2000_epoches.csv
# StarLightCurves 64
# Training on dataset: StarLightCurves
# Training StarLightCurves with num_cells = 64
# dname = StarLightCurves, num_cells = 64, Test Accuracy = 0.9507, Test Loss = 0.2136
# BEST: dname = StarLightCurves, Best num_cells: 64, Test Accuracy: 0.9507, Test Loss: 0.2136
# StarLightCurves best result appended successfully to LSTM_train_2000_epoches.csv
# Strawberry 128
# Training on dataset: Strawberry
# Training Strawberry with num_cells = 128
# dname = Strawberry, num_cells = 128, Test Accuracy = 0.9730, Test Loss = 0.1187
# BEST: dname = Strawberry, Best num_cells: 128, Test Accuracy: 0.9730, Test Loss: 0.1187
# Strawberry best result appended successfully to LSTM_train_2000_epoches.csv
# SwedishLeaf 64
# Training on dataset: SwedishLeaf
# Training SwedishLeaf with num_cells = 64
# dname = SwedishLeaf, num_cells = 64, Test Accuracy = 0.8992, Test Loss = 0.3538
# BEST: dname = SwedishLeaf, Best num_cells: 64, Test Accuracy: 0.8992, Test Loss: 0.3538
# SwedishLeaf best result appended successfully to LSTM_train_2000_epoches.csv
# Symbols 128
# Training on dataset: Symbols
# Training Symbols with num_cells = 128
# dname = Symbols, num_cells = 128, Test Accuracy = 0.8312, Test Loss = 0.4510
# BEST: dname = Symbols, Best num_cells: 128, Test Accuracy: 0.8312, Test Loss: 0.4510
# Symbols best result appended successfully to LSTM_train_2000_epoches.csv
# SyntheticControl 64
# Training on dataset: SyntheticControl
# Training SyntheticControl with num_cells = 64
# dname = SyntheticControl, num_cells = 64, Test Accuracy = 0.9467, Test Loss = 0.1471
# BEST: dname = SyntheticControl, Best num_cells: 64, Test Accuracy: 0.9467, Test Loss: 0.1471
# SyntheticControl best result appended successfully to LSTM_train_2000_epoches.csv
# ToeSegmentation1 128
# Training on dataset: ToeSegmentation1
# Training ToeSegmentation1 with num_cells = 128
# dname = ToeSegmentation1, num_cells = 128, Test Accuracy = 0.6140, Test Loss = 0.6618
# BEST: dname = ToeSegmentation1, Best num_cells: 128, Test Accuracy: 0.6140, Test Loss: 0.6618
# ToeSegmentation1 best result appended successfully to LSTM_train_2000_epoches.csv
# ToeSegmentation2 128
# Training on dataset: ToeSegmentation2
# Training ToeSegmentation2 with num_cells = 128
# dname = ToeSegmentation2, num_cells = 128, Test Accuracy = 0.7154, Test Loss = 0.5640
# BEST: dname = ToeSegmentation2, Best num_cells: 128, Test Accuracy: 0.7154, Test Loss: 0.5640
# ToeSegmentation2 best result appended successfully to LSTM_train_2000_epoches.csv
# Trace 8
# Training on dataset: Trace
# Training Trace with num_cells = 8
# dname = Trace, num_cells = 8, Test Accuracy = 0.4800, Test Loss = 0.9895
# BEST: dname = Trace, Best num_cells: 8, Test Accuracy: 0.4800, Test Loss: 0.9895
# Trace best result appended successfully to LSTM_train_2000_epoches.csv
# TwoLeadECG 8
# Training on dataset: TwoLeadECG
# Training TwoLeadECG with num_cells = 8
# dname = TwoLeadECG, num_cells = 8, Test Accuracy = 0.6076, Test Loss = 0.6316
# BEST: dname = TwoLeadECG, Best num_cells: 8, Test Accuracy: 0.6076, Test Loss: 0.6316
# TwoLeadECG best result appended successfully to LSTM_train_2000_epoches.csv
# TwoPatterns 64
# Training on dataset: TwoPatterns
# Training TwoPatterns with num_cells = 64
# dname = TwoPatterns, num_cells = 64, Test Accuracy = 0.8662, Test Loss = 0.3682
# BEST: dname = TwoPatterns, Best num_cells: 64, Test Accuracy: 0.8662, Test Loss: 0.3682
# TwoPatterns best result appended successfully to LSTM_train_2000_epoches.csv
# UMD 8
# Training on dataset: UMD
# Training UMD with num_cells = 8
# dname = UMD, num_cells = 8, Test Accuracy = 0.8611, Test Loss = 0.3584
# BEST: dname = UMD, Best num_cells: 8, Test Accuracy: 0.8611, Test Loss: 0.3584
# UMD best result appended successfully to LSTM_train_2000_epoches.csv
# UWaveGestureLibraryAll 8
# Training on dataset: UWaveGestureLibraryAll
# Training UWaveGestureLibraryAll with num_cells = 8
# dname = UWaveGestureLibraryAll, num_cells = 8, Test Accuracy = 0.9517, Test Loss = 0.1708
# BEST: dname = UWaveGestureLibraryAll, Best num_cells: 8, Test Accuracy: 0.9517, Test Loss: 0.1708
# UWaveGestureLibraryAll best result appended successfully to LSTM_train_2000_epoches.csv
# UWaveGestureLibraryX 64
# Training on dataset: UWaveGestureLibraryX
# Training UWaveGestureLibraryX with num_cells = 64
# dname = UWaveGestureLibraryX, num_cells = 64, Test Accuracy = 0.7772, Test Loss = 0.6781
# BEST: dname = UWaveGestureLibraryX, Best num_cells: 64, Test Accuracy: 0.7772, Test Loss: 0.6781
# UWaveGestureLibraryX best result appended successfully to LSTM_train_2000_epoches.csv
# UWaveGestureLibraryY 64
# Training on dataset: UWaveGestureLibraryY
# Training UWaveGestureLibraryY with num_cells = 64
# dname = UWaveGestureLibraryY, num_cells = 64, Test Accuracy = 0.6834, Test Loss = 0.8685
# BEST: dname = UWaveGestureLibraryY, Best num_cells: 64, Test Accuracy: 0.6834, Test Loss: 0.8685
# UWaveGestureLibraryY best result appended successfully to LSTM_train_2000_epoches.csv
# UWaveGestureLibraryZ 8
# Training on dataset: UWaveGestureLibraryZ
# Training UWaveGestureLibraryZ with num_cells = 8
# dname = UWaveGestureLibraryZ, num_cells = 8, Test Accuracy = 0.7016, Test Loss = 0.8427
# BEST: dname = UWaveGestureLibraryZ, Best num_cells: 8, Test Accuracy: 0.7016, Test Loss: 0.8427
# UWaveGestureLibraryZ best result appended successfully to LSTM_train_2000_epoches.csv
# Wafer 8
# Training on dataset: Wafer
# Training Wafer with num_cells = 8
# dname = Wafer, num_cells = 8, Test Accuracy = 0.9961, Test Loss = 0.0214
# BEST: dname = Wafer, Best num_cells: 8, Test Accuracy: 0.9961, Test Loss: 0.0214
# Wafer best result appended successfully to LSTM_train_2000_epoches.csv
# Wine 8
# Training on dataset: Wine
# Training Wine with num_cells = 8
# dname = Wine, num_cells = 8, Test Accuracy = 0.4444, Test Loss = 0.6918
# BEST: dname = Wine, Best num_cells: 8, Test Accuracy: 0.4444, Test Loss: 0.6918
# Wine best result appended successfully to LSTM_train_2000_epoches.csv
# WordSynonyms 128
# Training on dataset: WordSynonyms
# Training WordSynonyms with num_cells = 128
# dname = WordSynonyms, num_cells = 128, Test Accuracy = 0.5643, Test Loss = 1.7452
# BEST: dname = WordSynonyms, Best num_cells: 128, Test Accuracy: 0.5643, Test Loss: 1.7452
# WordSynonyms best result appended successfully to LSTM_train_2000_epoches.csv
# Worms 64
# Training on dataset: Worms
# Training Worms with num_cells = 64
# dname = Worms, num_cells = 64, Test Accuracy = 0.4416, Test Loss = 1.4629
# BEST: dname = Worms, Best num_cells: 64, Test Accuracy: 0.4416, Test Loss: 1.4629
# Worms best result appended successfully to LSTM_train_2000_epoches.csv
# WormsTwoClass 64
# Training on dataset: WormsTwoClass
# Training WormsTwoClass with num_cells = 64
# dname = WormsTwoClass, num_cells = 64, Test Accuracy = 0.6234, Test Loss = 0.6353
# BEST: dname = WormsTwoClass, Best num_cells: 64, Test Accuracy: 0.6234, Test Loss: 0.6353
# WormsTwoClass best result appended successfully to LSTM_train_2000_epoches.csv
# Yoga 8
# Training on dataset: Yoga
# Training Yoga with num_cells = 8
# dname = Yoga, num_cells = 8, Test Accuracy = 0.8037, Test Loss = 0.4457
# BEST: dname = Yoga, Best num_cells: 8, Test Accuracy: 0.8037, Test Loss: 0.4457
# Yoga best result appended successfully to LSTM_train_2000_epoches.csv

# %%
# 3rd training: fine-tuning according to the paper
# fine_tune() uses load_ucr_dataset() in it


#parameters used for training
model_name = "LSTM" #LSTM or ALSTM
ucr_dir = "./data"
ini_lr = 1e-3
epochs = 50
ini_batch_size = 128
k = 5 # number of iterations
file_path = f"{model_name}__finetune.csv" # csv to save accuracy after this round of training

# %%
##### ATTENTION!!! 128 trained model of this step ↓, too large to upload to github
##### ATTENTION!!! so we only provide the model for Beef dataset for your reference
##### ATTENTION!!! you can try train any datasets in the 128 datasets
##### ATTENTION!!! we believe you will get similar result shown in our report!

# %%
##### NOTE: for your convinience, our output csv and model is directly saved in a safe location.
##### running the cell would create a csv and a models folder to save the output.(diffenrent models and csv!)
##### keras models is saved once 1 dataset is down training;
##### for csv, you will have to wait until all 128 datasets processed to see a complete one.
##### ↑you will have to wait super long for the csv, 60 mins for LSTM and 90 mins for ALSTM :<

# record of trained model for each dataset
# you need to finish the above 2nd train to get the csv
# or you can change the directory to our saved csv for 2nd train. No thanks!
trained_model = pd.read_csv( f"{model_name}_train_2000_epoches.csv",encoding = "UTF-8")
all_results_finetune = {}
#iterate through the 128 datasets and finetune
for i in range(trained_model.shape[0]):
    dataset_name,num_cell,accuracy,loss,model_path = trained_model.iloc[i,:].values
    print(f"Training on dataset: {dataset_name}")
    # don't move the 2nd train .keras model before you finish 3rd finetune! or our function would lose input :D
    # the fintuned models will be saved in the ./models/finetune directory directly.
    # Oh! to mention, we save the fintuned models for all k iterations for all 128 datasets
    # for each datasets only 1 out of k finetuned models is the best finetuned model (accuracy saved in csv)
    # please check which iteration best model belongs to in csv :D 
    best_iteration, best_accuracy, best_loss,best_model_paths= fine_tune_model(model_name,
                                                                                      dataset_name,
                                                                                      model_path,
                                                                                      ucr_dir,
                                                                                      initial_lr=ini_lr, 
                                                                                      initial_batch_size=ini_batch_size,
                                                                                      k=k, 
                                                                                      epochs_per_iteration= epochs, 
                                                                                      verbose = 0)
    all_results_finetune[dataset_name] = {
        "dataset_name" : dataset_name,
        "best_iteration" : best_iteration,
        "accuracy": best_accuracy,
        "loss": best_loss,
        "best_model_paths":best_model_paths
    }
    
    # append best result to a csv once the current dataset have done 
    save_best_result(file_path, all_results_finetune[dataset_name])
# Out:
# Training on dataset: ACSF1
# Loaded model from ./models/LSTM__ACSF1__64.keras
# Fine-tuning iteration 1/5 for dataset ACSF1
# Iteration 1 - Validation Loss: 2.4199, Validation Accuracy: 0.2100
# Fine-tuning iteration 2/5 for dataset ACSF1
# Iteration 2 - Validation Loss: 2.8996, Validation Accuracy: 0.1800
# Fine-tuning iteration 3/5 for dataset ACSF1
# Iteration 3 - Validation Loss: 2.3052, Validation Accuracy: 0.2800
# Fine-tuning iteration 4/5 for dataset ACSF1
# Iteration 4 - Validation Loss: 3.4439, Validation Accuracy: 0.3700
# Fine-tuning iteration 5/5 for dataset ACSF1
# Iteration 5 - Validation Loss: 6.1096, Validation Accuracy: 0.3400
# BEST: dname = ACSF1, Best model appears at iteration: 4, Val Accuracy: 0.3700, Val Loss: 3.4439
# ACSF1 best result appended successfully to LSTM__finetune.csv
# Training on dataset: Adiac
# Loaded model from ./models/LSTM__Adiac__128.keras
# Fine-tuning iteration 1/5 for dataset Adiac
# Iteration 1 - Validation Loss: 7.8620, Validation Accuracy: 0.1100
# Fine-tuning iteration 2/5 for dataset Adiac
# Iteration 2 - Validation Loss: 1.6791, Validation Accuracy: 0.5064
# Fine-tuning iteration 3/5 for dataset Adiac
# Iteration 3 - Validation Loss: 1.2895, Validation Accuracy: 0.6215
# Fine-tuning iteration 4/5 for dataset Adiac
# Iteration 4 - Validation Loss: 1.1365, Validation Accuracy: 0.6752
# Fine-tuning iteration 5/5 for dataset Adiac
# Iteration 5 - Validation Loss: 0.7759, Validation Accuracy: 0.7775
# BEST: dname = Adiac, Best model appears at iteration: 5, Val Accuracy: 0.7775, Val Loss: 0.7759
# Adiac best result appended successfully to LSTM__finetune.csv
# Training on dataset: AllGestureWiimoteX
# Loaded model from ./models/LSTM__AllGestureWiimoteX__8.keras
# Fine-tuning iteration 1/5 for dataset AllGestureWiimoteX
# Iteration 1 - Validation Loss: 10.9823, Validation Accuracy: 0.1343
# Fine-tuning iteration 2/5 for dataset AllGestureWiimoteX
# Iteration 2 - Validation Loss: 12.4931, Validation Accuracy: 0.1171
# Fine-tuning iteration 3/5 for dataset AllGestureWiimoteX
# Iteration 3 - Validation Loss: 12.7310, Validation Accuracy: 0.1200
# Fine-tuning iteration 4/5 for dataset AllGestureWiimoteX
# Iteration 4 - Validation Loss: 14.3574, Validation Accuracy: 0.1157
# Fine-tuning iteration 5/5 for dataset AllGestureWiimoteX
# Iteration 5 - Validation Loss: 13.0237, Validation Accuracy: 0.1200
# BEST: dname = AllGestureWiimoteX, Best model appears at iteration: 1, Val Accuracy: 0.1343, Val Loss: 10.9823
# AllGestureWiimoteX best result appended successfully to LSTM__finetune.csv
# Training on dataset: AllGestureWiimoteY
# Loaded model from ./models/LSTM__AllGestureWiimoteY__8.keras
# Fine-tuning iteration 1/5 for dataset AllGestureWiimoteY
# Iteration 1 - Validation Loss: 8.1902, Validation Accuracy: 0.1043
# Fine-tuning iteration 2/5 for dataset AllGestureWiimoteY
# Iteration 2 - Validation Loss: 11.3937, Validation Accuracy: 0.1057
# Fine-tuning iteration 3/5 for dataset AllGestureWiimoteY
# Iteration 3 - Validation Loss: 11.6736, Validation Accuracy: 0.1286
# Fine-tuning iteration 4/5 for dataset AllGestureWiimoteY
# Iteration 4 - Validation Loss: 13.4589, Validation Accuracy: 0.1114
# Fine-tuning iteration 5/5 for dataset AllGestureWiimoteY
# Iteration 5 - Validation Loss: 14.1814, Validation Accuracy: 0.1086
# BEST: dname = AllGestureWiimoteY, Best model appears at iteration: 3, Val Accuracy: 0.1286, Val Loss: 11.6736
# AllGestureWiimoteY best result appended successfully to LSTM__finetune.csv
# Training on dataset: AllGestureWiimoteZ
# Loaded model from ./models/LSTM__AllGestureWiimoteZ__8.keras
# Fine-tuning iteration 1/5 for dataset AllGestureWiimoteZ
# Iteration 1 - Validation Loss: 2.9170, Validation Accuracy: 0.3514
# Fine-tuning iteration 2/5 for dataset AllGestureWiimoteZ
# Iteration 2 - Validation Loss: 4.1516, Validation Accuracy: 0.2786
# Fine-tuning iteration 3/5 for dataset AllGestureWiimoteZ
# Iteration 3 - Validation Loss: 3.5654, Validation Accuracy: 0.2614
# Fine-tuning iteration 4/5 for dataset AllGestureWiimoteZ
# Iteration 4 - Validation Loss: 4.1251, Validation Accuracy: 0.3071
# Fine-tuning iteration 5/5 for dataset AllGestureWiimoteZ
# Iteration 5 - Validation Loss: 4.1697, Validation Accuracy: 0.2700
# BEST: dname = AllGestureWiimoteZ, Best model appears at iteration: 1, Val Accuracy: 0.3514, Val Loss: 2.9170
# AllGestureWiimoteZ best result appended successfully to LSTM__finetune.csv
# Training on dataset: ArrowHead
# Loaded model from ./models/LSTM__ArrowHead__128.keras
# Fine-tuning iteration 1/5 for dataset ArrowHead
# Iteration 1 - Validation Loss: 1.2752, Validation Accuracy: 0.6343
# Fine-tuning iteration 2/5 for dataset ArrowHead
# Iteration 2 - Validation Loss: 1.9887, Validation Accuracy: 0.6343
# Fine-tuning iteration 3/5 for dataset ArrowHead
# Iteration 3 - Validation Loss: 2.2375, Validation Accuracy: 0.6400
# Fine-tuning iteration 4/5 for dataset ArrowHead
# Iteration 4 - Validation Loss: 1.9240, Validation Accuracy: 0.6629
# Fine-tuning iteration 5/5 for dataset ArrowHead
# Iteration 5 - Validation Loss: 1.8919, Validation Accuracy: 0.7143
# BEST: dname = ArrowHead, Best model appears at iteration: 5, Val Accuracy: 0.7143, Val Loss: 1.8919
# ArrowHead best result appended successfully to LSTM__finetune.csv
# Training on dataset: Beef
# Loaded model from ./models/LSTM__Beef__128.keras
# Fine-tuning iteration 1/5 for dataset Beef
# Iteration 1 - Validation Loss: 3.0707, Validation Accuracy: 0.5000
# Fine-tuning iteration 2/5 for dataset Beef
# Iteration 2 - Validation Loss: 1.4808, Validation Accuracy: 0.8000
# Fine-tuning iteration 3/5 for dataset Beef
# Iteration 3 - Validation Loss: 1.0194, Validation Accuracy: 0.8000
# Fine-tuning iteration 4/5 for dataset Beef
# Iteration 4 - Validation Loss: 0.7843, Validation Accuracy: 0.8333
# Fine-tuning iteration 5/5 for dataset Beef
# Iteration 5 - Validation Loss: 0.4947, Validation Accuracy: 0.8667
# BEST: dname = Beef, Best model appears at iteration: 5, Val Accuracy: 0.8667, Val Loss: 0.4947
# Beef best result appended successfully to LSTM__finetune.csv
# Training on dataset: BeetleFly
# Loaded model from ./models/LSTM__BeetleFly__128.keras
# Fine-tuning iteration 1/5 for dataset BeetleFly
# Iteration 1 - Validation Loss: 0.7555, Validation Accuracy: 0.8500
# Fine-tuning iteration 2/5 for dataset BeetleFly
# Iteration 2 - Validation Loss: 0.8630, Validation Accuracy: 0.8500
# Fine-tuning iteration 3/5 for dataset BeetleFly
# Iteration 3 - Validation Loss: 0.9057, Validation Accuracy: 0.8500
# Fine-tuning iteration 4/5 for dataset BeetleFly
# Iteration 4 - Validation Loss: 0.9398, Validation Accuracy: 0.8500
# Fine-tuning iteration 5/5 for dataset BeetleFly
# Iteration 5 - Validation Loss: 0.9571, Validation Accuracy: 0.8500
# BEST: dname = BeetleFly, Best model appears at iteration: 1, Val Accuracy: 0.8500, Val Loss: 0.7555
# BeetleFly best result appended successfully to LSTM__finetune.csv
# Training on dataset: BirdChicken
# Loaded model from ./models/LSTM__BirdChicken__8.keras
# Fine-tuning iteration 1/5 for dataset BirdChicken
# Iteration 1 - Validation Loss: 0.9322, Validation Accuracy: 0.6000
# Fine-tuning iteration 2/5 for dataset BirdChicken
# Iteration 2 - Validation Loss: 0.9922, Validation Accuracy: 0.7000
# Fine-tuning iteration 3/5 for dataset BirdChicken
# Iteration 3 - Validation Loss: 1.1010, Validation Accuracy: 0.7500
# Fine-tuning iteration 4/5 for dataset BirdChicken
# Iteration 4 - Validation Loss: 1.2494, Validation Accuracy: 0.7500
# Fine-tuning iteration 5/5 for dataset BirdChicken
# Iteration 5 - Validation Loss: 1.3999, Validation Accuracy: 0.7000
# BEST: dname = BirdChicken, Best model appears at iteration: 3, Val Accuracy: 0.7500, Val Loss: 1.1010
# BirdChicken best result appended successfully to LSTM__finetune.csv
# Training on dataset: BME
# Loaded model from ./models/LSTM__BME__64.keras
# Fine-tuning iteration 1/5 for dataset BME
# Iteration 1 - Validation Loss: 0.7319, Validation Accuracy: 0.9067
# Fine-tuning iteration 2/5 for dataset BME
# Iteration 2 - Validation Loss: 0.6770, Validation Accuracy: 0.9133
# Fine-tuning iteration 3/5 for dataset BME
# Iteration 3 - Validation Loss: 0.6804, Validation Accuracy: 0.9133
# Fine-tuning iteration 4/5 for dataset BME
# Iteration 4 - Validation Loss: 0.6757, Validation Accuracy: 0.9133
# Fine-tuning iteration 5/5 for dataset BME
# Iteration 5 - Validation Loss: 0.6746, Validation Accuracy: 0.9133
# BEST: dname = BME, Best model appears at iteration: 2, Val Accuracy: 0.9133, Val Loss: 0.6770
# BME best result appended successfully to LSTM__finetune.csv
# Training on dataset: Car
# Loaded model from ./models/LSTM__Car__128.keras
# Fine-tuning iteration 1/5 for dataset Car
# Iteration 1 - Validation Loss: 1.2946, Validation Accuracy: 0.8333
# Fine-tuning iteration 2/5 for dataset Car
# Iteration 2 - Validation Loss: 1.3263, Validation Accuracy: 0.8333
# Fine-tuning iteration 3/5 for dataset Car
# Iteration 3 - Validation Loss: 1.3862, Validation Accuracy: 0.8167
# Fine-tuning iteration 4/5 for dataset Car
# Iteration 4 - Validation Loss: 1.3841, Validation Accuracy: 0.8667
# Fine-tuning iteration 5/5 for dataset Car
# Iteration 5 - Validation Loss: 1.3745, Validation Accuracy: 0.8333
# BEST: dname = Car, Best model appears at iteration: 4, Val Accuracy: 0.8667, Val Loss: 1.3841
# Car best result appended successfully to LSTM__finetune.csv
# Training on dataset: CBF
# Loaded model from ./models/LSTM__CBF__128.keras
# Fine-tuning iteration 1/5 for dataset CBF
# Iteration 1 - Validation Loss: 0.5402, Validation Accuracy: 0.8711
# Fine-tuning iteration 2/5 for dataset CBF
# Iteration 2 - Validation Loss: 0.5742, Validation Accuracy: 0.8667
# Fine-tuning iteration 3/5 for dataset CBF
# Iteration 3 - Validation Loss: 0.5799, Validation Accuracy: 0.8667
# Fine-tuning iteration 4/5 for dataset CBF
# Iteration 4 - Validation Loss: 0.5858, Validation Accuracy: 0.8667
# Fine-tuning iteration 5/5 for dataset CBF
# Iteration 5 - Validation Loss: 0.5884, Validation Accuracy: 0.8678
# BEST: dname = CBF, Best model appears at iteration: 1, Val Accuracy: 0.8711, Val Loss: 0.5402
# CBF best result appended successfully to LSTM__finetune.csv
# Training on dataset: Chinatown
# Loaded model from ./models/LSTM__Chinatown__128.keras
# Fine-tuning iteration 1/5 for dataset Chinatown
# Iteration 1 - Validation Loss: 0.1041, Validation Accuracy: 0.9650
# Fine-tuning iteration 2/5 for dataset Chinatown
# Iteration 2 - Validation Loss: 0.1052, Validation Accuracy: 0.9650
# Fine-tuning iteration 3/5 for dataset Chinatown
# Iteration 3 - Validation Loss: 0.1046, Validation Accuracy: 0.9650
# Fine-tuning iteration 4/5 for dataset Chinatown
# Iteration 4 - Validation Loss: 0.1041, Validation Accuracy: 0.9650
# Fine-tuning iteration 5/5 for dataset Chinatown
# Iteration 5 - Validation Loss: 0.1035, Validation Accuracy: 0.9650
# BEST: dname = Chinatown, Best model appears at iteration: 1, Val Accuracy: 0.9650, Val Loss: 0.1041
# Chinatown best result appended successfully to LSTM__finetune.csv
# Training on dataset: ChlorineConcentration
# Loaded model from ./models/LSTM__ChlorineConcentration__8.keras
# Fine-tuning iteration 1/5 for dataset ChlorineConcentration
# Iteration 1 - Validation Loss: 0.4417, Validation Accuracy: 0.9029
# Fine-tuning iteration 2/5 for dataset ChlorineConcentration
# Iteration 2 - Validation Loss: 0.4884, Validation Accuracy: 0.9096
# Fine-tuning iteration 3/5 for dataset ChlorineConcentration
# Iteration 3 - Validation Loss: 0.7980, Validation Accuracy: 0.8117
# Fine-tuning iteration 4/5 for dataset ChlorineConcentration
# Iteration 4 - Validation Loss: 0.6360, Validation Accuracy: 0.8807
# Fine-tuning iteration 5/5 for dataset ChlorineConcentration
# Iteration 5 - Validation Loss: 0.4056, Validation Accuracy: 0.9135
# BEST: dname = ChlorineConcentration, Best model appears at iteration: 5, Val Accuracy: 0.9135, Val Loss: 0.4056
# ChlorineConcentration best result appended successfully to LSTM__finetune.csv
# Training on dataset: CinCECGTorso
# Loaded model from ./models/LSTM__CinCECGTorso__64.keras
# Fine-tuning iteration 1/5 for dataset CinCECGTorso
# Iteration 1 - Validation Loss: 0.7471, Validation Accuracy: 0.8616
# Fine-tuning iteration 2/5 for dataset CinCECGTorso
# Iteration 2 - Validation Loss: 0.8007, Validation Accuracy: 0.8601
# Fine-tuning iteration 3/5 for dataset CinCECGTorso
# Iteration 3 - Validation Loss: 0.8192, Validation Accuracy: 0.8572
# Fine-tuning iteration 4/5 for dataset CinCECGTorso
# Iteration 4 - Validation Loss: 0.8294, Validation Accuracy: 0.8536
# Fine-tuning iteration 5/5 for dataset CinCECGTorso
# Iteration 5 - Validation Loss: 0.8213, Validation Accuracy: 0.8587
# BEST: dname = CinCECGTorso, Best model appears at iteration: 1, Val Accuracy: 0.8616, Val Loss: 0.7471
# CinCECGTorso best result appended successfully to LSTM__finetune.csv
# Training on dataset: Coffee
# Loaded model from ./models/LSTM__Coffee__128.keras
# Fine-tuning iteration 1/5 for dataset Coffee
# Iteration 1 - Validation Loss: 0.0036, Validation Accuracy: 1.0000
# Fine-tuning iteration 2/5 for dataset Coffee
# Iteration 2 - Validation Loss: 0.0010, Validation Accuracy: 1.0000
# Fine-tuning iteration 3/5 for dataset Coffee
# Iteration 3 - Validation Loss: 0.0005, Validation Accuracy: 1.0000
# Fine-tuning iteration 4/5 for dataset Coffee
# Iteration 4 - Validation Loss: 0.0003, Validation Accuracy: 1.0000
# Fine-tuning iteration 5/5 for dataset Coffee
# Iteration 5 - Validation Loss: 0.0003, Validation Accuracy: 1.0000
# BEST: dname = Coffee, Best model appears at iteration: 1, Val Accuracy: 1.0000, Val Loss: 0.0036
# Coffee best result appended successfully to LSTM__finetune.csv
# Training on dataset: Computers
# Loaded model from ./models/LSTM__Computers__8.keras
# Fine-tuning iteration 1/5 for dataset Computers
# Iteration 1 - Validation Loss: 2.8893, Validation Accuracy: 0.5320
# Fine-tuning iteration 2/5 for dataset Computers
# Iteration 2 - Validation Loss: 3.1813, Validation Accuracy: 0.5280
# Fine-tuning iteration 3/5 for dataset Computers
# Iteration 3 - Validation Loss: 3.3972, Validation Accuracy: 0.5240
# Fine-tuning iteration 4/5 for dataset Computers
# Iteration 4 - Validation Loss: 3.3530, Validation Accuracy: 0.5520
# Fine-tuning iteration 5/5 for dataset Computers
# Iteration 5 - Validation Loss: 3.5835, Validation Accuracy: 0.5560
# BEST: dname = Computers, Best model appears at iteration: 5, Val Accuracy: 0.5560, Val Loss: 3.5835
# Computers best result appended successfully to LSTM__finetune.csv
# Training on dataset: CricketX
# Loaded model from ./models/LSTM__CricketX__8.keras
# Fine-tuning iteration 1/5 for dataset CricketX
# Iteration 1 - Validation Loss: 2.9042, Validation Accuracy: 0.4744
# Fine-tuning iteration 2/5 for dataset CricketX
# Iteration 2 - Validation Loss: 2.6278, Validation Accuracy: 0.5179
# Fine-tuning iteration 3/5 for dataset CricketX
# Iteration 3 - Validation Loss: 2.5230, Validation Accuracy: 0.5538
# Fine-tuning iteration 4/5 for dataset CricketX
# Iteration 4 - Validation Loss: 2.4620, Validation Accuracy: 0.5590
# Fine-tuning iteration 5/5 for dataset CricketX
# Iteration 5 - Validation Loss: 2.5022, Validation Accuracy: 0.5410
# BEST: dname = CricketX, Best model appears at iteration: 4, Val Accuracy: 0.5590, Val Loss: 2.4620
# CricketX best result appended successfully to LSTM__finetune.csv
# Training on dataset: CricketY
# Loaded model from ./models/LSTM__CricketY__8.keras
# Fine-tuning iteration 1/5 for dataset CricketY
# Iteration 1 - Validation Loss: 2.7808, Validation Accuracy: 0.5385
# Fine-tuning iteration 2/5 for dataset CricketY
# Iteration 2 - Validation Loss: 2.5621, Validation Accuracy: 0.5282
# Fine-tuning iteration 3/5 for dataset CricketY
# Iteration 3 - Validation Loss: 2.3834, Validation Accuracy: 0.5385
# Fine-tuning iteration 4/5 for dataset CricketY
# Iteration 4 - Validation Loss: 2.4824, Validation Accuracy: 0.5410
# Fine-tuning iteration 5/5 for dataset CricketY
# Iteration 5 - Validation Loss: 2.4542, Validation Accuracy: 0.5513
# BEST: dname = CricketY, Best model appears at iteration: 5, Val Accuracy: 0.5513, Val Loss: 2.4542
# CricketY best result appended successfully to LSTM__finetune.csv
# Training on dataset: CricketZ
# Loaded model from ./models/LSTM__CricketZ__128.keras
# Fine-tuning iteration 1/5 for dataset CricketZ
# Iteration 1 - Validation Loss: 2.4688, Validation Accuracy: 0.5821
# Fine-tuning iteration 2/5 for dataset CricketZ
# Iteration 2 - Validation Loss: 2.3732, Validation Accuracy: 0.5769
# Fine-tuning iteration 3/5 for dataset CricketZ
# Iteration 3 - Validation Loss: 2.4118, Validation Accuracy: 0.5769
# Fine-tuning iteration 4/5 for dataset CricketZ
# Iteration 4 - Validation Loss: 2.3891, Validation Accuracy: 0.5846
# Fine-tuning iteration 5/5 for dataset CricketZ
# Iteration 5 - Validation Loss: 2.4082, Validation Accuracy: 0.6000
# BEST: dname = CricketZ, Best model appears at iteration: 5, Val Accuracy: 0.6000, Val Loss: 2.4082
# CricketZ best result appended successfully to LSTM__finetune.csv
# Training on dataset: Crop
# Loaded model from ./models/LSTM__Crop__8.keras
# Fine-tuning iteration 1/5 for dataset Crop
# Iteration 1 - Validation Loss: 2.8208, Validation Accuracy: 0.7407
# Fine-tuning iteration 2/5 for dataset Crop
# Iteration 2 - Validation Loss: 2.8191, Validation Accuracy: 0.7405
# Fine-tuning iteration 3/5 for dataset Crop
# Iteration 3 - Validation Loss: 2.8209, Validation Accuracy: 0.7436
# Fine-tuning iteration 4/5 for dataset Crop
# Iteration 4 - Validation Loss: 2.8293, Validation Accuracy: 0.7486
# Fine-tuning iteration 5/5 for dataset Crop
# Iteration 5 - Validation Loss: 2.8248, Validation Accuracy: 0.7504
# BEST: dname = Crop, Best model appears at iteration: 5, Val Accuracy: 0.7504, Val Loss: 2.8248
# Crop best result appended successfully to LSTM__finetune.csv
# Training on dataset: DiatomSizeReduction
# Loaded model from ./models/LSTM__DiatomSizeReduction__8.keras
# Fine-tuning iteration 1/5 for dataset DiatomSizeReduction
# Iteration 1 - Validation Loss: 0.6082, Validation Accuracy: 0.9641
# Fine-tuning iteration 2/5 for dataset DiatomSizeReduction
# Iteration 2 - Validation Loss: 0.6185, Validation Accuracy: 0.9641
# Fine-tuning iteration 3/5 for dataset DiatomSizeReduction
# Iteration 3 - Validation Loss: 0.6128, Validation Accuracy: 0.9641
# Fine-tuning iteration 4/5 for dataset DiatomSizeReduction
# Iteration 4 - Validation Loss: 0.6072, Validation Accuracy: 0.9641
# Fine-tuning iteration 5/5 for dataset DiatomSizeReduction
# Iteration 5 - Validation Loss: 0.6040, Validation Accuracy: 0.9641
# BEST: dname = DiatomSizeReduction, Best model appears at iteration: 1, Val Accuracy: 0.9641, Val Loss: 0.6082
# DiatomSizeReduction best result appended successfully to LSTM__finetune.csv
# Training on dataset: DistalPhalanxOutlineAgeGroup
# Loaded model from ./models/LSTM__DistalPhalanxOutlineAgeGroup__128.keras
# Fine-tuning iteration 1/5 for dataset DistalPhalanxOutlineAgeGroup
# Iteration 1 - Validation Loss: 2.1229, Validation Accuracy: 0.6906
# Fine-tuning iteration 2/5 for dataset DistalPhalanxOutlineAgeGroup
# Iteration 2 - Validation Loss: 3.1103, Validation Accuracy: 0.6835
# Fine-tuning iteration 3/5 for dataset DistalPhalanxOutlineAgeGroup
# Iteration 3 - Validation Loss: 2.3428, Validation Accuracy: 0.7266
# Fine-tuning iteration 4/5 for dataset DistalPhalanxOutlineAgeGroup
# Iteration 4 - Validation Loss: 2.4157, Validation Accuracy: 0.7338
# Fine-tuning iteration 5/5 for dataset DistalPhalanxOutlineAgeGroup
# Iteration 5 - Validation Loss: 2.5372, Validation Accuracy: 0.7410
# BEST: dname = DistalPhalanxOutlineAgeGroup, Best model appears at iteration: 5, Val Accuracy: 0.7410, Val Loss: 2.5372
# DistalPhalanxOutlineAgeGroup best result appended successfully to LSTM__finetune.csv
# Training on dataset: DistalPhalanxOutlineCorrect
# Loaded model from ./models/LSTM__DistalPhalanxOutlineCorrect__128.keras
# Fine-tuning iteration 1/5 for dataset DistalPhalanxOutlineCorrect
# Iteration 1 - Validation Loss: 2.2931, Validation Accuracy: 0.7029
# Fine-tuning iteration 2/5 for dataset DistalPhalanxOutlineCorrect
# Iteration 2 - Validation Loss: 2.9050, Validation Accuracy: 0.6739
# Fine-tuning iteration 3/5 for dataset DistalPhalanxOutlineCorrect
# Iteration 3 - Validation Loss: 2.6158, Validation Accuracy: 0.7428
# Fine-tuning iteration 4/5 for dataset DistalPhalanxOutlineCorrect
# Iteration 4 - Validation Loss: 2.5364, Validation Accuracy: 0.7138
# Fine-tuning iteration 5/5 for dataset DistalPhalanxOutlineCorrect
# Iteration 5 - Validation Loss: 2.5555, Validation Accuracy: 0.7174
# BEST: dname = DistalPhalanxOutlineCorrect, Best model appears at iteration: 3, Val Accuracy: 0.7428, Val Loss: 2.6158
# DistalPhalanxOutlineCorrect best result appended successfully to LSTM__finetune.csv
# Training on dataset: DistalPhalanxTW
# Loaded model from ./models/LSTM__DistalPhalanxTW__8.keras
# Fine-tuning iteration 1/5 for dataset DistalPhalanxTW
# Iteration 1 - Validation Loss: 3.6980, Validation Accuracy: 0.5396
# Fine-tuning iteration 2/5 for dataset DistalPhalanxTW
# Iteration 2 - Validation Loss: 3.3387, Validation Accuracy: 0.5396
# Fine-tuning iteration 3/5 for dataset DistalPhalanxTW
# Iteration 3 - Validation Loss: 2.9966, Validation Accuracy: 0.5971
# Fine-tuning iteration 4/5 for dataset DistalPhalanxTW
# Iteration 4 - Validation Loss: 3.0145, Validation Accuracy: 0.5755
# Fine-tuning iteration 5/5 for dataset DistalPhalanxTW
# Iteration 5 - Validation Loss: 3.3282, Validation Accuracy: 0.6043
# BEST: dname = DistalPhalanxTW, Best model appears at iteration: 5, Val Accuracy: 0.6043, Val Loss: 3.3282
# DistalPhalanxTW best result appended successfully to LSTM__finetune.csv
# Training on dataset: DodgerLoopDay
# Loaded model from ./models/LSTM__DodgerLoopDay__128.keras
# Fine-tuning iteration 1/5 for dataset DodgerLoopDay
# Iteration 1 - Validation Loss: 1.8189, Validation Accuracy: 0.5250
# Fine-tuning iteration 2/5 for dataset DodgerLoopDay
# Iteration 2 - Validation Loss: 1.8563, Validation Accuracy: 0.5250
# Fine-tuning iteration 3/5 for dataset DodgerLoopDay
# Iteration 3 - Validation Loss: 1.9751, Validation Accuracy: 0.5375
# Fine-tuning iteration 4/5 for dataset DodgerLoopDay
# Iteration 4 - Validation Loss: 2.0315, Validation Accuracy: 0.5125
# Fine-tuning iteration 5/5 for dataset DodgerLoopDay
# Iteration 5 - Validation Loss: 1.9772, Validation Accuracy: 0.5625
# BEST: dname = DodgerLoopDay, Best model appears at iteration: 5, Val Accuracy: 0.5625, Val Loss: 1.9772
# DodgerLoopDay best result appended successfully to LSTM__finetune.csv
# Training on dataset: DodgerLoopGame
# Loaded model from ./models/LSTM__DodgerLoopGame__8.keras
# Fine-tuning iteration 1/5 for dataset DodgerLoopGame
# Iteration 1 - Validation Loss: 0.5918, Validation Accuracy: 0.8478
# Fine-tuning iteration 2/5 for dataset DodgerLoopGame
# Iteration 2 - Validation Loss: 0.5994, Validation Accuracy: 0.8478
# Fine-tuning iteration 3/5 for dataset DodgerLoopGame
# Iteration 3 - Validation Loss: 0.5986, Validation Accuracy: 0.8478
# Fine-tuning iteration 4/5 for dataset DodgerLoopGame
# Iteration 4 - Validation Loss: 0.5985, Validation Accuracy: 0.8406
# Fine-tuning iteration 5/5 for dataset DodgerLoopGame
# Iteration 5 - Validation Loss: 0.5977, Validation Accuracy: 0.8406
# BEST: dname = DodgerLoopGame, Best model appears at iteration: 1, Val Accuracy: 0.8478, Val Loss: 0.5918
# DodgerLoopGame best result appended successfully to LSTM__finetune.csv
# Training on dataset: DodgerLoopWeekend
# Loaded model from ./models/LSTM__DodgerLoopWeekend__8.keras
# Fine-tuning iteration 1/5 for dataset DodgerLoopWeekend
# Iteration 1 - Validation Loss: 0.2170, Validation Accuracy: 0.9855
# Fine-tuning iteration 2/5 for dataset DodgerLoopWeekend
# Iteration 2 - Validation Loss: 0.2252, Validation Accuracy: 0.9855
# Fine-tuning iteration 3/5 for dataset DodgerLoopWeekend
# Iteration 3 - Validation Loss: 0.2264, Validation Accuracy: 0.9855
# Fine-tuning iteration 4/5 for dataset DodgerLoopWeekend
# Iteration 4 - Validation Loss: 0.2261, Validation Accuracy: 0.9855
# Fine-tuning iteration 5/5 for dataset DodgerLoopWeekend
# Iteration 5 - Validation Loss: 0.2261, Validation Accuracy: 0.9855
# BEST: dname = DodgerLoopWeekend, Best model appears at iteration: 1, Val Accuracy: 0.9855, Val Loss: 0.2170
# DodgerLoopWeekend best result appended successfully to LSTM__finetune.csv
# Training on dataset: Earthquakes
# Loaded model from ./models/LSTM__Earthquakes__8.keras
# Fine-tuning iteration 1/5 for dataset Earthquakes
# Iteration 1 - Validation Loss: 2.4255, Validation Accuracy: 0.6619
# Fine-tuning iteration 2/5 for dataset Earthquakes
# Iteration 2 - Validation Loss: 2.5843, Validation Accuracy: 0.6763
# Fine-tuning iteration 3/5 for dataset Earthquakes
# Iteration 3 - Validation Loss: 3.0132, Validation Accuracy: 0.6547
# Fine-tuning iteration 4/5 for dataset Earthquakes
# Iteration 4 - Validation Loss: 3.0847, Validation Accuracy: 0.6331
# Fine-tuning iteration 5/5 for dataset Earthquakes
# Iteration 5 - Validation Loss: 3.0152, Validation Accuracy: 0.6475
# BEST: dname = Earthquakes, Best model appears at iteration: 2, Val Accuracy: 0.6763, Val Loss: 2.5843
# Earthquakes best result appended successfully to LSTM__finetune.csv
# Training on dataset: ECG200
# Loaded model from ./models/LSTM__ECG200__8.keras
# Fine-tuning iteration 1/5 for dataset ECG200
# Iteration 1 - Validation Loss: 0.6421, Validation Accuracy: 0.9000
# Fine-tuning iteration 2/5 for dataset ECG200
# Iteration 2 - Validation Loss: 0.6713, Validation Accuracy: 0.9200
# Fine-tuning iteration 3/5 for dataset ECG200
# Iteration 3 - Validation Loss: 0.6558, Validation Accuracy: 0.9400
# Fine-tuning iteration 4/5 for dataset ECG200
# Iteration 4 - Validation Loss: 0.7251, Validation Accuracy: 0.9300
# Fine-tuning iteration 5/5 for dataset ECG200
# Iteration 5 - Validation Loss: 0.7034, Validation Accuracy: 0.9100
# BEST: dname = ECG200, Best model appears at iteration: 3, Val Accuracy: 0.9400, Val Loss: 0.6558
# ECG200 best result appended successfully to LSTM__finetune.csv
# Training on dataset: ECG5000
# Loaded model from ./models/LSTM__ECG5000__8.keras
# Fine-tuning iteration 1/5 for dataset ECG5000
# Iteration 1 - Validation Loss: 0.4502, Validation Accuracy: 0.9360
# Fine-tuning iteration 2/5 for dataset ECG5000
# Iteration 2 - Validation Loss: 0.5229, Validation Accuracy: 0.9338
# Fine-tuning iteration 3/5 for dataset ECG5000
# Iteration 3 - Validation Loss: 0.5682, Validation Accuracy: 0.9333
# Fine-tuning iteration 4/5 for dataset ECG5000
# Iteration 4 - Validation Loss: 0.6837, Validation Accuracy: 0.9353
# Fine-tuning iteration 5/5 for dataset ECG5000
# Iteration 5 - Validation Loss: 0.6087, Validation Accuracy: 0.9322
# BEST: dname = ECG5000, Best model appears at iteration: 1, Val Accuracy: 0.9360, Val Loss: 0.4502
# ECG5000 best result appended successfully to LSTM__finetune.csv
# Training on dataset: ECGFiveDays
# Loaded model from ./models/LSTM__ECGFiveDays__128.keras
# Fine-tuning iteration 1/5 for dataset ECGFiveDays
# Iteration 1 - Validation Loss: 0.1361, Validation Accuracy: 0.9652
# Fine-tuning iteration 2/5 for dataset ECGFiveDays
# Iteration 2 - Validation Loss: 0.1318, Validation Accuracy: 0.9663
# Fine-tuning iteration 3/5 for dataset ECGFiveDays
# Iteration 3 - Validation Loss: 0.1342, Validation Accuracy: 0.9652
# Fine-tuning iteration 4/5 for dataset ECGFiveDays
# Iteration 4 - Validation Loss: 0.1343, Validation Accuracy: 0.9617
# Fine-tuning iteration 5/5 for dataset ECGFiveDays
# Iteration 5 - Validation Loss: 0.1332, Validation Accuracy: 0.9617
# BEST: dname = ECGFiveDays, Best model appears at iteration: 2, Val Accuracy: 0.9663, Val Loss: 0.1318
# ECGFiveDays best result appended successfully to LSTM__finetune.csv
# Training on dataset: ElectricDevices
# Loaded model from ./models/LSTM__ElectricDevices__64.keras
# Fine-tuning iteration 1/5 for dataset ElectricDevices
# Iteration 1 - Validation Loss: 10.6899, Validation Accuracy: 0.5333
# Fine-tuning iteration 2/5 for dataset ElectricDevices
# Iteration 2 - Validation Loss: 10.9744, Validation Accuracy: 0.5355
# Fine-tuning iteration 3/5 for dataset ElectricDevices
# Iteration 3 - Validation Loss: 11.1487, Validation Accuracy: 0.5333
# Fine-tuning iteration 4/5 for dataset ElectricDevices
# Iteration 4 - Validation Loss: 10.8420, Validation Accuracy: 0.5434
# Fine-tuning iteration 5/5 for dataset ElectricDevices
# Iteration 5 - Validation Loss: 10.7610, Validation Accuracy: 0.5369
# BEST: dname = ElectricDevices, Best model appears at iteration: 4, Val Accuracy: 0.5434, Val Loss: 10.8420
# ElectricDevices best result appended successfully to LSTM__finetune.csv
# Training on dataset: EOGHorizontalSignal
# Loaded model from ./models/LSTM__EOGHorizontalSignal__8.keras
# Fine-tuning iteration 1/5 for dataset EOGHorizontalSignal
# Iteration 1 - Validation Loss: 4.1315, Validation Accuracy: 0.3812
# Fine-tuning iteration 2/5 for dataset EOGHorizontalSignal
# Iteration 2 - Validation Loss: 4.2290, Validation Accuracy: 0.4337
# Fine-tuning iteration 3/5 for dataset EOGHorizontalSignal
# Iteration 3 - Validation Loss: 4.5654, Validation Accuracy: 0.4171
# Fine-tuning iteration 4/5 for dataset EOGHorizontalSignal
# Iteration 4 - Validation Loss: 4.6473, Validation Accuracy: 0.4392
# Fine-tuning iteration 5/5 for dataset EOGHorizontalSignal
# Iteration 5 - Validation Loss: 4.6438, Validation Accuracy: 0.4171
# BEST: dname = EOGHorizontalSignal, Best model appears at iteration: 4, Val Accuracy: 0.4392, Val Loss: 4.6473
# EOGHorizontalSignal best result appended successfully to LSTM__finetune.csv
# Training on dataset: EOGVerticalSignal
# Loaded model from ./models/LSTM__EOGVerticalSignal__8.keras
# Fine-tuning iteration 1/5 for dataset EOGVerticalSignal
# Iteration 1 - Validation Loss: 5.3480, Validation Accuracy: 0.4088
# Fine-tuning iteration 2/5 for dataset EOGVerticalSignal
# Iteration 2 - Validation Loss: 5.6072, Validation Accuracy: 0.4006
# Fine-tuning iteration 3/5 for dataset EOGVerticalSignal
# Iteration 3 - Validation Loss: 6.1209, Validation Accuracy: 0.3923
# Fine-tuning iteration 4/5 for dataset EOGVerticalSignal
# Iteration 4 - Validation Loss: 5.6264, Validation Accuracy: 0.4006
# Fine-tuning iteration 5/5 for dataset EOGVerticalSignal
# Iteration 5 - Validation Loss: 5.2543, Validation Accuracy: 0.4365
# BEST: dname = EOGVerticalSignal, Best model appears at iteration: 5, Val Accuracy: 0.4365, Val Loss: 5.2543
# EOGVerticalSignal best result appended successfully to LSTM__finetune.csv
# Training on dataset: EthanolLevel
# Loaded model from ./models/LSTM__EthanolLevel__64.keras
# Fine-tuning iteration 1/5 for dataset EthanolLevel
# Iteration 1 - Validation Loss: 3.2886, Validation Accuracy: 0.4880
# Fine-tuning iteration 2/5 for dataset EthanolLevel
# Iteration 2 - Validation Loss: 2.5251, Validation Accuracy: 0.6680
# Fine-tuning iteration 3/5 for dataset EthanolLevel
# Iteration 3 - Validation Loss: 4.1419, Validation Accuracy: 0.4860
# Fine-tuning iteration 4/5 for dataset EthanolLevel
# Iteration 4 - Validation Loss: 9.8383, Validation Accuracy: 0.2820
# Fine-tuning iteration 5/5 for dataset EthanolLevel
# Iteration 5 - Validation Loss: 10.5902, Validation Accuracy: 0.3880
# BEST: dname = EthanolLevel, Best model appears at iteration: 2, Val Accuracy: 0.6680, Val Loss: 2.5251
# EthanolLevel best result appended successfully to LSTM__finetune.csv
# Training on dataset: FaceAll
# Loaded model from ./models/LSTM__FaceAll__8.keras
# Fine-tuning iteration 1/5 for dataset FaceAll
# Iteration 1 - Validation Loss: 0.7561, Validation Accuracy: 0.8432
# Fine-tuning iteration 2/5 for dataset FaceAll
# Iteration 2 - Validation Loss: 0.7979, Validation Accuracy: 0.8485
# Fine-tuning iteration 3/5 for dataset FaceAll
# Iteration 3 - Validation Loss: 0.7595, Validation Accuracy: 0.8598
# Fine-tuning iteration 4/5 for dataset FaceAll
# Iteration 4 - Validation Loss: 0.7767, Validation Accuracy: 0.8621
# Fine-tuning iteration 5/5 for dataset FaceAll
# Iteration 5 - Validation Loss: 0.7794, Validation Accuracy: 0.8663
# BEST: dname = FaceAll, Best model appears at iteration: 5, Val Accuracy: 0.8663, Val Loss: 0.7794
# FaceAll best result appended successfully to LSTM__finetune.csv
# Training on dataset: FaceFour
# Loaded model from ./models/LSTM__FaceFour__8.keras
# Fine-tuning iteration 1/5 for dataset FaceFour
# Iteration 1 - Validation Loss: 0.8826, Validation Accuracy: 0.8636
# Fine-tuning iteration 2/5 for dataset FaceFour
# Iteration 2 - Validation Loss: 0.9040, Validation Accuracy: 0.8636
# Fine-tuning iteration 3/5 for dataset FaceFour
# Iteration 3 - Validation Loss: 0.9023, Validation Accuracy: 0.8636
# Fine-tuning iteration 4/5 for dataset FaceFour
# Iteration 4 - Validation Loss: 0.8968, Validation Accuracy: 0.8636
# Fine-tuning iteration 5/5 for dataset FaceFour
# Iteration 5 - Validation Loss: 0.8910, Validation Accuracy: 0.8636
# BEST: dname = FaceFour, Best model appears at iteration: 1, Val Accuracy: 0.8636, Val Loss: 0.8826
# FaceFour best result appended successfully to LSTM__finetune.csv
# Training on dataset: FacesUCR
# Loaded model from ./models/LSTM__FacesUCR__64.keras
# Fine-tuning iteration 1/5 for dataset FacesUCR
# Iteration 1 - Validation Loss: 0.9142, Validation Accuracy: 0.8059
# Fine-tuning iteration 2/5 for dataset FacesUCR
# Iteration 2 - Validation Loss: 0.9648, Validation Accuracy: 0.8088
# Fine-tuning iteration 3/5 for dataset FacesUCR
# Iteration 3 - Validation Loss: 1.0708, Validation Accuracy: 0.7917
# Fine-tuning iteration 4/5 for dataset FacesUCR
# Iteration 4 - Validation Loss: 1.0195, Validation Accuracy: 0.8059
# Fine-tuning iteration 5/5 for dataset FacesUCR
# Iteration 5 - Validation Loss: 1.0148, Validation Accuracy: 0.8068
# BEST: dname = FacesUCR, Best model appears at iteration: 2, Val Accuracy: 0.8088, Val Loss: 0.9648
# FacesUCR best result appended successfully to LSTM__finetune.csv
# Training on dataset: FiftyWords
# Loaded model from ./models/LSTM__FiftyWords__128.keras
# Fine-tuning iteration 1/5 for dataset FiftyWords
# Iteration 1 - Validation Loss: 2.3642, Validation Accuracy: 0.6813
# Fine-tuning iteration 2/5 for dataset FiftyWords
# Iteration 2 - Validation Loss: 2.4338, Validation Accuracy: 0.6725
# Fine-tuning iteration 3/5 for dataset FiftyWords
# Iteration 3 - Validation Loss: 2.4548, Validation Accuracy: 0.6637
# Fine-tuning iteration 4/5 for dataset FiftyWords
# Iteration 4 - Validation Loss: 2.4725, Validation Accuracy: 0.6835
# Fine-tuning iteration 5/5 for dataset FiftyWords
# Iteration 5 - Validation Loss: 2.4372, Validation Accuracy: 0.6659
# BEST: dname = FiftyWords, Best model appears at iteration: 4, Val Accuracy: 0.6835, Val Loss: 2.4725
# FiftyWords best result appended successfully to LSTM__finetune.csv
# Training on dataset: Fish
# Loaded model from ./models/LSTM__Fish__64.keras
# Fine-tuning iteration 1/5 for dataset Fish
# Iteration 1 - Validation Loss: 2.2339, Validation Accuracy: 0.5771
# Fine-tuning iteration 2/5 for dataset Fish
# Iteration 2 - Validation Loss: 5.0118, Validation Accuracy: 0.5143
# Fine-tuning iteration 3/5 for dataset Fish
# Iteration 3 - Validation Loss: 0.6070, Validation Accuracy: 0.9029
# Fine-tuning iteration 4/5 for dataset Fish
# Iteration 4 - Validation Loss: 0.6300, Validation Accuracy: 0.8914
# Fine-tuning iteration 5/5 for dataset Fish
# Iteration 5 - Validation Loss: 0.6269, Validation Accuracy: 0.8914
# BEST: dname = Fish, Best model appears at iteration: 3, Val Accuracy: 0.9029, Val Loss: 0.6070
# Fish best result appended successfully to LSTM__finetune.csv
# Training on dataset: FordA
# Loaded model from ./models/LSTM__FordA__128.keras
# Fine-tuning iteration 1/5 for dataset FordA
# Iteration 1 - Validation Loss: 1.2726, Validation Accuracy: 0.8083
# Fine-tuning iteration 2/5 for dataset FordA
# Iteration 2 - Validation Loss: 1.3585, Validation Accuracy: 0.8053
# Fine-tuning iteration 3/5 for dataset FordA
# Iteration 3 - Validation Loss: 1.4491, Validation Accuracy: 0.8159
# Fine-tuning iteration 4/5 for dataset FordA
# Iteration 4 - Validation Loss: 1.5080, Validation Accuracy: 0.8038
# Fine-tuning iteration 5/5 for dataset FordA
# Iteration 5 - Validation Loss: 1.4717, Validation Accuracy: 0.8083
# BEST: dname = FordA, Best model appears at iteration: 3, Val Accuracy: 0.8159, Val Loss: 1.4491
# FordA best result appended successfully to LSTM__finetune.csv
# Training on dataset: FordB
# Loaded model from ./models/LSTM__FordB__128.keras
# Fine-tuning iteration 1/5 for dataset FordB
# Iteration 1 - Validation Loss: 3.3412, Validation Accuracy: 0.6877
# Fine-tuning iteration 2/5 for dataset FordB
# Iteration 2 - Validation Loss: 3.2542, Validation Accuracy: 0.6840
# Fine-tuning iteration 3/5 for dataset FordB
# Iteration 3 - Validation Loss: 3.1799, Validation Accuracy: 0.6741
# Fine-tuning iteration 4/5 for dataset FordB
# Iteration 4 - Validation Loss: 3.1899, Validation Accuracy: 0.6753
# Fine-tuning iteration 5/5 for dataset FordB
# Iteration 5 - Validation Loss: 3.1275, Validation Accuracy: 0.6827
# BEST: dname = FordB, Best model appears at iteration: 1, Val Accuracy: 0.6877, Val Loss: 3.3412
# FordB best result appended successfully to LSTM__finetune.csv
# Training on dataset: FreezerRegularTrain
# Loaded model from ./models/LSTM__FreezerRegularTrain__128.keras
# Fine-tuning iteration 1/5 for dataset FreezerRegularTrain
# Iteration 1 - Validation Loss: 0.2955, Validation Accuracy: 0.9530
# Fine-tuning iteration 2/5 for dataset FreezerRegularTrain
# Iteration 2 - Validation Loss: 0.2237, Validation Accuracy: 0.9695
# Fine-tuning iteration 3/5 for dataset FreezerRegularTrain
# Iteration 3 - Validation Loss: 0.3145, Validation Accuracy: 0.9530
# Fine-tuning iteration 4/5 for dataset FreezerRegularTrain
# Iteration 4 - Validation Loss: 0.1633, Validation Accuracy: 0.9814
# Fine-tuning iteration 5/5 for dataset FreezerRegularTrain
# Iteration 5 - Validation Loss: 0.1516, Validation Accuracy: 0.9828
# BEST: dname = FreezerRegularTrain, Best model appears at iteration: 5, Val Accuracy: 0.9828, Val Loss: 0.1516
# FreezerRegularTrain best result appended successfully to LSTM__finetune.csv
# Training on dataset: FreezerSmallTrain
# Loaded model from ./models/LSTM__FreezerSmallTrain__128.keras
# Fine-tuning iteration 1/5 for dataset FreezerSmallTrain
# Iteration 1 - Validation Loss: 3.1601, Validation Accuracy: 0.6954
# Fine-tuning iteration 2/5 for dataset FreezerSmallTrain
# Iteration 2 - Validation Loss: 3.4177, Validation Accuracy: 0.6870
# Fine-tuning iteration 3/5 for dataset FreezerSmallTrain
# Iteration 3 - Validation Loss: 3.4692, Validation Accuracy: 0.6846
# Fine-tuning iteration 4/5 for dataset FreezerSmallTrain
# Iteration 4 - Validation Loss: 3.4863, Validation Accuracy: 0.6856
# Fine-tuning iteration 5/5 for dataset FreezerSmallTrain
# Iteration 5 - Validation Loss: 3.4856, Validation Accuracy: 0.6860
# BEST: dname = FreezerSmallTrain, Best model appears at iteration: 1, Val Accuracy: 0.6954, Val Loss: 3.1601
# FreezerSmallTrain best result appended successfully to LSTM__finetune.csv
# Training on dataset: Fungi
# Loaded model from ./models/LSTM__Fungi__8.keras
# Fine-tuning iteration 1/5 for dataset Fungi
# Iteration 1 - Validation Loss: 1.1004, Validation Accuracy: 0.8333
# Fine-tuning iteration 2/5 for dataset Fungi
# Iteration 2 - Validation Loss: 1.1895, Validation Accuracy: 0.8333
# Fine-tuning iteration 3/5 for dataset Fungi
# Iteration 3 - Validation Loss: 1.2200, Validation Accuracy: 0.8333
# Fine-tuning iteration 4/5 for dataset Fungi
# Iteration 4 - Validation Loss: 1.2255, Validation Accuracy: 0.8333
# Fine-tuning iteration 5/5 for dataset Fungi
# Iteration 5 - Validation Loss: 1.2393, Validation Accuracy: 0.8333
# BEST: dname = Fungi, Best model appears at iteration: 1, Val Accuracy: 0.8333, Val Loss: 1.1004
# Fungi best result appended successfully to LSTM__finetune.csv
# Training on dataset: GestureMidAirD1
# Loaded model from ./models/LSTM__GestureMidAirD1__8.keras
# Fine-tuning iteration 1/5 for dataset GestureMidAirD1
# Iteration 1 - Validation Loss: 5.4778, Validation Accuracy: 0.3154
# Fine-tuning iteration 2/5 for dataset GestureMidAirD1
# Iteration 2 - Validation Loss: 6.1755, Validation Accuracy: 0.3000
# Fine-tuning iteration 3/5 for dataset GestureMidAirD1
# Iteration 3 - Validation Loss: 5.7648, Validation Accuracy: 0.2846
# Fine-tuning iteration 4/5 for dataset GestureMidAirD1
# Iteration 4 - Validation Loss: 5.3631, Validation Accuracy: 0.2923
# Fine-tuning iteration 5/5 for dataset GestureMidAirD1
# Iteration 5 - Validation Loss: 5.3757, Validation Accuracy: 0.3000
# BEST: dname = GestureMidAirD1, Best model appears at iteration: 1, Val Accuracy: 0.3154, Val Loss: 5.4778
# GestureMidAirD1 best result appended successfully to LSTM__finetune.csv
# Training on dataset: GestureMidAirD2
# Loaded model from ./models/LSTM__GestureMidAirD2__128.keras
# Fine-tuning iteration 1/5 for dataset GestureMidAirD2
# Iteration 1 - Validation Loss: 5.6962, Validation Accuracy: 0.2538
# Fine-tuning iteration 2/5 for dataset GestureMidAirD2
# Iteration 2 - Validation Loss: 5.5723, Validation Accuracy: 0.2385
# Fine-tuning iteration 3/5 for dataset GestureMidAirD2
# Iteration 3 - Validation Loss: 5.8680, Validation Accuracy: 0.2538
# Fine-tuning iteration 4/5 for dataset GestureMidAirD2
# Iteration 4 - Validation Loss: 5.6147, Validation Accuracy: 0.2692
# Fine-tuning iteration 5/5 for dataset GestureMidAirD2
# Iteration 5 - Validation Loss: 5.5554, Validation Accuracy: 0.2692
# BEST: dname = GestureMidAirD2, Best model appears at iteration: 4, Val Accuracy: 0.2692, Val Loss: 5.6147
# GestureMidAirD2 best result appended successfully to LSTM__finetune.csv
# Training on dataset: GestureMidAirD3
# Loaded model from ./models/LSTM__GestureMidAirD3__64.keras
# Fine-tuning iteration 1/5 for dataset GestureMidAirD3
# Iteration 1 - Validation Loss: 5.7098, Validation Accuracy: 0.2077
# Fine-tuning iteration 2/5 for dataset GestureMidAirD3
# Iteration 2 - Validation Loss: 6.1361, Validation Accuracy: 0.2077
# Fine-tuning iteration 3/5 for dataset GestureMidAirD3
# Iteration 3 - Validation Loss: 5.8853, Validation Accuracy: 0.2000
# Fine-tuning iteration 4/5 for dataset GestureMidAirD3
# Iteration 4 - Validation Loss: 5.8239, Validation Accuracy: 0.2077
# Fine-tuning iteration 5/5 for dataset GestureMidAirD3
# Iteration 5 - Validation Loss: 5.7703, Validation Accuracy: 0.1692
# BEST: dname = GestureMidAirD3, Best model appears at iteration: 1, Val Accuracy: 0.2077, Val Loss: 5.7098
# GestureMidAirD3 best result appended successfully to LSTM__finetune.csv
# Training on dataset: GesturePebbleZ1
# Loaded model from ./models/LSTM__GesturePebbleZ1__128.keras
# Fine-tuning iteration 1/5 for dataset GesturePebbleZ1
# Iteration 1 - Validation Loss: 3.2374, Validation Accuracy: 0.4826
# Fine-tuning iteration 2/5 for dataset GesturePebbleZ1
# Iteration 2 - Validation Loss: 2.4049, Validation Accuracy: 0.5233
# Fine-tuning iteration 3/5 for dataset GesturePebbleZ1
# Iteration 3 - Validation Loss: 2.3557, Validation Accuracy: 0.5349
# Fine-tuning iteration 4/5 for dataset GesturePebbleZ1
# Iteration 4 - Validation Loss: 2.4131, Validation Accuracy: 0.5174
# Fine-tuning iteration 5/5 for dataset GesturePebbleZ1
# Iteration 5 - Validation Loss: 2.3445, Validation Accuracy: 0.5233
# BEST: dname = GesturePebbleZ1, Best model appears at iteration: 3, Val Accuracy: 0.5349, Val Loss: 2.3557
# GesturePebbleZ1 best result appended successfully to LSTM__finetune.csv
# Training on dataset: GesturePebbleZ2
# Loaded model from ./models/LSTM__GesturePebbleZ2__128.keras
# Fine-tuning iteration 1/5 for dataset GesturePebbleZ2
# Iteration 1 - Validation Loss: 3.6625, Validation Accuracy: 0.4114
# Fine-tuning iteration 2/5 for dataset GesturePebbleZ2
# Iteration 2 - Validation Loss: 2.8356, Validation Accuracy: 0.4620
# Fine-tuning iteration 3/5 for dataset GesturePebbleZ2
# Iteration 3 - Validation Loss: 2.8234, Validation Accuracy: 0.4620
# Fine-tuning iteration 4/5 for dataset GesturePebbleZ2
# Iteration 4 - Validation Loss: 2.8174, Validation Accuracy: 0.4747
# Fine-tuning iteration 5/5 for dataset GesturePebbleZ2
# Iteration 5 - Validation Loss: 2.9691, Validation Accuracy: 0.4873
# BEST: dname = GesturePebbleZ2, Best model appears at iteration: 5, Val Accuracy: 0.4873, Val Loss: 2.9691
# GesturePebbleZ2 best result appended successfully to LSTM__finetune.csv
# Training on dataset: GunPoint
# Loaded model from ./models/LSTM__GunPoint__128.keras
# Fine-tuning iteration 1/5 for dataset GunPoint
# Iteration 1 - Validation Loss: 0.7423, Validation Accuracy: 0.8467
# Fine-tuning iteration 2/5 for dataset GunPoint
# Iteration 2 - Validation Loss: 0.5191, Validation Accuracy: 0.9267
# Fine-tuning iteration 3/5 for dataset GunPoint
# Iteration 3 - Validation Loss: 0.4867, Validation Accuracy: 0.9400
# Fine-tuning iteration 4/5 for dataset GunPoint
# Iteration 4 - Validation Loss: 0.4358, Validation Accuracy: 0.9333
# Fine-tuning iteration 5/5 for dataset GunPoint
# Iteration 5 - Validation Loss: 0.3769, Validation Accuracy: 0.9467
# BEST: dname = GunPoint, Best model appears at iteration: 5, Val Accuracy: 0.9467, Val Loss: 0.3769
# GunPoint best result appended successfully to LSTM__finetune.csv
# Training on dataset: GunPointAgeSpan
# Loaded model from ./models/LSTM__GunPointAgeSpan__64.keras
# Fine-tuning iteration 1/5 for dataset GunPointAgeSpan
# Iteration 1 - Validation Loss: 0.3463, Validation Accuracy: 0.8924
# Fine-tuning iteration 2/5 for dataset GunPointAgeSpan
# Iteration 2 - Validation Loss: 0.2158, Validation Accuracy: 0.9557
# Fine-tuning iteration 3/5 for dataset GunPointAgeSpan
# Iteration 3 - Validation Loss: 0.2060, Validation Accuracy: 0.9589
# Fine-tuning iteration 4/5 for dataset GunPointAgeSpan
# Iteration 4 - Validation Loss: 0.2157, Validation Accuracy: 0.9557
# Fine-tuning iteration 5/5 for dataset GunPointAgeSpan
# Iteration 5 - Validation Loss: 0.2031, Validation Accuracy: 0.9525
# BEST: dname = GunPointAgeSpan, Best model appears at iteration: 3, Val Accuracy: 0.9589, Val Loss: 0.2060
# GunPointAgeSpan best result appended successfully to LSTM__finetune.csv
# Training on dataset: GunPointMaleVersusFemale
# Loaded model from ./models/LSTM__GunPointMaleVersusFemale__8.keras
# Fine-tuning iteration 1/5 for dataset GunPointMaleVersusFemale
# Iteration 1 - Validation Loss: 0.0509, Validation Accuracy: 0.9873
# Fine-tuning iteration 2/5 for dataset GunPointMaleVersusFemale
# Iteration 2 - Validation Loss: 0.0573, Validation Accuracy: 0.9842
# Fine-tuning iteration 3/5 for dataset GunPointMaleVersusFemale
# Iteration 3 - Validation Loss: 0.0442, Validation Accuracy: 0.9905
# Fine-tuning iteration 4/5 for dataset GunPointMaleVersusFemale
# Iteration 4 - Validation Loss: 0.0556, Validation Accuracy: 0.9842
# Fine-tuning iteration 5/5 for dataset GunPointMaleVersusFemale
# Iteration 5 - Validation Loss: 0.0409, Validation Accuracy: 0.9905
# BEST: dname = GunPointMaleVersusFemale, Best model appears at iteration: 3, Val Accuracy: 0.9905, Val Loss: 0.0442
# GunPointMaleVersusFemale best result appended successfully to LSTM__finetune.csv
# Training on dataset: GunPointOldVersusYoung
# Loaded model from ./models/LSTM__GunPointOldVersusYoung__64.keras
# Fine-tuning iteration 1/5 for dataset GunPointOldVersusYoung
# Iteration 1 - Validation Loss: 0.4925, Validation Accuracy: 0.9492
# Fine-tuning iteration 2/5 for dataset GunPointOldVersusYoung
# Iteration 2 - Validation Loss: 0.5266, Validation Accuracy: 0.9492
# Fine-tuning iteration 3/5 for dataset GunPointOldVersusYoung
# Iteration 3 - Validation Loss: 0.4730, Validation Accuracy: 0.9429
# Fine-tuning iteration 4/5 for dataset GunPointOldVersusYoung
# Iteration 4 - Validation Loss: 0.4868, Validation Accuracy: 0.9460
# Fine-tuning iteration 5/5 for dataset GunPointOldVersusYoung
# Iteration 5 - Validation Loss: 0.4886, Validation Accuracy: 0.9460
# BEST: dname = GunPointOldVersusYoung, Best model appears at iteration: 1, Val Accuracy: 0.9492, Val Loss: 0.4925
# GunPointOldVersusYoung best result appended successfully to LSTM__finetune.csv
# Training on dataset: Ham
# Loaded model from ./models/LSTM__Ham__8.keras
# Fine-tuning iteration 1/5 for dataset Ham
# Iteration 1 - Validation Loss: 2.3829, Validation Accuracy: 0.6571
# Fine-tuning iteration 2/5 for dataset Ham
# Iteration 2 - Validation Loss: 2.5049, Validation Accuracy: 0.6476
# Fine-tuning iteration 3/5 for dataset Ham
# Iteration 3 - Validation Loss: 2.6187, Validation Accuracy: 0.6190
# Fine-tuning iteration 4/5 for dataset Ham
# Iteration 4 - Validation Loss: 2.6477, Validation Accuracy: 0.6571
# Fine-tuning iteration 5/5 for dataset Ham
# Iteration 5 - Validation Loss: 3.1189, Validation Accuracy: 0.6381
# BEST: dname = Ham, Best model appears at iteration: 1, Val Accuracy: 0.6571, Val Loss: 2.3829
# Ham best result appended successfully to LSTM__finetune.csv
# Training on dataset: HandOutlines
# Loaded model from ./models/LSTM__HandOutlines__128.keras
# Fine-tuning iteration 1/5 for dataset HandOutlines
# Iteration 1 - Validation Loss: 1.3769, Validation Accuracy: 0.8243
# Fine-tuning iteration 2/5 for dataset HandOutlines
# Iteration 2 - Validation Loss: 0.6986, Validation Accuracy: 0.9108
# Fine-tuning iteration 3/5 for dataset HandOutlines
# ...
# Fine-tuning iteration 1/5 for dataset ToeSegmentation1
# Iteration 1 - Validation Loss: 0.8957, Validation Accuracy: 0.6228
# Fine-tuning iteration 2/5 for dataset ToeSegmentation1
# Iteration 2 - Validation Loss: 1.2386, Validation Accuracy: 0.6316
# Fine-tuning iteration 3/5 for dataset ToeSegmentation1
# Iteration 3 - Validation Loss: 1.5104, Validation Accuracy: 0.6360
# Fine-tuning iteration 4/5 for dataset ToeSegmentation1
# Iteration 4 - Validation Loss: 1.7082, Validation Accuracy: 0.6360
# Fine-tuning iteration 5/5 for dataset ToeSegmentation1
# Iteration 5 - Validation Loss: 2.1717, Validation Accuracy: 0.6404
# BEST: dname = ToeSegmentation1, Best model appears at iteration: 5, Val Accuracy: 0.6404, Val Loss: 2.1717
# ToeSegmentation1 best result appended successfully to LSTM__finetune.csv
# Training on dataset: ToeSegmentation2
# Loaded model from ./models/LSTM__ToeSegmentation2__128.keras
# Fine-tuning iteration 1/5 for dataset ToeSegmentation2
# Iteration 1 - Validation Loss: 0.7380, Validation Accuracy: 0.7615
# Fine-tuning iteration 2/5 for dataset ToeSegmentation2
# Iteration 2 - Validation Loss: 0.9655, Validation Accuracy: 0.7462
# Fine-tuning iteration 3/5 for dataset ToeSegmentation2
# Iteration 3 - Validation Loss: 1.1005, Validation Accuracy: 0.7462
# Fine-tuning iteration 4/5 for dataset ToeSegmentation2
# Iteration 4 - Validation Loss: 1.1842, Validation Accuracy: 0.7538
# Fine-tuning iteration 5/5 for dataset ToeSegmentation2
# Iteration 5 - Validation Loss: 1.3954, Validation Accuracy: 0.7615
# BEST: dname = ToeSegmentation2, Best model appears at iteration: 1, Val Accuracy: 0.7615, Val Loss: 0.7380
# ToeSegmentation2 best result appended successfully to LSTM__finetune.csv
# Training on dataset: Trace
# Loaded model from ./models/LSTM__Trace__8.keras
# Fine-tuning iteration 1/5 for dataset Trace
# Iteration 1 - Validation Loss: 1.6379, Validation Accuracy: 0.4800
# Fine-tuning iteration 2/5 for dataset Trace
# Iteration 2 - Validation Loss: 2.3648, Validation Accuracy: 0.4900
# Fine-tuning iteration 3/5 for dataset Trace
# Iteration 3 - Validation Loss: 1.9584, Validation Accuracy: 0.5300
# Fine-tuning iteration 4/5 for dataset Trace
# Iteration 4 - Validation Loss: 1.8617, Validation Accuracy: 0.7000
# Fine-tuning iteration 5/5 for dataset Trace
# Iteration 5 - Validation Loss: 1.6852, Validation Accuracy: 0.7700
# BEST: dname = Trace, Best model appears at iteration: 5, Val Accuracy: 0.7700, Val Loss: 1.6852
# Trace best result appended successfully to LSTM__finetune.csv
# Training on dataset: TwoLeadECG
# Loaded model from ./models/LSTM__TwoLeadECG__8.keras
# Fine-tuning iteration 1/5 for dataset TwoLeadECG
# Iteration 1 - Validation Loss: 1.1791, Validation Accuracy: 0.5514
# Fine-tuning iteration 2/5 for dataset TwoLeadECG
# Iteration 2 - Validation Loss: 1.3646, Validation Accuracy: 0.6076
# Fine-tuning iteration 3/5 for dataset TwoLeadECG
# Iteration 3 - Validation Loss: 1.2534, Validation Accuracy: 0.6585
# Fine-tuning iteration 4/5 for dataset TwoLeadECG
# Iteration 4 - Validation Loss: 1.0376, Validation Accuracy: 0.7287
# Fine-tuning iteration 5/5 for dataset TwoLeadECG
# Iteration 5 - Validation Loss: 0.8388, Validation Accuracy: 0.7858
# BEST: dname = TwoLeadECG, Best model appears at iteration: 5, Val Accuracy: 0.7858, Val Loss: 0.8388
# TwoLeadECG best result appended successfully to LSTM__finetune.csv
# Training on dataset: TwoPatterns
# Loaded model from ./models/LSTM__TwoPatterns__64.keras
# Fine-tuning iteration 1/5 for dataset TwoPatterns
# Iteration 1 - Validation Loss: 0.4936, Validation Accuracy: 0.8712
# Fine-tuning iteration 2/5 for dataset TwoPatterns
# Iteration 2 - Validation Loss: 0.5521, Validation Accuracy: 0.8702
# Fine-tuning iteration 3/5 for dataset TwoPatterns
# Iteration 3 - Validation Loss: 0.6284, Validation Accuracy: 0.8668
# Fine-tuning iteration 4/5 for dataset TwoPatterns
# Iteration 4 - Validation Loss: 0.5738, Validation Accuracy: 0.8760
# Fine-tuning iteration 5/5 for dataset TwoPatterns
# Iteration 5 - Validation Loss: 0.6119, Validation Accuracy: 0.8683
# BEST: dname = TwoPatterns, Best model appears at iteration: 4, Val Accuracy: 0.8760, Val Loss: 0.5738
# TwoPatterns best result appended successfully to LSTM__finetune.csv
# Training on dataset: UMD
# Loaded model from ./models/LSTM__UMD__8.keras
# Fine-tuning iteration 1/5 for dataset UMD
# Iteration 1 - Validation Loss: 0.3888, Validation Accuracy: 0.8889
# Fine-tuning iteration 2/5 for dataset UMD
# Iteration 2 - Validation Loss: 0.4178, Validation Accuracy: 0.8889
# Fine-tuning iteration 3/5 for dataset UMD
# Iteration 3 - Validation Loss: 0.4279, Validation Accuracy: 0.8889
# Fine-tuning iteration 4/5 for dataset UMD
# Iteration 4 - Validation Loss: 0.4328, Validation Accuracy: 0.8889
# Fine-tuning iteration 5/5 for dataset UMD
# Iteration 5 - Validation Loss: 0.5261, Validation Accuracy: 0.8750
# BEST: dname = UMD, Best model appears at iteration: 1, Val Accuracy: 0.8889, Val Loss: 0.3888
# UMD best result appended successfully to LSTM__finetune.csv
# Training on dataset: UWaveGestureLibraryAll
# Loaded model from ./models/LSTM__UWaveGestureLibraryAll__8.keras
# Fine-tuning iteration 1/5 for dataset UWaveGestureLibraryAll
# Iteration 1 - Validation Loss: 0.1986, Validation Accuracy: 0.9567
# Fine-tuning iteration 2/5 for dataset UWaveGestureLibraryAll
# Iteration 2 - Validation Loss: 0.2581, Validation Accuracy: 0.9534
# Fine-tuning iteration 3/5 for dataset UWaveGestureLibraryAll
# Iteration 3 - Validation Loss: 0.2602, Validation Accuracy: 0.9509
# Fine-tuning iteration 4/5 for dataset UWaveGestureLibraryAll
# Iteration 4 - Validation Loss: 0.2605, Validation Accuracy: 0.9542
# Fine-tuning iteration 5/5 for dataset UWaveGestureLibraryAll
# Iteration 5 - Validation Loss: 0.2504, Validation Accuracy: 0.9545
# BEST: dname = UWaveGestureLibraryAll, Best model appears at iteration: 1, Val Accuracy: 0.9567, Val Loss: 0.1986
# UWaveGestureLibraryAll best result appended successfully to LSTM__finetune.csv
# Training on dataset: UWaveGestureLibraryX
# Loaded model from ./models/LSTM__UWaveGestureLibraryX__64.keras
# Fine-tuning iteration 1/5 for dataset UWaveGestureLibraryX
# Iteration 1 - Validation Loss: 1.3159, Validation Accuracy: 0.7599
# Fine-tuning iteration 2/5 for dataset UWaveGestureLibraryX
# Iteration 2 - Validation Loss: 1.5018, Validation Accuracy: 0.7393
# Fine-tuning iteration 3/5 for dataset UWaveGestureLibraryX
# Iteration 3 - Validation Loss: 1.3705, Validation Accuracy: 0.7708
# Fine-tuning iteration 4/5 for dataset UWaveGestureLibraryX
# Iteration 4 - Validation Loss: 1.4086, Validation Accuracy: 0.7722
# Fine-tuning iteration 5/5 for dataset UWaveGestureLibraryX
# Iteration 5 - Validation Loss: 1.4602, Validation Accuracy: 0.7711
# BEST: dname = UWaveGestureLibraryX, Best model appears at iteration: 4, Val Accuracy: 0.7722, Val Loss: 1.4086
# UWaveGestureLibraryX best result appended successfully to LSTM__finetune.csv
# Training on dataset: UWaveGestureLibraryY
# Loaded model from ./models/LSTM__UWaveGestureLibraryY__64.keras
# Fine-tuning iteration 1/5 for dataset UWaveGestureLibraryY
# Iteration 1 - Validation Loss: 1.3986, Validation Accuracy: 0.6910
# Fine-tuning iteration 2/5 for dataset UWaveGestureLibraryY
# Iteration 2 - Validation Loss: 1.6865, Validation Accuracy: 0.6940
# Fine-tuning iteration 3/5 for dataset UWaveGestureLibraryY
# Iteration 3 - Validation Loss: 1.8099, Validation Accuracy: 0.6882
# Fine-tuning iteration 4/5 for dataset UWaveGestureLibraryY
# Iteration 4 - Validation Loss: 1.8033, Validation Accuracy: 0.6991
# Fine-tuning iteration 5/5 for dataset UWaveGestureLibraryY
# Iteration 5 - Validation Loss: 1.7983, Validation Accuracy: 0.6940
# BEST: dname = UWaveGestureLibraryY, Best model appears at iteration: 4, Val Accuracy: 0.6991, Val Loss: 1.8033
# UWaveGestureLibraryY best result appended successfully to LSTM__finetune.csv
# Training on dataset: UWaveGestureLibraryZ
# Loaded model from ./models/LSTM__UWaveGestureLibraryZ__8.keras
# Fine-tuning iteration 1/5 for dataset UWaveGestureLibraryZ
# Iteration 1 - Validation Loss: 1.5288, Validation Accuracy: 0.6893
# Fine-tuning iteration 2/5 for dataset UWaveGestureLibraryZ
# Iteration 2 - Validation Loss: 1.7723, Validation Accuracy: 0.6876
# Fine-tuning iteration 3/5 for dataset UWaveGestureLibraryZ
# Iteration 3 - Validation Loss: 1.8596, Validation Accuracy: 0.6879
# Fine-tuning iteration 4/5 for dataset UWaveGestureLibraryZ
# Iteration 4 - Validation Loss: 1.9048, Validation Accuracy: 0.6935
# Fine-tuning iteration 5/5 for dataset UWaveGestureLibraryZ
# Iteration 5 - Validation Loss: 1.8985, Validation Accuracy: 0.6921
# BEST: dname = UWaveGestureLibraryZ, Best model appears at iteration: 4, Val Accuracy: 0.6935, Val Loss: 1.9048
# UWaveGestureLibraryZ best result appended successfully to LSTM__finetune.csv
# Training on dataset: Wafer
# Loaded model from ./models/LSTM__Wafer__8.keras
# Fine-tuning iteration 1/5 for dataset Wafer
# Iteration 1 - Validation Loss: 0.0308, Validation Accuracy: 0.9943
# Fine-tuning iteration 2/5 for dataset Wafer
# Iteration 2 - Validation Loss: 0.0373, Validation Accuracy: 0.9951
# Fine-tuning iteration 3/5 for dataset Wafer
# Iteration 3 - Validation Loss: 0.0384, Validation Accuracy: 0.9963
# Fine-tuning iteration 4/5 for dataset Wafer
# Iteration 4 - Validation Loss: 0.0452, Validation Accuracy: 0.9955
# Fine-tuning iteration 5/5 for dataset Wafer
# Iteration 5 - Validation Loss: 0.0447, Validation Accuracy: 0.9958
# BEST: dname = Wafer, Best model appears at iteration: 3, Val Accuracy: 0.9963, Val Loss: 0.0384
# Wafer best result appended successfully to LSTM__finetune.csv
# Training on dataset: Wine
# Loaded model from ./models/LSTM__Wine__8.keras
# Fine-tuning iteration 1/5 for dataset Wine
# Iteration 1 - Validation Loss: 0.7219, Validation Accuracy: 0.5000
# Fine-tuning iteration 2/5 for dataset Wine
# Iteration 2 - Validation Loss: 0.7143, Validation Accuracy: 0.5000
# Fine-tuning iteration 3/5 for dataset Wine
# Iteration 3 - Validation Loss: 0.6772, Validation Accuracy: 0.5926
# Fine-tuning iteration 4/5 for dataset Wine
# Iteration 4 - Validation Loss: 0.7650, Validation Accuracy: 0.5556
# Fine-tuning iteration 5/5 for dataset Wine
# Iteration 5 - Validation Loss: 0.9246, Validation Accuracy: 0.5556
# BEST: dname = Wine, Best model appears at iteration: 3, Val Accuracy: 0.5926, Val Loss: 0.6772
# Wine best result appended successfully to LSTM__finetune.csv
# Training on dataset: WordSynonyms
# Loaded model from ./models/LSTM__WordSynonyms__128.keras
# Fine-tuning iteration 1/5 for dataset WordSynonyms
# Iteration 1 - Validation Loss: 2.5562, Validation Accuracy: 0.5110
# Fine-tuning iteration 2/5 for dataset WordSynonyms
# Iteration 2 - Validation Loss: 2.3973, Validation Accuracy: 0.5439
# Fine-tuning iteration 3/5 for dataset WordSynonyms
# Iteration 3 - Validation Loss: 2.3924, Validation Accuracy: 0.5784
# Fine-tuning iteration 4/5 for dataset WordSynonyms
# Iteration 4 - Validation Loss: 2.3924, Validation Accuracy: 0.5815
# Fine-tuning iteration 5/5 for dataset WordSynonyms
# Iteration 5 - Validation Loss: 2.4188, Validation Accuracy: 0.5956
# BEST: dname = WordSynonyms, Best model appears at iteration: 5, Val Accuracy: 0.5956, Val Loss: 2.4188
# WordSynonyms best result appended successfully to LSTM__finetune.csv
# Training on dataset: Worms
# Loaded model from ./models/LSTM__Worms__64.keras
# Fine-tuning iteration 1/5 for dataset Worms
# Iteration 1 - Validation Loss: 2.5219, Validation Accuracy: 0.4675
# Fine-tuning iteration 2/5 for dataset Worms
# Iteration 2 - Validation Loss: 3.0028, Validation Accuracy: 0.4416
# Fine-tuning iteration 3/5 for dataset Worms
# Iteration 3 - Validation Loss: 3.1627, Validation Accuracy: 0.4286
# Fine-tuning iteration 4/5 for dataset Worms
# Iteration 4 - Validation Loss: 3.5164, Validation Accuracy: 0.4286
# Fine-tuning iteration 5/5 for dataset Worms
# Iteration 5 - Validation Loss: 3.6331, Validation Accuracy: 0.4286
# BEST: dname = Worms, Best model appears at iteration: 1, Val Accuracy: 0.4675, Val Loss: 2.5219
# Worms best result appended successfully to LSTM__finetune.csv
# Training on dataset: WormsTwoClass
# Loaded model from ./models/LSTM__WormsTwoClass__64.keras
# Fine-tuning iteration 1/5 for dataset WormsTwoClass
# Iteration 1 - Validation Loss: 1.3759, Validation Accuracy: 0.6494
# Fine-tuning iteration 2/5 for dataset WormsTwoClass
# Iteration 2 - Validation Loss: 1.8302, Validation Accuracy: 0.6623
# Fine-tuning iteration 3/5 for dataset WormsTwoClass
# Iteration 3 - Validation Loss: 1.9850, Validation Accuracy: 0.6494
# Fine-tuning iteration 4/5 for dataset WormsTwoClass
# Iteration 4 - Validation Loss: 2.1058, Validation Accuracy: 0.6234
# Fine-tuning iteration 5/5 for dataset WormsTwoClass
# Iteration 5 - Validation Loss: 2.3215, Validation Accuracy: 0.6234
# BEST: dname = WormsTwoClass, Best model appears at iteration: 2, Val Accuracy: 0.6623, Val Loss: 1.8302
# WormsTwoClass best result appended successfully to LSTM__finetune.csv
# Training on dataset: Yoga
# Loaded model from ./models/LSTM__Yoga__8.keras
# Fine-tuning iteration 1/5 for dataset Yoga
# Iteration 1 - Validation Loss: 0.9771, Validation Accuracy: 0.7613
# Fine-tuning iteration 2/5 for dataset Yoga
# Iteration 2 - Validation Loss: 0.6983, Validation Accuracy: 0.8463
# Fine-tuning iteration 3/5 for dataset Yoga
# Iteration 3 - Validation Loss: 0.7532, Validation Accuracy: 0.8453
# Fine-tuning iteration 4/5 for dataset Yoga
# Iteration 4 - Validation Loss: 0.8602, Validation Accuracy: 0.8447
# Fine-tuning iteration 5/5 for dataset Yoga
# Iteration 5 - Validation Loss: 0.8228, Validation Accuracy: 0.8380
# BEST: dname = Yoga, Best model appears at iteration: 2, Val Accuracy: 0.8463, Val Loss: 0.6983
# Yoga best result appended successfully to LSTM__finetune.csv
# Training on dataset: ACSF1
# Loaded model from ./models/LSTM__ACSF1__64.keras
# Fine-tuning iteration 1/5 for dataset ACSF1
# Iteration 1 - Validation Loss: 2.6432, Validation Accuracy: 0.1200
# Fine-tuning iteration 2/5 for dataset ACSF1
# Iteration 2 - Validation Loss: 3.3229, Validation Accuracy: 0.1500
# Fine-tuning iteration 3/5 for dataset ACSF1
# Iteration 3 - Validation Loss: 2.4072, Validation Accuracy: 0.2200
# Fine-tuning iteration 4/5 for dataset ACSF1
# Iteration 4 - Validation Loss: 2.6141, Validation Accuracy: 0.4000
# Fine-tuning iteration 5/5 for dataset ACSF1
# Iteration 5 - Validation Loss: 4.1619, Validation Accuracy: 0.3600
# BEST: dname = ACSF1, Best model appears at iteration: 4, Val Accuracy: 0.4000, Val Loss: 2.6141
# ACSF1 best result appended successfully to LSTM__finetune.csv
# Training on dataset: Adiac
# Loaded model from ./models/LSTM__Adiac__128.keras
# Fine-tuning iteration 1/5 for dataset Adiac
# Iteration 1 - Validation Loss: 3.0570, Validation Accuracy: 0.2583
# Fine-tuning iteration 2/5 for dataset Adiac
# Iteration 2 - Validation Loss: 2.8146, Validation Accuracy: 0.3146
# Fine-tuning iteration 3/5 for dataset Adiac
# Iteration 3 - Validation Loss: 1.4253, Validation Accuracy: 0.5754
# Fine-tuning iteration 4/5 for dataset Adiac
# Iteration 4 - Validation Loss: 0.9667, Validation Accuracy: 0.7315
# Fine-tuning iteration 5/5 for dataset Adiac
# Iteration 5 - Validation Loss: 0.8941, Validation Accuracy: 0.7519
# BEST: dname = Adiac, Best model appears at iteration: 5, Val Accuracy: 0.7519, Val Loss: 0.8941
# Adiac best result appended successfully to LSTM__finetune.csv
# Training on dataset: AllGestureWiimoteX
# Loaded model from ./models/LSTM__AllGestureWiimoteX__8.keras
# Fine-tuning iteration 1/5 for dataset AllGestureWiimoteX
# Iteration 1 - Validation Loss: 11.9064, Validation Accuracy: 0.1186
# Fine-tuning iteration 2/5 for dataset AllGestureWiimoteX
# Iteration 2 - Validation Loss: 11.8140, Validation Accuracy: 0.1114
# Fine-tuning iteration 3/5 for dataset AllGestureWiimoteX
# Iteration 3 - Validation Loss: 17.1466, Validation Accuracy: 0.1171
# Fine-tuning iteration 4/5 for dataset AllGestureWiimoteX
# Iteration 4 - Validation Loss: 15.3642, Validation Accuracy: 0.1329
# Fine-tuning iteration 5/5 for dataset AllGestureWiimoteX
# Iteration 5 - Validation Loss: 15.0509, Validation Accuracy: 0.1257
# BEST: dname = AllGestureWiimoteX, Best model appears at iteration: 4, Val Accuracy: 0.1329, Val Loss: 15.3642
# AllGestureWiimoteX best result appended successfully to LSTM__finetune.csv

# %%
# after fine tune
# move the models in 2nd train to another folder to keep the directory neat!
current_path = "./models"
to_path = "./models/train"

move_files(current_path,to_path)

# %%
# You may be looking for plots!
# but we don't have plots for this project :D
# since we are training 128 datasets, we cannot output training accuracy curve for every dataset!
# for table illustration of number of best cell & accuracies, please see README or reports!
# or you can run pd.read_csv(csv_path, encoding = "UTF-8") to look into rare data!
# good luck and goodbye and happy holiday/New Year!
